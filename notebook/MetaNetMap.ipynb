# %% [markdown]
# # Using MetaNetMap

# %% [markdown]
# MetNetMap aims to map metabolites between metabolomic data and metabolic networks.
#
# There are several challenges to this task:
#
# - **ID homogenization in metabolic networks:**
#   Automatic reconstruction of metabolic networks using different tools often assigns different IDs to the same metabolites. This inconsistency makes it difficult to cross-compare or transfer data across networks.
#
# - **Metabolomic data complexities:**
#   Due to the difficulty of annotating metabolomic profiles, identifications are often partial, incomplete, and inconsistently represented. For example, enantiomers are frequently not precisely specified because they are indistinguishable by LC/MS methods (to be confirmed with Sylvain).
#
# Successfully bridging metabolomic data and metabolic networks is complex but highly valuable, both for species-specific studies and community-level analyses.
#
# Metanetmap enables this bridging process. We have developed a tool that primarily allows the construction of a knowledge base based on:
#
# The ``datatable_conversion`` file acts as a bridge between the metabolomics data and the metabolic networks.
# It combines all structured information extracted from the MetaCyc ``compounds.dat`` file, along with any additional identifiers or metadata provided by the user through the ``datatable_complementary`` file.
#
# This unified table serves as a comprehensive knowledge base that allows the tool to search across all known identifiers for a given metabolite and match them between the input data and the metabolic networks.
#
# By leveraging both the MetaCyc database and user-provided enhancements, the ``datatable_conversion`` enables robust and flexible mapping across diverse data sources.
#
# > <picture>
# >   <source media="(prefers-color-scheme: light)" srcset="https://raw.githubusercontent.com/Mqxx/GitHub-Markdown/main/blockquotes/badge/light-theme/info.svg">
# >   <img alt="Info" src="https://raw.githubusercontent.com/Mqxx/GitHub-Markdown/main/blockquotes/badge/dark-theme/info.svg">
# > </picture><br>
# > Metacyc database information related to the ontology of metabolites and pathways is not included in test option.
#
#
# This notebook is used to regenerate mapping with toys using Metacyc datatable. For more details about MetaNetX conversion datatable, please refers to [documentation](https://metanetmap.readthedocs.io/en/latest/index.html).
#
# To sum up, it covers the use of MetNetMap, as well as the results of our mapping.
#
#
# #### Table of contents:
# - [0. Requirements : Jupyter](#requirements)
# - [I. Data requirements](#data)
# - [II. General use of the MetaNetMap](#general)
#
#
#
# ***

# %% [markdown]
# ## 0. Requirements : Jupyter <a id="requirements"></a>
#
# /!\ In order to use this notebook, it mandatory to activate a specific environnement and set the jupyter kernel.
# If this step is not done, the tutorial is below.
#
#
# ### Conda environment
#
#
# - **Step 1** : Create a conda environemnt <a name="Conda"></a>
# Create your environnement :
#
# ```
# conda env create -n <name> python==3.11
# conda activate <name>
# ```
#
# - **Step 2** : Install python-dfba-sampling in the environment
#
# Install with pip:
#
# ```sh
# pip install metanetmap
# ```
#
# Or from source:
#
# ```sh
# git clone git@gitlab.inria.fr:mistic/metanetmap.git
# cd metanetmap
# pip install -r requirements.txt
# pip install -r requirements_dev.txt
# pip install .
# ```
#
#
# - **Step 3** : Install in the environment (still activated) jupyter :
#
# ```sh
# conda install jupyter
# conda install -n base nb_conda_kernels
# ```
#
# Your Jupyter notebook can now run on the kernel you will set, in our case this environnemnt. It will not working if the kernel is not selected.

# %% [markdown]
# _____________________________________________________

# %% [markdown]
# # I. Data requirements <a id="data"></a>
#
# ## Input data: <a id="inputs"></a>
# ### Summary of Input Files for Database Building Mode
#
# | File/Directory          | Description                                                 |
# |-------------------------|-------------------------------------------------------------|
# | `metacyc_compounds`       | Tabular file provided by the MetaCyc database                |
# | `chem_xref`       | Tabular file provided by the MetanetX database                |
# | `datatable_complementary` | Tabular file provided by the user (see details below)       |
# | `output -o`               | Output directory for mapping results and logs               |
#
# > <picture>
# >   <source media="(prefers-color-scheme: light)" srcset="https://raw.githubusercontent.com/Mqxx/GitHub-Markdown/main/blockquotes/badge/light-theme/info.svg">
# >   <img alt="Info" src="https://raw.githubusercontent.com/Mqxx/GitHub-Markdown/main/blockquotes/badge/dark-theme/info.svg">
# > </picture><br>
# > The ouput stucture will be show as 'input' for the Summary of Input Files for Mapping Modes just below.
#
#
# ### Overview structure
# <h3 style="color: green;">metacyc_compounds:</h3>
#
# ><picture>
# >   <source media="(prefers-color-scheme: light)" srcset="https://raw.githubusercontent.com/Mqxx/GitHub-Markdown/main/blockquotes/badge/light-theme/info.svg">
# >   <img alt="Info" src="https://raw.githubusercontent.com/Mqxx/GitHub-Markdown/main/blockquotes/badge/dark-theme/info.svg">
# > </picture><br>
# > The `datatable_complementary` is a tabular file provided by the user. It allows users to add their own custom identifiers in order to improve matching with their metabolomics data.icence for MetaCyc
#
# The following is a raw entry for a compound from a MetaCyc flat file `.dat` extension.
# The file is structured as key-value pairs, where each line represents a specific property or annotation of the compound.
#
# Some keys, such as `CHEMICAL-FORMULA`, `SYNONYMS`, or `DBLINKS`, may occur multiple times. Values can contain nested content, quotes, or formatting(e.g. HTML tags in names).
#
# Some Key Characteristics (non-exhaustive)
#
# | **Field**                | **Description**                                                                                        |
# |--------------------------|--------------------------------------------------------------------------------------------------------|
# | `UNIQUE-ID`              | Primary identifier of the compound in the MetaCyc database.                                            |
# | `TYPES`                  | Declares the type of entity — typically `Compound`, but can also be other biological entities.         |
# | `COMMON-NAME`            | Human-readable compound name. May contain HTML formatting.                                             |
# | `CHEMICAL-FORMULA`       | Chemical composition split across multiple lines, each specifying an element and its count.            |
# | `DBLINKS`                | Cross-references to external databases such as BiGG, ChEBI, HMDB, KEGG, PubChem, etc. Multiple lines.  |
# | `INCHI`                  | Standard InChI string describing the molecular structure.                                              |
# | `INCHI-KEY`              | Hashed InChI identifier (short, fixed-length string) used for quick comparison of chemical structures. |
# | `INSTANCE-NAME-TEMPLATE` | A template indicating how this compound ID is generated or structured (e.g., starts with `CPD-`).      |
# | `LOGP`                   | Octanol–water partition coefficient (logP), representing hydrophobicity.                               |
# | `MOLECULAR-WEIGHT`       | Average molecular weight based on atomic composition.                                                  |
# | `MONOISOTOPIC-MW`        | Exact mass using the most abundant isotope for each element.                                           |
# | `NON-STANDARD-INCHI`     | Alternative or non-standard InChI representation.                                                      |
# | `POLAR-SURFACE-AREA`     | Topological polar surface area (TPSA) of the molecule.                                                 |
# | `SMILES`                 | Simplified Molecular Input Line Entry System (SMILES) string representing the structure.               |
# | `SYNONYMS`               | Alternate or common names for the compound. Can appear on multiple lines.                              |
#
# ____________________________________
#
# <h3 style="color: green;">datatable_complementary:</h3>
# Tabular file provided by the user
#
# | UNIQUE-ID        | ADD-COMPLEMENT                      | BIGG | SEED |
# |------------------|-------------------------------------|------|------|
# | CPD-7100         | (2S)-2-isopropyl-3-oxosuccinic acid |      |      |
# | DI-H-OROTATE     | (S)-dihydroorotic acid              |      |      |
# | SHIKIMATE-5P     | 3-phosphoshikimic acid              |      |      |
# | DIAMINONONANOATE | 7,8-diaminononanoate                | dann |      |
#
# > <picture>
# >   <source media="(prefers-color-scheme: light)" srcset="https://raw.githubusercontent.com/Mqxx/GitHub-Markdown/main/blockquotes/badge/light-theme/info.svg">
# >   <img alt="Info" src="https://raw.githubusercontent.com/Mqxx/GitHub-Markdown/main/blockquotes/badge/dark-theme/info.svg">
# > </picture><br>
# > The `datatable_complementary` is a tabular file provided by the user. It allows users to add their own custom identifiers in order to improve matching with their metabolomics data.
#
#
# **Requirements and structure:**
#
# - The **first column must be** a ``UNIQUE-ID`` that links to the MetaCyc database.
# - All **following columns are free** and may contain any identifiers or names. Their column names will be automatically included in the main conversion datatable.
# - The file must be in tabular format (e.g., TSV), with headers.
#
#
# <h4 style="color: red;">Important notes:</h4>
#
# - If you have a metabolite **without a matching ``UNIQUE-ID`` in MetaCyc**, you may assign it a **custom or fictional ID** in the first column.
# - This fictional ``UNIQUE-ID`` will still be included in the conversion table, and **will be used if a match is found based on the name or identifier you provided.**
# - Be sure to keep track of any custom or fictional IDs you create, so you can filter or manage them later if needed.

# %% [markdown]
# ___________________

# %% [markdown]
# ### Summary of Input Files for Mapping Modes  <a id="input-mode"></a>
#
# | File/Directory        | Description                                                 |
# |-----------------------|-------------------------------------------------------------|
# | `MetaNetMap output`   | Output directory for mapping results and logs               |
# | `metabolic_networks`  | Path to the directory with `.sbml` and/or `.xml` files      |
# | `metabolomics_data`   | Tabulated file (see note below for details)                 |
# | `datatable_conversion`| Tabulated file, first column is the `UNIQUE-ID` in MetaCyc  |
#
#
# > <picture>
# >   <source media="(prefers-color-scheme: light)" srcset="https://raw.githubusercontent.com/Mqxx/GitHub-Markdown/main/blockquotes/badge/light-theme/info.svg">
# >   <img alt="Info" src="https://raw.githubusercontent.com/Mqxx/GitHub-Markdown/main/blockquotes/badge/dark-theme/info.svg">
# > </picture><br>
# > For `metabolomics_data`:
# > Column names must follow a specific naming convention to be properly processed by the tool during the mapping step.
# >
# > Recognized column names include:
# >
# > `UNIQUE-ID`, `CHEBI`, `COMMON-NAME`, `ABBREV-NAME`, `SYNONYMS`, `ADD-COMPLEMENT`, `MOLECULAR-WEIGHT`, `MONOISOTOPIC-MW`, `SEED`, `BIGG`, `HMDB`, `METANETX`, `LIGAND-CPD`, `REFMET`, `PUBCHEM`, `CAS`, `INCHI-KEY`, `SMILES`
#
#
# ### Overview structure
#
# <h3 style="color: green;">metabolomics_data:</h3>
#
#   > **Note:**
#   > For **metabolomics_data**:
#   > Column names must follow a specific naming convention and each line is a metabolite.
#   > Metabolomic data files must include column names that follow a specific naming convention in order to be properly processed by the tool during the mapping step.
#   >
#   > The following column names are recognized:
#   >
#   > `UNIQUE-ID`, `CHEBI`, `COMMON-NAME`, `ABBREV-NAME`, `SYNONYMS`,
#   > `ADD-COMPLEMENT`, `MOLECULAR-WEIGHT`, `MONOISOTOPIC-MW`, `SEED`,
#   > `BIGG`, `HMDB`, `METANETX`, `LIGAND-CPD`, `REFMET`, `PUBCHEM`,
#   > `CAS`, `INCHI-KEY`, `SMILES`
#
# | UNIQUE-ID  | CHEBI       | COMMON-NAME           | M/Z       | INCHI-KEY                               |
# |------------|-------------|----------------------|-----------|----------------------------------------|
# |            | CHEBI:4167  |                      | 179       |                                        |
# |            |             | L-methionine         | 150       |                                        |
# | CPD-17381  |             | roquefortine C       | 389.185   |                                        |
# |            |             |                      |           | InChIKey=CGBYBGVMDAPUIH-ARJAWSKDSA-L  |
# | CPD-25370  | 84783       |                      | 701.58056 |                                        |
# |            | CHEBI:16708 | Adenine              |           |                                        |
#
# ---
#
# <h3 style="color: green;">Metabolic networks: </h3>
#
# ```xml
# <?xml version="1.0" encoding="UTF-8"?>
# <sbml xmlns="http://www.sbml.org/sbml/level3/version1/core"
#       level="3" version="1">
#   <model id="example_model" name="Example Metabolic Model">
#     <!-- Compartments -->
#     <listOfCompartments>
#       <compartment id="cytosol" name="Cytosol" constant="true"/>
#     </listOfCompartments>
#
#     <listOfSpecies>
#       <species id="glucose_c" name="Glucose" compartment="cytosol" initialAmount="1.0" hasOnlySubstanceUnits="false" boundaryCondition="false" constant="false">
#         <annotation>
#           <rdf:RDF xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#">
#             <rdf:Description rdf:about="#glucose_c">
#               <bqbiol:is>
#                 <rdf:Bag>
#                   <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:17234"/>
#                   <rdf:li rdf:resource="http://identifiers.org/inchikey/WQZGKKKJIJFFOK-GASJEMHNSA-N"/>
#                 </rdf:Bag>
#               </bqbiol:is>
#             </rdf:Description>
#           </rdf:RDF>
#         </annotation>
#       </species>
#     </listOfSpecies>
#
#   </model>
# </sbml>
# ```
#
# For **metabolic network data**, we typically extract the ID and name, as well as all possible metadata present in the networks, for example: (chebi, InChIKey...) via annotation.
#
# | Element              | Description                                                                   |
# |----------------------|-------------------------------------------------------------------------------|
# | `species`            | Defines a metabolite within a compartment                                     |
# | `annotation`         | Contains **metadata** in RDF format, including standardized cross-references  |
# | `chebi` / `inchikey` | Links to standardized identifiers for interoperability                        |
#
# ---
#
# <h3 style="color: green;">Datatable_conversion: </h3>
#
# The ``datatable_conversion`` file acts as a bridge between the metabolomic data and the metabolic networks.
# It combines all structured information extracted from the MetaCyc ``compounds.dat`` file, along with any additional identifiers or metadata provided by the user through the ``datatable_complementary`` file.
# This unified table serves as a comprehensive knowledge base that allows the tool to search across all known identifiers for a given metabolite, and match them between the input metabolomic data and the metabolic networks.
# By leveraging both the MetaCyc database and user-provided knowledge, the ``datatable_conversion`` enables robust and flexible mapping across diverse data sources.
#
#
# | UNIQUE-ID    | CHEBI  | COMMON-NAME           | ABBREV-NAME | SYNONYMS                                            | ADD-COMPLEMENT | MOLECULAR-WEIGHT | MONOISOTOPIC-MW  | SEED | BIGG   |
# |--------------|--------|-----------------------|-------------|-----------------------------------------------------|----------------|------------------|------------------|------|--------|
# | CPD-17257    | 30828  | trans-vaccenate       |             | ["trans-vaccenic acid","(E)-11-octadecenoic acid"]  |                | 281.457          | 282.2558803356   |      |        |
# | CPD-24978    | 50258  | alpha-L-allofuranose  |             |                                                     |                | 180.157          | 180.0633881178   |      |        |
# | CPD-25014    | 147718 | alpha-D-talofuranoses |             |                                                     |                | 180.157          | 180.0633881178   |      |        |
# | CPD-25010    | 153460 | alpha-D-mannofuranose |             |                                                     |                | 180.157          | 180.0633881178   |      |        |
# | Glucopyranose| 4167   | D-glucopyranose       |             | ["6-(hydroxymethyl)tetrahydropyran-2,3,4,5-tetraol"]|                | 180.157          | 180.0633881178   |      | glc__D |
#
#
# Without other columns created with the datatable_complementary, the general keys are listed below:
#
# | Column Name        | Description                                                                                                                                        |
# |--------------------|----------------------------------------------------------------------------------------------------------------------------------------------------|
# | `UNIQUE-ID`        | The unique identifier for the compound, typically from the MetaCyc database (e.g., `CPD-17257`).                                                   |
# | `CHEBI`            | The corresponding ChEBI identifier (if available), used for chemical standardization and interoperability.                                         |
# | `COMMON-NAME`      | The common name of the metabolite as found in MetaCyc or other databases.                                                                          |
# | `ABBREV-NAME`      | Abbreviated name for the metabolite, if defined. Often used in metabolic modeling tools (e.g., COBRA models).                                      |
# | `SYNONYMS`         | A list of alternative names for the metabolite. These may include IUPAC names, trivial names, and other variants used in the literature/databases. |
# | `ADD-COMPLEMENT`   | Reserved for additional manually added metadata or complement terms, if applicable.                                                                |
# | `MOLECULAR-WEIGHT` | The molecular weight (nominal or average) of the metabolite.                                                                                       |
# | `MONOISOTOPIC-MW`  | The monoisotopic molecular weight — i.e., the exact mass based on the most abundant isotope of each element.                                       |
# | `SEED`             | Identifier from the SEED database, if available.                                                                                                   |
# | `BIGG`             | Identifier from the BiGG Models database, if available. Typically used in genome-scale metabolic models.                                           |

# %% [markdown]
# ---
#
# # Output Data
#
# ### Summary of Output File for Database Building Mode
#
# | File/Directory         | Description                                                 |
# |------------------------|-------------------------------------------------------------|
# | `datatable_conversion` | Tabulated file, first column is the `UNIQUE-ID` in MetaCyc  |
# | `logs`                 | Directory providing more detailed information               |
#
# ___
#
# > <picture>
# >   <source media="(prefers-color-scheme: light)" srcset="https://raw.githubusercontent.com/Mqxx/GitHub-Markdown/main/blockquotes/badge/light-theme/info.svg">
# >   <img alt="Info" src="https://raw.githubusercontent.com/Mqxx/GitHub-Markdown/main/blockquotes/badge/dark-theme/info.svg">
# > </picture><br>
# > The `datatable_conversion` file acts as a bridge between the metabolomics data and the metabolic networks.
# > It combines structured data from the MetaCyc `compounds.dat` file with user-provided identifiers or metadata from `datatable_complementary`.
# >
# > This unified table enables comprehensive and flexible mapping across diverse data sources.
# >
# > The `logs` directory contains detailed processing information, helpful for debugging, auditing, and understanding how the tool performed the mapping.
#
# ---
#
# ### Summary of Output File for Mapping Modes
#
# | File/Directory         | Description                                                 |
# |------------------------|-------------------------------------------------------------|
# | `mapping_results`      | Tabulated file with match/unmatch results                   |
# | `logs`                 | Directory providing more detailed information               |
#
#
# <h3 style="color: green;">mapping_results: </h3>
# #### Output File Format
#
# - In **community mode**, the file is named: `community_mapping_results_YYYY-MM-DD_HH:MM:SS.tsv`
# - In **classic mode**, the file is named: `mapping_results_YYYY-MM-DD_HH:MM:SS.tsv`
# - If **partial match** is activated, the filename will include `partial_match` to indicate this.
#
# #### Output file Content and Column Structure
#
# 1. **Metabolite Matches**
#    Lists metabolite names that matched. If multiple matches are found for a single input, they are joined with `_AND_`.
#
# 2. **MetaCyc UNIQUE-ID Match (from `datatable_conversion`)**
#    Shows matches found using MetaCyc `UNIQUE-ID`.
#    Multiple matches are separated by `_AND_` and flagged as uncertain. These are also shown in the **Partial Match** column.
#
# 3. **Input File Match (metabolomics data)**
#    - In **classic mode**: Shows identifier from the input file that matched with the SBML model.
#    - In **community mode**: Shows a list like `[data1, data4]` indicating specific files with matches.
#      More details are available in the logs.
#
# 4. **Partial Match**
#    Contains uncertain or ambiguous matches:
#    - Duplicates (same metabolite matched multiple entries)
#    - Post-processing matches, including:
#      - CHEBI ontology expansion
#      - INCHIKEY simplification
#      - Enantiomer removal
#    These require manual review and are logged in detail.
#
# 5. **Other Columns**
#    Correspond to identifiers or metadata from the metabolomics data.
#    Each cell shows `YES` if a match was found for that ID in the data.
#
#
# <h3 style="color: green;">log: </h3>
#
# Provides more information about each step and the corresponding results.
#
# ```
#
#     -----------------------------------------
#                 MAPPING METABOLITES
#     -----------------------------------------
#
#     ------ Main package version ------
#     numpy version: 2.3.2
#     pandas version: 2.3.2
#     cobra version: 0.29.1
#     libchebipy version: 1.0.10
#
#     Command run:
#     Actual command run (from sys.argv): python /home/cmuller/miniconda3/envs/test2/bin/metanetmap -t -c -p
#
#     #---------------------------#
#           Test COMMUNITY
#     #---------------------------#
#
#      Test with .. code-block:: noneatching test between metabolites derived from metabolomic data on  all metadata in the metabolic network
#     <2> Matching test between metabolites derived from metabolomic data on all metadata in the database conversion
#
#     ++ Match step for "CPD-17381":
#     -- "CPD-17381" is present in database with the UNIQUE-ID "CPD-17381" and matches via "UNIQUE-ID"
#
#     ++ Match step for "CPD-25370":
#     -- "CPD-25370" is present directly in "toys1" metabolic network with the ID "CPD-25370" via "UNIQUE-ID"
#     -- "CPD-25370" is present in database with the UNIQUE-ID "CPD-25370" and matches via "UNIQUE-ID"
#
#     ++ Match step for "C9H16NO5":
#     -- "C9H16NO5" is present directly in "toys3" metabolic network with the ID "pnto__R" via "UNIQUE-ID"
#     -- ""C9H16NO5"" has a partial match. We have a formula as identifier for this metabolite: "C9H16NO5"
#
#     ++ Match step for "4167":
#     -- "4167" is present directly in "toys3" metabolic network with the ID "glc__D" via "CHEBI"
#     .....
#
#     --"NO" is present directly in metabolic network with the corresponding ID "NITRIC-OXIDE" via the match ID "nitric-oxide"
#
#
#     ......
#
#     ----------------------------------------------
#     ---------------MATCH STEP 2-------------------
#     ----------------------------------------------
#
#     <3> Matching test on metabolites that matched only on the database conversion data against all metadata from the metabolic network
#
#     --"Glycocholic acid" is present directly in metabolic network with the corresponding ID "GLYCOCHOLIC_ACID" via the match ID "glycocholic_acid"
#     --"gamma-Tocopherol" is present directly in metabolic network with the corresponding ID "GAMA-TOCOPHEROL" via the match ID "gama-tocopherol"
#
#     .......
#
#
#     -------------------- SUMMARY REPORT --------------------
#
#
#     Recap of Matches:
#       + Matched metabolites: 103
#       + Unmatched metabolites: 43740
#       + Partial matches: 15
#
#      Match Details:
#       -- Full match (database + SBML): 103
#       -- Partial match + metabolic info: 10
#       -- Match only in SBML: 0
#
#      Unmatch Details:
#       -- Full unmatch (no match in DB or SBML): 43514
#       -- Match in DB but not in SBML: 226
#       -- Partial match in DB only: 5
#
#     --------------------------------------------------------
#
#
#     --- Total runtime 1478.55 seconds ---
#      --- MAPPING COMPLETED'

# %% [markdown]
# __________________

# %% [markdown]
# # II. General use of the MetaNetMap
#
# #### a. Build database_conversion
#
# */!\ Warning:* This step requires the MetaCyc database or MetaNetX database. Metacyc information related to the ontology of metabolites and pathways is not included in this test.
# You must provide your own ``compounds.dat`` file from MetaCyc or use MetaNetX files ``chem_xref.tsv`` and ``chem_prop.tsv`` wich are open source.
#
# The ``datatable_conversion`` file acts as a bridge between the metabolomics data and the metabolic networks.
# It combines all structured information extracted from the MetaCyc ``compounds.dat`` or from MetaNetX files ``chem_xref.tsv`` and ``chem_prop.tsv``files, along with any additional identifiers or metadata provided by the user through the ``datatable_complementary`` file.
#
# This unified table serves as a comprehensive knowledge base that allows the tool to search across all known identifiers for a given metabolite and match them between the input data and the metabolic networks.
#
# By leveraging both the MetaCyc database and user-provided enhancements, the ``datatable_conversion`` enables robust and flexible mapping across diverse data sources.
# <a id="general"></a>

# %%
''' Run database building mode**:  

'''
#for Metacyc
# Commented out because we don’t have the MetaCyc compounds.dat file,
# so it can’t be run directly with MetaCyc data.
#!metanetmap build_db --db metacyc -f  <your_path_to_metacyc_compounds.dat>  --compfiles ../src/metanetmap/build_datatable_conversion/datatable_complementary_file  --out_db <output>


##for MetaNetX -> can be time comnsuming because it download inputs files
#!metanetmap build_db --db metanetx -f  <your_path_to_metanetx_chem_prop>  <your_path_to_metanetx_chem_xref> --compfiles ../src/metanetmap/build_datatable_conversion/datatable_complementary --out_db <output>
# !metanetmap build_db --db metanetx --out_db build/
# Out:
# -----------------------------------------
#             BUILD CONVERTION TABLE
# -----------------------------------------
#
#
# Command run:
# Actual command run (from sys.argv): python /home/cmuller/miniconda3/envs/metanetmap/bin/metanetmap build_db --db metanetx --out_db build/
# Downloading chem_prop.tsv from https://www.metanetx.org/cgi-bin/mnxget/mnxref/chem_prop.tsv...
# chem_prop.tsv successfully downloaded to build/metanetx_db/chem_prop.tsv
# File exists: build/metanetx_db/chem_prop.tsv
# Downloading chem_xref.tsv from https://www.metanetx.org/cgi-bin/mnxget/mnxref/chem_xref.tsv...
# chem_xref.tsv successfully downloaded to build/metanetx_db/chem_xref.tsv
# File exists: build/metanetx_db/chem_xref.tsv
#
# ---> Run construction of the datatable for MetaNetX
# /!\  No complementary file added
# Final merged table generated: build/metanetx_conversion_datatable.tsv
#
# --- Total runtime 93.09 seconds ---
#  ---> Construction of the database completed

# %%
''' Show Build mode (display first 10 rows) '''

import os
import pandas as pd

# 1. Set the file path directly
file_path = 'build/metanetx_conversion_datatable.tsv'  

# 2. Check if the file exists
if os.path.isfile(file_path):
    print(f"Found file: {file_path}")

    # 3. Read the file (auto-detect TSV)
    if file_path.endswith('.tsv'):
        df = pd.read_csv(file_path, sep='\t')
    else:
        print("Unsupported file format.")
        df = None

    # 4. Display only the first 10 rows if loaded
    if df is not None:
        display(df.head(10))
else:
    print(f"File not found: {file_path}")

# !rm -r build/
# Out:
# Found file: build/metanetx_conversion_datatable.tsv
#   UNIQUE-ID        CHEBI COMMON_NAME  ABBREV_NAME  SYNONYMS  ADD-COMPLEMENT  \
# 0   BIOMASS          NaN     BIOMASS          NaN       NaN             NaN
# 1    MNXM01          NaN         PMF          NaN       NaN             NaN
# 2    MNXM02  chebi:13365       OH(-)          NaN       NaN             NaN
# 3    MNXM02  chebi:13419       OH(-)          NaN       NaN             NaN
# 4    MNXM02  chebi:16234       OH(-)          NaN       NaN             NaN
# 5    MNXM02  chebi:29356       OH(-)          NaN       NaN             NaN
# 6    MNXM02  chebi:44641       OH(-)          NaN       NaN             NaN
# 7    MNXM02   chebi:5594       OH(-)          NaN       NaN             NaN
# 8    MNXM03  chebi:29412      H3O(+)          NaN       NaN             NaN
# 9     MNXM1  chebi:10744        H(+)          NaN       NaN             NaN
#
#    MOLECULAR_WEIGHT      SEED BIGG         HMDB  METACYC  REFMET  PUBCHEM  \
# 0               NaN  cpd11416  NaN          NaN      NaN     NaN      NaN
# 1           1.00794       NaN  NaN          NaN      NaN     NaN      NaN
# 2          17.00700  cpd15275  oh1  HMDB0001039       OH     NaN      NaN
# 3          17.00700  cpd15275  oh1  HMDB0001039       OH     NaN      NaN
# 4          17.00700  cpd15275  oh1  HMDB0001039       OH     NaN      NaN
# 5          17.00700  cpd15275  oh1  HMDB0001039       OH     NaN      NaN
# 6          17.00700  cpd15275  oh1  HMDB0001039       OH     NaN      NaN
# 7          17.00700  cpd15275  oh1  HMDB0001039       OH     NaN      NaN
# 8          19.02300       NaN  NaN          NaN  OXONIUM     NaN      NaN
# 9           1.00794  cpd00067    h  HMDB0059597   PROTON     NaN      NaN
#
#        VMH  CAS                  INCHI  NON-STANDARD-INCHI  \
# 0      NaN  NaN                    NaN                 NaN
# 1      NaN  NaN           InChI=1S/p+1                 NaN
# 2      oh1  NaN  InChI=1S/H2O/h1H2/p-1                 NaN
# 3      oh1  NaN  InChI=1S/H2O/h1H2/p-1                 NaN
# 4      oh1  NaN  InChI=1S/H2O/h1H2/p-1                 NaN
# 5      oh1  NaN  InChI=1S/H2O/h1H2/p-1                 NaN
# 6      oh1  NaN  InChI=1S/H2O/h1H2/p-1                 NaN
# 7      oh1  NaN  InChI=1S/H2O/h1H2/p-1                 NaN
# 8      NaN  NaN  InChI=1S/H2O/h1H2/p+1                 NaN
# 9  HC02115  NaN           InChI=1S/p+1                 NaN
#
#                      INCHI_KEY           SMILES
# 0                          NaN              NaN
# 1  GPRLSGONYQIRFK-UHFFFAOYSA-N             [H+]
# 2  XLYOFNOQVPJJNP-UHFFFAOYSA-M          [H][O-]
# 3  XLYOFNOQVPJJNP-UHFFFAOYSA-M          [H][O-]
# 4  XLYOFNOQVPJJNP-UHFFFAOYSA-M          [H][O-]
# 5  XLYOFNOQVPJJNP-UHFFFAOYSA-M          [H][O-]
# 6  XLYOFNOQVPJJNP-UHFFFAOYSA-M          [H][O-]
# 7  XLYOFNOQVPJJNP-UHFFFAOYSA-M          [H][O-]
# 8  XLYOFNOQVPJJNP-UHFFFAOYSA-O  [H][O+]([H])[H]
# 9  GPRLSGONYQIRFK-UHFFFAOYSA-N             [H+]

# %% [markdown]
# #### b. Run mapping mode
#
# You can run MetaNetMap in two different modes (classic, Community) with a partial match option :
#
# Rappel partial match:
# - **Partial match**:
# The **partial match** is optional, as it can be time-consuming. It is a post-processing step applied to metabolites or IDs that were not successfully mapped during the initial run. These unmatched entries are re-evaluated using specific strategies, which increase the chances of finding a match (e.g., via CHEBI, INCHIKEY, or enantiomer simplification).
#
# After this processing step, the entire mapping pipeline is re-executed, taking the modifications into account.
#
# **The following treatments are applied:**
#
# - **CHEBI** *(only if a CHEBI column exists in the metabolomics data)*:
#   For each row containing a CHEBI ID, the Python library `libCHEBI` is used to retrieve the full CHEBI ontology of the metabolite. These related terms are then remapped against the target databases.
#
# - **INCHIKEY**:
#   An INCHIKEY is structured as `XXXXXXXXXXXXXX-YYYYYYYAB-Z`. The first block (`X`) represents the core molecular structure. We extract only this primary structure to increase the chances of a match during the second mapping phase.
#
# - **Enantiomers**:
#   Stereochemistry indicators (L, D, R, S) are removed from both the metabolomics data and the databases. This improves matching rates, since stereochemical information is often missing in metabolomics datasets.

# %%
''' Run Classic mode
    The classic mode allows you to input a single metabolomics data file and a directory containing multiple metabolic networks.
'''

# !metanetmap classic -s ../src/metanetmap/toys_tests_data/toys/sbml/ -a ../src/metanetmap/toys_tests_data/toys/maf/toys2.tsv -d ../src/metanetmap/toys_tests_data/conversion_datatable_toys.tsv -o mapping/classic/
# Out:
# -----------------------------------------
#             MAPPING METABOLITES
# -----------------------------------------
#
# ------> Main package version <------
# numpy version: 2.3.3
# pandas version: 2.3.2
# cobra version: 0.29.1
# libchebipy version: 1.0.10
#
# Command run:
# Actual command run (from sys.argv): python /home/cmuller/miniconda3/envs/metanetmap/bin/metanetmap classic -s ../src/metanetmap/toys_tests_data/toys/sbml/ -a ../src/metanetmap/toys_tests_data/toys/maf/toys2.tsv -d ../src/metanetmap/toys_tests_data/conversion_datatable_toys.tsv -o mapping/classic/
#
#
#
# ---->    MODE CLASSIC    <----
#
# Load metabolomics data user path: ../src/metanetmap/toys_tests_data/toys/maf/toys2.tsv and metabolic networks user path: ../src/metanetmap/toys_tests_data/toys/sbml/
#
#
# ---------------PATHS-------------------
# List metabolomics data paths: ['../src/metanetmap/toys_tests_data/toys/maf/toys2.tsv']
# List metabolic networks paths: ['../src/metanetmap/toys_tests_data/toys/sbml/toys1.sbml', '../src/metanetmap/toys_tests_data/toys/sbml/toys3.xml', '../src/metanetmap/toys_tests_data/toys/sbml/toys2.sbml']
#
# 2025-09-13 12:45:24,738 - metanetmap.mapping - INFO -
#
# ----------------------------------------------
# 2025-09-13 12:45:24,738 - metanetmap.mapping - INFO - ---------------MATCH STEP 1-------------------
# 2025-09-13 12:45:24,738 - metanetmap.mapping - INFO - ----------------------------------------------
#
# 2025-09-13 12:45:24,738 - metanetmap.mapping - INFO - <1> Direct matching test between metabolites derived from metabolomic data on all metadata in the metabolic network
# 2025-09-13 12:45:24,738 - metanetmap.mapping - INFO - <2> Matching test between metabolites derived from metabolomic data on all metadata in the database conversion
# 2025-09-13 12:45:24,738 - metanetmap.mapping - INFO -
# ++ Match step for "123564.0":
# 2025-09-13 12:45:24,742 - metanetmap.mapping - INFO -
# ++ Match step for "methionine":
# 2025-09-13 12:45:24,746 - metanetmap.mapping - INFO - --"methionine" is present in database with the UNIQUE-ID "MET" and matches via "COMMON-NAME"
# 2025-09-13 12:45:24,746 - metanetmap.mapping - INFO -
# ++ Match step for "8-O-methylfusarubin alcohol":
# 2025-09-13 12:45:24,750 - metanetmap.mapping - INFO - --"8-O-methylfusarubin alcohol" is present in database with the UNIQUE-ID "CPD-18186" and matches via "COMMON-NAME"
# 2025-09-13 12:45:24,750 - metanetmap.mapping - INFO -
# ++ Match step for "thionine":
# 2025-09-13 12:45:24,754 - metanetmap.mapping - INFO -
# ++ Match step for "beta-D-galactosyl-(1->3)-N-acetyl-beta-D-glucosaminyl-R":
# 2025-09-13 12:45:24,758 - metanetmap.mapping - INFO - --"beta-D-galactosyl-(1->3)-N-acetyl-beta-D-glucosaminyl-R" is present in database with the UNIQUE-ID "beta-Gal-13-beta-GlcNac-R" and matches via "COMMON-NAME"
# 2025-09-13 12:45:24,758 - metanetmap.mapping - INFO - --"beta-D-galactosyl-(1->3)-N-acetyl-beta-D-glucosaminyl-R" has a partial match. We have several UNIQUE-ID identifiers for this metabolite: "beta-Gal-13-beta-GlcNac-R" and "Gal-13-GlcN-R"
# 2025-09-13 12:45:24,758 - metanetmap.mapping - INFO -
# ++ Match step for "orotic acid":
# 2025-09-13 12:45:24,761 - metanetmap.mapping - INFO - --"orotic acid" is present in database with the UNIQUE-ID "OROTATE" and matches via "SYNONYMS"
# 2025-09-13 12:45:24,762 - metanetmap.mapping - INFO -
# ++ Match step for "Carbamyl-phosphate":
# 2025-09-13 12:45:24,765 - metanetmap.mapping - INFO - --"Carbamyl-phosphate" is present directly in metabolic network with the ID "Carbamyl-phosphate" via "SYNONYMS"
# 2025-09-13 12:45:24,765 - metanetmap.mapping - INFO - --"Carbamyl-phosphate" is present in database with the UNIQUE-ID "CARBAMOYL-P" and matches via "SYNONYMS"
# 2025-09-13 12:45:24,765 - metanetmap.mapping - INFO -
# ++ Match step for "pantothenic acid":
# 2025-09-13 12:45:24,769 - metanetmap.mapping - INFO - --"pantothenic acid" is present in database with the UNIQUE-ID "PANTOTHENATE" and matches via "ADD-COMPLEMENT"
# 2025-09-13 12:45:24,769 - metanetmap.mapping - INFO -
# ++ Match step for "InChIKey=FSCYHDCTAZZSKN-DJNGBR":
# 2025-09-13 12:45:24,772 - metanetmap.mapping - INFO -
# ++ Match step for "CCCC(=O)OCC(/C=C=C1([C@](C)(O)C[C@@H](OC(=O)C)CC(C)(C)1))=C/C=C/C(\C)=C/C=C/C=C(C)/C=C/C=C(C)/C(=O)C[C@]23(C(C)(C)C[C@H](O)C[C@@](C)(O2)3)":
# 2025-09-13 12:45:24,777 - metanetmap.mapping - INFO - --"CCCC(=O)OCC(/C=C=C1([C@](C)(O)C[C@@H](OC(=O)C)CC(C)(C)1))=C/C=C/C(\C)=C/C=C/C=C(C)/C=C/C=C(C)/C(=O)C[C@]23(C(C)(C)C[C@H](O)C[C@@](C)(O2)3)" is present in database with the UNIQUE-ID "CPD-26454" and matches via "SMILES"
# 2025-09-13 12:45:24,777 - metanetmap.mapping - INFO -
# ++ Match step for "C(S)[C@@H](C(NCCC(=O)[O-])=O)NC(=O)CC[C@@H](C([O-])=O)NC(=O)[C@H](CS)NC(=O)CC[C@H]([NH3+])C([O-])":
# 2025-09-13 12:45:24,781 - metanetmap.mapping - INFO -
#
# ----------------------------------------------
# 2025-09-13 12:45:24,781 - metanetmap.mapping - INFO - ---------------MATCH STEP 2-------------------
# 2025-09-13 12:45:24,781 - metanetmap.mapping - INFO - ----------------------------------------------
#
# 2025-09-13 12:45:24,781 - metanetmap.mapping - INFO - <3> Matching test on metabolites that matched only on the database conversion data against all metadata from the metabolic network
#
# 2025-09-13 12:45:24,781 - metanetmap.mapping - INFO - --"methionine" is present directly in metabolic network with the corresponding ID "MET" via the match ID "met"
# 2025-09-13 12:45:24,784 - metanetmap.mapping - INFO - --"methionine" is present directly in metabolic network with the corresponding ID "met__L" via the match ID "57844"
# 2025-09-13 12:45:24,787 - metanetmap.mapping - INFO - --"methionine" is present directly in metabolic network with the corresponding ID "MET" via the match ID "met"
# 2025-09-13 12:45:24,800 - metanetmap.mapping - INFO - --"methionine" is present directly in metabolic network with the corresponding ID "met__L" via the match ID "met__l"
# 2025-09-13 12:45:24,802 - metanetmap.mapping - INFO - --"methionine" is present directly in metabolic network with the corresponding ID "met__L" via the match ID "hmdb00696"
# 2025-09-13 12:45:24,805 - metanetmap.mapping - INFO - --"methionine" is present directly in metabolic network with the corresponding ID "met__L" via the match ID "mnxm61"
# 2025-09-13 12:45:24,807 - metanetmap.mapping - INFO - --"methionine" is present directly in metabolic network with the corresponding ID "met__L" via the match ID "c00073"
# 2025-09-13 12:45:24,832 - metanetmap.mapping - INFO - --"8-O-methylfusarubin alcohol" is present directly in metabolic network with the corresponding ID "CPD-18186" via the match ID "cpd-18186"
# 2025-09-13 12:45:24,886 - metanetmap.mapping - INFO - --"beta-D-galactosyl-(1->3)-N-acetyl-beta-D-glucosaminyl-R" is present directly in metabolic network with the corresponding ID "Gal-13-GlcN-R" via the match ID "gal-13-glcn-r"
# 2025-09-13 12:45:24,900 - metanetmap.mapping - INFO - --"orotic acid" is present directly in metabolic network with the corresponding ID "orot" via the match ID "orotate"
# 2025-09-13 12:45:24,903 - metanetmap.mapping - INFO - --"orotic acid" is present directly in metabolic network with the corresponding ID "orot" via the match ID "30839"
# 2025-09-13 12:45:24,906 - metanetmap.mapping - INFO - --"orotic acid" is present directly in metabolic network with the corresponding ID "orot" via the match ID "orotate"
# 2025-09-13 12:45:24,919 - metanetmap.mapping - INFO - --"orotic acid" is present directly in metabolic network with the corresponding ID "orot" via the match ID "cpd00247"
# 2025-09-13 12:45:24,922 - metanetmap.mapping - INFO - --"orotic acid" is present directly in metabolic network with the corresponding ID "orot" via the match ID "orot"
# 2025-09-13 12:45:24,924 - metanetmap.mapping - INFO - --"orotic acid" is present directly in metabolic network with the corresponding ID "orot" via the match ID "hmdb00226"
# 2025-09-13 12:45:24,927 - metanetmap.mapping - INFO - --"orotic acid" is present directly in metabolic network with the corresponding ID "orot" via the match ID "mnxm235"
# 2025-09-13 12:45:24,930 - metanetmap.mapping - INFO - --"orotic acid" is present directly in metabolic network with the corresponding ID "orot" via the match ID "c00295"
# 2025-09-13 12:45:24,992 - metanetmap.mapping - INFO - --"pantothenic acid" is present directly in metabolic network with the corresponding ID "pnto__R" via the match ID "pantothenate"
# 2025-09-13 12:45:24,995 - metanetmap.mapping - INFO - --"pantothenic acid" is present directly in metabolic network with the corresponding ID "pnto__R" via the match ID "29032"
# 2025-09-13 12:45:25,015 - metanetmap.mapping - INFO - --"pantothenic acid" is present directly in metabolic network with the corresponding ID "pnto__R" via the match ID "cpd00644"
# 2025-09-13 12:45:25,018 - metanetmap.mapping - INFO - --"pantothenic acid" is present directly in metabolic network with the corresponding ID "pnto__R" via the match ID "pnto__r"
# 2025-09-13 12:45:25,021 - metanetmap.mapping - INFO - --"pantothenic acid" is present directly in metabolic network with the corresponding ID "pnto__R" via the match ID "hmdb00210"
# 2025-09-13 12:45:25,024 - metanetmap.mapping - INFO - --"pantothenic acid" is present directly in metabolic network with the corresponding ID "pnto__R" via the match ID "mnxm364"
# 2025-09-13 12:45:25,027 - metanetmap.mapping - INFO - --"pantothenic acid" is present directly in metabolic network with the corresponding ID "pnto__R" via the match ID "c00864"
# 2025-09-13 12:45:25,051 - metanetmap.mapping - INFO - --"CCCC(=O)OCC(/C=C=C1([C@](C)(O)C[C@@H](OC(=O)C)CC(C)(C)1))=C/C=C/C(\C)=C/C=C/C=C(C)/C=C/C=C(C)/C(=O)C[C@]23(C(C)(C)C[C@H](O)C[C@@](C)(O2)3)" is present directly in metabolic network with the corresponding ID "CPD-26454" via the match ID "cpd-26454"
# 2025-09-13 12:45:25,079 - metanetmap.mapping - INFO -
# -------------------- SUMMARY REPORT --------------------
#
# 2025-09-13 12:45:25,079 - metanetmap.mapping - INFO -
# Recap of Matches:
# 2025-09-13 12:45:25,079 - metanetmap.mapping - INFO -   + Matched metabolites: 7
# 2025-09-13 12:45:25,079 - metanetmap.mapping - INFO -   + Unmatched metabolites: 3
# 2025-09-13 12:45:25,079 - metanetmap.mapping - INFO -   + Partial matches: 1
# 2025-09-13 12:45:25,079 - metanetmap.mapping - INFO -
#  Match Details:
# 2025-09-13 12:45:25,079 - metanetmap.mapping - INFO -   --> Full match (database + SBML): 7
# 2025-09-13 12:45:25,079 - metanetmap.mapping - INFO -   --> Partial match + metabolic info: 1
# 2025-09-13 12:45:25,079 - metanetmap.mapping - INFO -   --> Match only in SBML: 0
# 2025-09-13 12:45:25,079 - metanetmap.mapping - INFO -
#  Unmatch Details:
# 2025-09-13 12:45:25,079 - metanetmap.mapping - INFO -   --> Full unmatch (no match in DB or SBML): 3
# 2025-09-13 12:45:25,079 - metanetmap.mapping - INFO -   --> Match in DB but not in SBML: 0
# 2025-09-13 12:45:25,079 - metanetmap.mapping - INFO -   --> Partial match in DB only: 0
# 2025-09-13 12:45:25,079 - metanetmap.mapping - INFO -
# --------------------------------------------------------
#
# Output file successfully written to: mapping/classic/mapping_results_2025-09-13_12:45:23.tsv
#
# --- Total runtime 2.03 seconds ---
#  ---> MAPPING COMPLETED'

# %%
''' Show Classic mode 

'''
import os
import pandas as pd

# 1. Set the directory path
directory = 'mapping/classic/'

# 2. List all files in the directory
files = [f for f in os.listdir(directory) if os.path.isfile(os.path.join(directory, f))]

# 3. Check if exactly one file exists
if len(files) == 1:
    file_path = os.path.join(directory, files[0])
    print(f"Found file: {file_path}")
    
    # 4. Read the file (auto-detect TSV)
    if file_path.endswith('.tsv'):
        df = pd.read_csv(file_path, sep='\t')
    else:
        print("Unsupported file format.")
        df = None
    
    # 5. Display the table if loaded
    if df is not None:
        display(df)
else:
    print(f"Expected 1 file, found {len(files)}: {files}")
# Out:
# Found file: mapping/classic/mapping_results_2025-09-13_12:45:23.tsv
#                                          Metabolites  \
# 0                                         methionine
# 1                        8-O-methylfusarubin alcohol
# 2  beta-D-galactosyl-(1->3)-N-acetyl-beta-D-gluco...
# 3                                        orotic acid
# 4                                 Carbamyl-phosphate
# 5                                   pantothenic acid
# 6  CCCC(=O)OCC(/C=C=C1([C@](C)(O)C[C@@H](OC(=O)C)...
# 7  C(S)[C@@H](C(NCCC(=O)[O-])=O)NC(=O)CC[C@@H](C(...
# 8                     InChIKey=FSCYHDCTAZZSKN-DJNGBR
# 9                                           thionine
#
#                                Match in database Match in metabolic networks  \
# 0                                            MET                  ['met__L']
# 1                                      CPD-18186               ['CPD-18186']
# 2  Gal-13-GlcN-R _AND_ beta-Gal-13-beta-GlcNac-R           ['Gal-13-GlcN-R']
# 3                                        OROTATE                    ['orot']
# 4                                    CARBAMOYL-P      ['Carbamyl-phosphate']
# 5                                   PANTOTHENATE                 ['pnto__R']
# 6                                      CPD-26454               ['CPD-26454']
# 7                                            NaN                         NaN
# 8                                            NaN                         NaN
# 9                                            NaN                         NaN
#
#                                    Partial match  Match via UNIQUE-ID  \
# 0                                            NaN                  NaN
# 1                                            NaN                  NaN
# 2  Gal-13-GlcN-R _AND_ beta-Gal-13-beta-GlcNac-R                  NaN
# 3                                            NaN                  NaN
# 4                                            NaN                  NaN
# 5                                            NaN                  NaN
# 6                                            NaN                  NaN
# 7                                            NaN                  NaN
# 8                                            NaN                  NaN
# 9                                            NaN                  NaN
#
#    Match via CHEBI Match via COMMON-NAME  Match via ABBREV-NAME  \
# 0              NaN                   YES                    NaN
# 1              NaN                   YES                    NaN
# 2              NaN                   YES                    NaN
# 3              NaN                   NaN                    NaN
# 4              NaN                   NaN                    NaN
# 5              NaN                   NaN                    NaN
# 6              NaN                   NaN                    NaN
# 7              NaN                   NaN                    NaN
# 8              NaN                   NaN                    NaN
# 9              NaN                   NaN                    NaN
#
#   Match via SYNONYMS Match via ADD-COMPLEMENT  ...  Match via BIGG  \
# 0                NaN                      NaN  ...             NaN
# 1                NaN                      NaN  ...             NaN
# 2                NaN                      NaN  ...             NaN
# 3                YES                      NaN  ...             NaN
# 4                YES                      NaN  ...             NaN
# 5                NaN                      YES  ...             NaN
# 6                NaN                      NaN  ...             NaN
# 7                NaN                      NaN  ...             NaN
# 8                NaN                      NaN  ...             NaN
# 9                NaN                      NaN  ...             NaN
#
#    Match via HMDB  Match via METANETX  Match via LIGAND-CPD  Match via REFMET  \
# 0             NaN                 NaN                   NaN               NaN
# 1             NaN                 NaN                   NaN               NaN
# 2             NaN                 NaN                   NaN               NaN
# 3             NaN                 NaN                   NaN               NaN
# 4             NaN                 NaN                   NaN               NaN
# 5             NaN                 NaN                   NaN               NaN
# 6             NaN                 NaN                   NaN               NaN
# 7             NaN                 NaN                   NaN               NaN
# 8             NaN                 NaN                   NaN               NaN
# 9             NaN                 NaN                   NaN               NaN
#
#    Match via PUBCHEM  Match via CAS  Match via INCHI-KEY  Match via SMILES  \
# 0                NaN            NaN                  NaN               NaN
# 1                NaN            NaN                  NaN               NaN
# 2                NaN            NaN                  NaN               NaN
# 3                NaN            NaN                  NaN               NaN
# 4                NaN            NaN                  NaN               NaN
# 5                NaN            NaN                  NaN               NaN
# 6                NaN            NaN                  NaN               YES
# 7                NaN            NaN                  NaN               NaN
# 8                NaN            NaN                  NaN               NaN
# 9                NaN            NaN                  NaN               NaN
#
#    Match via FORMULA
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
# 5                NaN
# 6                NaN
# 7                NaN
# 8                NaN
# 9                NaN
#
# [10 rows x 23 columns]

# %% [markdown]
# ## Output File Content and Column Structure
#
# | **Column Name**                  | **Description**                                                                                                                                                       |
# |----------------------------------|-----------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# | `Metabolite`                     | Name of the input metabolite (from the experimental data). May be a name, SMILES, InChIKey, or identifier. If multiple matches are found, they are joined with "\_AND\_".                                                       |
# | `Match in database`             | Main match found in the reference database (e.g., MetaCyc). May be a MetaCyc ID like `CPD-XXXX` or a named entity. Multiple matches are joined with "\_AND\_" and flagged in **Partial Match**.                                                   |
# | `Match in metabolic networks`    | List of metabolite matches in the metabolic network (SBML model). Typically uses short IDs like `met__L`. Returned as a list: `['met__L']`. In community mode, the list indicates each SBML model where the metabolite is present. The name is in the log for more details  |
# | `Partial match`                  | Shows ambiguous or post-processed matches, e.g.: <br> - Duplicates <br> - CHEBI ontology expansion <br> - INCHIKEY simplification <br> - Enantiomer removal         |
# | `Match via UNIQUE-ID`           | Indicates whether a match was found using the MetaCyc `UNIQUE-ID` from the `datatable_conversion`. Displays `YES` if matched.                                        |
# | `Match via CHEBI`               | Match based on **ChEBI** identifier. Displays `YES` if a ChEBI ID in the data matched the network.                                                                   |
# | `Match via COMMON-NAME`         | Match based on common (non-abbreviated) name of the metabolite. E.g., `"methionine"`.                                                                                |
# | `Match via ABBREV-NAME`         | Match based on abbreviated names, often from SBML or COBRA models. E.g., `"met__L"`, `"pnto__R"`.                                                                    |
# | `Match via SYNONYMS`            | Match using any of the listed synonyms for the metabolite. Useful when matching trivial or alternate names.                                                          |
# | `Match via ADD-COMPLEMENT`      | Match using manually added complementary fields (from `ADD-COMPLEMENT` column in your input data).                                                                   |
# | `Match via BIGG`                | Match using **BiGG Models** identifiers. Typically abbreviated and used in genome-scale models.                                                                      |
# | `Match via HMDB`                | Match via **Human Metabolome Database (HMDB)** identifiers.                                                                                                           |
# | `Match via METANETX`            | Match via **MetaNetX** IDs, used for cross-database integration.                                                                                                     |
# | `Match via LIGAND-CPD`          | Match via identifiers from **KEGG Ligand** or other ligand-based databases.                                                                                          |
# | `Match via REFMET`              | Match via **RefMet**, a reference nomenclature system for metabolomics.                                                                                              |
# | `Match via PUBCHEM`             | Match via **PubChem Compound IDs (CIDs)**.                                                                                                                            |
# | `Match via CAS`                 | Match using **CAS numbers** (Chemical Abstracts Service).                                                                                                             |
# | `Match via INCHI-KEY`           | Match based on the **InChIKey**, a hashed version of the InChI chemical identifier.                                                                                   |
# | `Match via SMILES`              | Match via the **SMILES** string (Simplified Molecular Input Line Entry System) representing the molecular structure.                                                  |
# | `Match via FORMULA`             | Match based on **molecular formula**, e.g., `C6H12O6`.                                                                                                                |
# | `Input File Match`              | - **Classic mode**: Matched identifier from the original input file. <br> - **Community mode**: List of input files where the match was found, e.g., `[data1, data3]`. |

# %%
''' Run Classic mode with partial match
    The classic mode allows you to input a single metabolomics data file and a directory containing multiple metabolic networks.

'''

# !metanetmap classic -p -s ../src/metanetmap/toys_tests_data/toys/sbml/ -a ../src/metanetmap/toys_tests_data/toys/maf/toys2.tsv -d ../src/metanetmap/toys_tests_data/conversion_datatable_toys.tsv -o mapping/classic_partial/
# Out:
# -----------------------------------------
#             MAPPING METABOLITES
# -----------------------------------------
#
# ------> Main package version <------
# numpy version: 2.3.3
# pandas version: 2.3.2
# cobra version: 0.29.1
# libchebipy version: 1.0.10
#
# Command run:
# Actual command run (from sys.argv): python /home/cmuller/miniconda3/envs/metanetmap/bin/metanetmap classic -p -s ../src/metanetmap/toys_tests_data/toys/sbml/ -a ../src/metanetmap/toys_tests_data/toys/maf/toys2.tsv -d ../src/metanetmap/toys_tests_data/conversion_datatable_toys.tsv -o mapping/classic_partial/
#
#
#
# ---->    MODE CLASSIC    <----
#
# Load metabolomics data user path: ../src/metanetmap/toys_tests_data/toys/maf/toys2.tsv and metabolic networks user path: ../src/metanetmap/toys_tests_data/toys/sbml/
#
#
# ---------------PATHS-------------------
# List metabolomics data paths: ['../src/metanetmap/toys_tests_data/toys/maf/toys2.tsv']
# List metabolic networks paths: ['../src/metanetmap/toys_tests_data/toys/sbml/toys1.sbml', '../src/metanetmap/toys_tests_data/toys/sbml/toys3.xml', '../src/metanetmap/toys_tests_data/toys/sbml/toys2.sbml']
#
# 2025-09-13 12:45:27,858 - metanetmap.mapping - INFO -
#
# ----------------------------------------------
# 2025-09-13 12:45:27,858 - metanetmap.mapping - INFO - ---------------MATCH STEP 1-------------------
# 2025-09-13 12:45:27,858 - metanetmap.mapping - INFO - ----------------------------------------------
#
# 2025-09-13 12:45:27,858 - metanetmap.mapping - INFO - <1> Direct matching test between metabolites derived from metabolomic data on all metadata in the metabolic network
# 2025-09-13 12:45:27,858 - metanetmap.mapping - INFO - <2> Matching test between metabolites derived from metabolomic data on all metadata in the database conversion
# 2025-09-13 12:45:27,858 - metanetmap.mapping - INFO -
# ++ Match step for "123564.0":
# 2025-09-13 12:45:27,862 - metanetmap.mapping - INFO -
# ++ Match step for "methionine":
# 2025-09-13 12:45:27,866 - metanetmap.mapping - INFO - --"methionine" is present in database with the UNIQUE-ID "MET" and matches via "COMMON-NAME"
# 2025-09-13 12:45:27,867 - metanetmap.mapping - INFO -
# ++ Match step for "8-O-methylfusarubin alcohol":
# 2025-09-13 12:45:27,870 - metanetmap.mapping - INFO - --"8-O-methylfusarubin alcohol" is present in database with the UNIQUE-ID "CPD-18186" and matches via "COMMON-NAME"
# 2025-09-13 12:45:27,870 - metanetmap.mapping - INFO -
# ++ Match step for "thionine":
# 2025-09-13 12:45:27,874 - metanetmap.mapping - INFO -
# ++ Match step for "beta-D-galactosyl-(1->3)-N-acetyl-beta-D-glucosaminyl-R":
# 2025-09-13 12:45:27,878 - metanetmap.mapping - INFO - --"beta-D-galactosyl-(1->3)-N-acetyl-beta-D-glucosaminyl-R" is present in database with the UNIQUE-ID "beta-Gal-13-beta-GlcNac-R" and matches via "COMMON-NAME"
# 2025-09-13 12:45:27,878 - metanetmap.mapping - INFO - --"beta-D-galactosyl-(1->3)-N-acetyl-beta-D-glucosaminyl-R" has a partial match. We have several UNIQUE-ID identifiers for this metabolite: "beta-Gal-13-beta-GlcNac-R" and "Gal-13-GlcN-R"
# 2025-09-13 12:45:27,878 - metanetmap.mapping - INFO -
# ++ Match step for "orotic acid":
# 2025-09-13 12:45:27,882 - metanetmap.mapping - INFO - --"orotic acid" is present in database with the UNIQUE-ID "OROTATE" and matches via "SYNONYMS"
# 2025-09-13 12:45:27,882 - metanetmap.mapping - INFO -
# ++ Match step for "Carbamyl-phosphate":
# 2025-09-13 12:45:27,886 - metanetmap.mapping - INFO - --"Carbamyl-phosphate" is present directly in metabolic network with the ID "Carbamyl-phosphate" via "SYNONYMS"
# 2025-09-13 12:45:27,886 - metanetmap.mapping - INFO - --"Carbamyl-phosphate" is present in database with the UNIQUE-ID "CARBAMOYL-P" and matches via "SYNONYMS"
# 2025-09-13 12:45:27,886 - metanetmap.mapping - INFO -
# ++ Match step for "pantothenic acid":
# 2025-09-13 12:45:27,889 - metanetmap.mapping - INFO - --"pantothenic acid" is present in database with the UNIQUE-ID "PANTOTHENATE" and matches via "ADD-COMPLEMENT"
# 2025-09-13 12:45:27,889 - metanetmap.mapping - INFO -
# ++ Match step for "InChIKey=FSCYHDCTAZZSKN-DJNGBR":
# 2025-09-13 12:45:27,893 - metanetmap.mapping - INFO -
# ++ Match step for "CCCC(=O)OCC(/C=C=C1([C@](C)(O)C[C@@H](OC(=O)C)CC(C)(C)1))=C/C=C/C(\C)=C/C=C/C=C(C)/C=C/C=C(C)/C(=O)C[C@]23(C(C)(C)C[C@H](O)C[C@@](C)(O2)3)":
# 2025-09-13 12:45:27,898 - metanetmap.mapping - INFO - --"CCCC(=O)OCC(/C=C=C1([C@](C)(O)C[C@@H](OC(=O)C)CC(C)(C)1))=C/C=C/C(\C)=C/C=C/C=C(C)/C=C/C=C(C)/C(=O)C[C@]23(C(C)(C)C[C@H](O)C[C@@](C)(O2)3)" is present in database with the UNIQUE-ID "CPD-26454" and matches via "SMILES"
# 2025-09-13 12:45:27,898 - metanetmap.mapping - INFO -
# ++ Match step for "C(S)[C@@H](C(NCCC(=O)[O-])=O)NC(=O)CC[C@@H](C([O-])=O)NC(=O)[C@H](CS)NC(=O)CC[C@H]([NH3+])C([O-])":
# 2025-09-13 12:45:27,902 - metanetmap.mapping - INFO -
#
# ----------------------------------------------
# 2025-09-13 12:45:27,902 - metanetmap.mapping - INFO - ---------------MATCH STEP 2-------------------
# 2025-09-13 12:45:27,902 - metanetmap.mapping - INFO - ----------------------------------------------
#
# 2025-09-13 12:45:27,902 - metanetmap.mapping - INFO - <3> Matching test on metabolites that matched only on the database conversion data against all metadata from the metabolic network
#
# 2025-09-13 12:45:27,902 - metanetmap.mapping - INFO - --"methionine" is present directly in metabolic network with the corresponding ID "MET" via the match ID "met"
# 2025-09-13 12:45:27,905 - metanetmap.mapping - INFO - --"methionine" is present directly in metabolic network with the corresponding ID "met__L" via the match ID "57844"
# 2025-09-13 12:45:27,908 - metanetmap.mapping - INFO - --"methionine" is present directly in metabolic network with the corresponding ID "MET" via the match ID "met"
# 2025-09-13 12:45:27,922 - metanetmap.mapping - INFO - --"methionine" is present directly in metabolic network with the corresponding ID "met__L" via the match ID "met__l"
# 2025-09-13 12:45:27,924 - metanetmap.mapping - INFO - --"methionine" is present directly in metabolic network with the corresponding ID "met__L" via the match ID "hmdb00696"
# 2025-09-13 12:45:27,927 - metanetmap.mapping - INFO - --"methionine" is present directly in metabolic network with the corresponding ID "met__L" via the match ID "mnxm61"
# 2025-09-13 12:45:27,930 - metanetmap.mapping - INFO - --"methionine" is present directly in metabolic network with the corresponding ID "met__L" via the match ID "c00073"
# 2025-09-13 12:45:27,954 - metanetmap.mapping - INFO - --"8-O-methylfusarubin alcohol" is present directly in metabolic network with the corresponding ID "CPD-18186" via the match ID "cpd-18186"
# 2025-09-13 12:45:28,010 - metanetmap.mapping - INFO - --"beta-D-galactosyl-(1->3)-N-acetyl-beta-D-glucosaminyl-R" is present directly in metabolic network with the corresponding ID "Gal-13-GlcN-R" via the match ID "gal-13-glcn-r"
# 2025-09-13 12:45:28,024 - metanetmap.mapping - INFO - --"orotic acid" is present directly in metabolic network with the corresponding ID "orot" via the match ID "orotate"
# 2025-09-13 12:45:28,027 - metanetmap.mapping - INFO - --"orotic acid" is present directly in metabolic network with the corresponding ID "orot" via the match ID "30839"
# 2025-09-13 12:45:28,030 - metanetmap.mapping - INFO - --"orotic acid" is present directly in metabolic network with the corresponding ID "orot" via the match ID "orotate"
# 2025-09-13 12:45:28,043 - metanetmap.mapping - INFO - --"orotic acid" is present directly in metabolic network with the corresponding ID "orot" via the match ID "cpd00247"
# 2025-09-13 12:45:28,046 - metanetmap.mapping - INFO - --"orotic acid" is present directly in metabolic network with the corresponding ID "orot" via the match ID "orot"
# 2025-09-13 12:45:28,049 - metanetmap.mapping - INFO - --"orotic acid" is present directly in metabolic network with the corresponding ID "orot" via the match ID "hmdb00226"
# 2025-09-13 12:45:28,052 - metanetmap.mapping - INFO - --"orotic acid" is present directly in metabolic network with the corresponding ID "orot" via the match ID "mnxm235"
# 2025-09-13 12:45:28,054 - metanetmap.mapping - INFO - --"orotic acid" is present directly in metabolic network with the corresponding ID "orot" via the match ID "c00295"
# 2025-09-13 12:45:28,118 - metanetmap.mapping - INFO - --"pantothenic acid" is present directly in metabolic network with the corresponding ID "pnto__R" via the match ID "pantothenate"
# 2025-09-13 12:45:28,121 - metanetmap.mapping - INFO - --"pantothenic acid" is present directly in metabolic network with the corresponding ID "pnto__R" via the match ID "29032"
# 2025-09-13 12:45:28,141 - metanetmap.mapping - INFO - --"pantothenic acid" is present directly in metabolic network with the corresponding ID "pnto__R" via the match ID "cpd00644"
# 2025-09-13 12:45:28,144 - metanetmap.mapping - INFO - --"pantothenic acid" is present directly in metabolic network with the corresponding ID "pnto__R" via the match ID "pnto__r"
# 2025-09-13 12:45:28,147 - metanetmap.mapping - INFO - --"pantothenic acid" is present directly in metabolic network with the corresponding ID "pnto__R" via the match ID "hmdb00210"
# 2025-09-13 12:45:28,150 - metanetmap.mapping - INFO - --"pantothenic acid" is present directly in metabolic network with the corresponding ID "pnto__R" via the match ID "mnxm364"
# 2025-09-13 12:45:28,153 - metanetmap.mapping - INFO - --"pantothenic acid" is present directly in metabolic network with the corresponding ID "pnto__R" via the match ID "c00864"
# 2025-09-13 12:45:28,178 - metanetmap.mapping - INFO - --"CCCC(=O)OCC(/C=C=C1([C@](C)(O)C[C@@H](OC(=O)C)CC(C)(C)1))=C/C=C/C(\C)=C/C=C/C=C(C)/C=C/C=C(C)/C(=O)C[C@]23(C(C)(C)C[C@H](O)C[C@@](C)(O2)3)" is present directly in metabolic network with the corresponding ID "CPD-26454" via the match ID "cpd-26454"
# 2025-09-13 12:45:28,204 - metanetmap.mapping - INFO -
#
# ------------------------------------------------
# 2025-09-13 12:45:28,204 - metanetmap.mapping - INFO - ---------------PARTIAL MATCH -------------------
# 2025-09-13 12:45:28,204 - metanetmap.mapping - INFO - ----------------------------------------------
#
# 2025-09-13 12:45:28,204 - metanetmap.mapping - INFO - <4> Attempting to find new IDs for unmatched metabolites using multiple strategies: removing enantiomer specificity, using the core part of InChIKeys, or exploring parent/child relationships in CHEBI.
#
# 2025-09-13 12:45:28,205 - metanetmap.mapping - INFO -
# -----> CHEBI <-----
# 2025-09-13 12:45:28,206 - metanetmap.mapping - INFO -
# -----> Inchey <-----
# 2025-09-13 12:45:28,206 - metanetmap.mapping - INFO - Inchey: {key} -> Short Inchey: {value}
# 2025-09-13 12:45:28,206 - metanetmap.mapping - INFO -
# -----> Enantiomers <-----
# 2025-09-13 12:45:28,206 - metanetmap.mapping - INFO - -----> Remove enantiomers in database and in metadata of sbml <-----
# 2025-09-13 12:45:28,288 - metanetmap.mapping - INFO -
#
# ----------------------------------------------------
# 2025-09-13 12:45:28,288 - metanetmap.mapping - INFO - ---------------Retry MATCH STEP 1-------------------
# 2025-09-13 12:45:28,288 - metanetmap.mapping - INFO - ----------------------------------------------------
# 2025-09-13 12:45:28,289 - metanetmap.mapping - INFO -
# -----> Test: CHEBI <-----
# 2025-09-13 12:45:28,289 - metanetmap.mapping - INFO -
# -----> Test: Inchey <-----
# 2025-09-13 12:45:28,289 - metanetmap.mapping - INFO -
# ++ Match step for "InChIKey=FSCYHDCTAZZSKN":
# 2025-09-13 12:45:28,289 - metanetmap.mapping - INFO -
# --Try with InChIKey=FSCYHDCTAZZSKN-DJNGBR":
# 2025-09-13 12:45:28,293 - metanetmap.mapping - INFO -
# -----> Test: Enantiomers <-----
# 2025-09-13 12:45:28,293 - metanetmap.mapping - INFO -
# ++ Match step for "thionine":
# 2025-09-13 12:45:28,298 - metanetmap.mapping - INFO -
# ++ Match step for "C(S)[C@@H](C(NCCC(=O)[O-])=O)NC(=O)CC[C@@H](C([O-])=O)NC(=O)[C@H](CS)NC(=O)CC[C@H]([NH3+])C([O-])":
# 2025-09-13 12:45:28,302 - metanetmap.mapping - INFO -
#
# ----------------------------------------------------
# 2025-09-13 12:45:28,302 - metanetmap.mapping - INFO - ---------------Retry MATCH STEP 2-------------------
# 2025-09-13 12:45:28,302 - metanetmap.mapping - INFO - ----------------------------------------------------
# 2025-09-13 12:45:28,304 - metanetmap.mapping - INFO -
# -------------------- SUMMARY REPORT --------------------
#
# 2025-09-13 12:45:28,304 - metanetmap.mapping - INFO -
# Recap of Matches:
# 2025-09-13 12:45:28,304 - metanetmap.mapping - INFO -   + Matched metabolites: 7
# 2025-09-13 12:45:28,305 - metanetmap.mapping - INFO -   + Unmatched metabolites: 3
# 2025-09-13 12:45:28,305 - metanetmap.mapping - INFO -   + Partial matches: 1
# 2025-09-13 12:45:28,305 - metanetmap.mapping - INFO -
#  Match Details:
# 2025-09-13 12:45:28,305 - metanetmap.mapping - INFO -   --> Full match (database + SBML): 7
# 2025-09-13 12:45:28,305 - metanetmap.mapping - INFO -   --> Partial match + metabolic info: 1
# 2025-09-13 12:45:28,305 - metanetmap.mapping - INFO -   --> Match only in SBML: 0
# 2025-09-13 12:45:28,305 - metanetmap.mapping - INFO -
#  Unmatch Details:
# 2025-09-13 12:45:28,305 - metanetmap.mapping - INFO -   --> Full unmatch (no match in DB or SBML): 3
# 2025-09-13 12:45:28,305 - metanetmap.mapping - INFO -   --> Match in DB but not in SBML: 0
# 2025-09-13 12:45:28,305 - metanetmap.mapping - INFO -   --> Partial match in DB only: 0
# 2025-09-13 12:45:28,305 - metanetmap.mapping - INFO -
# --------------------------------------------------------
#
# Output file successfully written to: mapping/classic_partial/mapping_results_partial_match_2025-09-13_12:45:26.tsv
#
# --- Total runtime 2.19 seconds ---
#  ---> MAPPING COMPLETED'

# %%
''' Show Classic mode partial match

'''
import os
import pandas as pd

# 1. Set the directory path
directory = 'mapping/classic_partial/'

# 2. List all files in the directory
files = [f for f in os.listdir(directory) if os.path.isfile(os.path.join(directory, f))]

# 3. Check if exactly one file exists
if len(files) == 1:
    file_path = os.path.join(directory, files[0])
    print(f"Found file: {file_path}")
    
    # 4. Read the file (auto-detect TSV)
    if file_path.endswith('.tsv'):
        df = pd.read_csv(file_path, sep='\t')
    else:
        print("Unsupported file format.")
        df = None
    
    # 5. Display the table if loaded
    if df is not None:
        display(df)
else:
    print(f"Expected 1 file, found {len(files)}: {files}")
# Out:
# Found file: mapping/classic_partial/mapping_results_partial_match_2025-09-13_12:45:26.tsv
#                                          Metabolites  \
# 0                                         methionine
# 1                        8-O-methylfusarubin alcohol
# 2  beta-D-galactosyl-(1->3)-N-acetyl-beta-D-gluco...
# 3                                        orotic acid
# 4                                 Carbamyl-phosphate
# 5                                   pantothenic acid
# 6  CCCC(=O)OCC(/C=C=C1([C@](C)(O)C[C@@H](OC(=O)C)...
# 7  C(S)[C@@H](C(NCCC(=O)[O-])=O)NC(=O)CC[C@@H](C(...
# 8                     InChIKey=FSCYHDCTAZZSKN-DJNGBR
# 9                                           thionine
#
#                                Match in database Match in metabolic networks  \
# 0                                            MET                  ['met__L']
# 1                                      CPD-18186               ['CPD-18186']
# 2  Gal-13-GlcN-R _AND_ beta-Gal-13-beta-GlcNac-R           ['Gal-13-GlcN-R']
# 3                                        OROTATE                    ['orot']
# 4                                    CARBAMOYL-P      ['Carbamyl-phosphate']
# 5                                   PANTOTHENATE                 ['pnto__R']
# 6                                      CPD-26454               ['CPD-26454']
# 7                                            NaN                         NaN
# 8                                            NaN                         NaN
# 9                                            NaN                         NaN
#
#                                    Partial match  Match via UNIQUE-ID  \
# 0                                            NaN                  NaN
# 1                                            NaN                  NaN
# 2  Gal-13-GlcN-R _AND_ beta-Gal-13-beta-GlcNac-R                  NaN
# 3                                            NaN                  NaN
# 4                                            NaN                  NaN
# 5                                            NaN                  NaN
# 6                                            NaN                  NaN
# 7                                            NaN                  NaN
# 8                                            NaN                  NaN
# 9                                            NaN                  NaN
#
#    Match via CHEBI Match via COMMON-NAME  Match via ABBREV-NAME  \
# 0              NaN                   YES                    NaN
# 1              NaN                   YES                    NaN
# 2              NaN                   YES                    NaN
# 3              NaN                   NaN                    NaN
# 4              NaN                   NaN                    NaN
# 5              NaN                   NaN                    NaN
# 6              NaN                   NaN                    NaN
# 7              NaN                   NaN                    NaN
# 8              NaN                   NaN                    NaN
# 9              NaN                   NaN                    NaN
#
#   Match via SYNONYMS Match via ADD-COMPLEMENT  ...  Match via BIGG  \
# 0                NaN                      NaN  ...             NaN
# 1                NaN                      NaN  ...             NaN
# 2                NaN                      NaN  ...             NaN
# 3                YES                      NaN  ...             NaN
# 4                YES                      NaN  ...             NaN
# 5                NaN                      YES  ...             NaN
# 6                NaN                      NaN  ...             NaN
# 7                NaN                      NaN  ...             NaN
# 8                NaN                      NaN  ...             NaN
# 9                NaN                      NaN  ...             NaN
#
#    Match via HMDB  Match via METANETX  Match via LIGAND-CPD  Match via REFMET  \
# 0             NaN                 NaN                   NaN               NaN
# 1             NaN                 NaN                   NaN               NaN
# 2             NaN                 NaN                   NaN               NaN
# 3             NaN                 NaN                   NaN               NaN
# 4             NaN                 NaN                   NaN               NaN
# 5             NaN                 NaN                   NaN               NaN
# 6             NaN                 NaN                   NaN               NaN
# 7             NaN                 NaN                   NaN               NaN
# 8             NaN                 NaN                   NaN               NaN
# 9             NaN                 NaN                   NaN               NaN
#
#    Match via PUBCHEM  Match via CAS  Match via INCHI-KEY  Match via SMILES  \
# 0                NaN            NaN                  NaN               NaN
# 1                NaN            NaN                  NaN               NaN
# 2                NaN            NaN                  NaN               NaN
# 3                NaN            NaN                  NaN               NaN
# 4                NaN            NaN                  NaN               NaN
# 5                NaN            NaN                  NaN               NaN
# 6                NaN            NaN                  NaN               YES
# 7                NaN            NaN                  NaN               NaN
# 8                NaN            NaN                  NaN               NaN
# 9                NaN            NaN                  NaN               NaN
#
#    Match via FORMULA
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
# 5                NaN
# 6                NaN
# 7                NaN
# 8                NaN
# 9                NaN
#
# [10 rows x 23 columns]

# %%
''' Run Community mode
   The "community" mode allows you to input a directory containing multiple metabolomics data files, as well as a directory containing multiple metabolic networks.


'''

# !metanetmap community -s ../src/metanetmap/toys_tests_data/toys/sbml/ -a ../src/metanetmap/toys_tests_data/toys/maf/ -d ../src/metanetmap/toys_tests_data/conversion_datatable_toys.tsv -o mapping/community/
# Out:
# -----------------------------------------
#             MAPPING METABOLITES
# -----------------------------------------
#
# ------> Main package version <------
# numpy version: 2.3.3
# pandas version: 2.3.2
# cobra version: 0.29.1
# libchebipy version: 1.0.10
#
# Command run:
# Actual command run (from sys.argv): python /home/cmuller/miniconda3/envs/metanetmap/bin/metanetmap community -s ../src/metanetmap/toys_tests_data/toys/sbml/ -a ../src/metanetmap/toys_tests_data/toys/maf/ -d ../src/metanetmap/toys_tests_data/conversion_datatable_toys.tsv -o mapping/community/
#
#
# ---->    MODE COMMUNITY    <----
# Load metabolomics data user path: ../src/metanetmap/toys_tests_data/toys/maf/ and metabolic networks user path: ../src/metanetmap/toys_tests_data/toys/sbml/
#
# ---------------PATHS-------------------
# List metabolomics data paths: ['../src/metanetmap/toys_tests_data/toys/maf/toys1.tsv', '../src/metanetmap/toys_tests_data/toys/maf/toys3.tsv', '../src/metanetmap/toys_tests_data/toys/maf/toys2.tsv']
# List metabolic networks paths: ['../src/metanetmap/toys_tests_data/toys/sbml/toys1.sbml', '../src/metanetmap/toys_tests_data/toys/sbml/toys3.xml', '../src/metanetmap/toys_tests_data/toys/sbml/toys2.sbml']
# 2025-09-13 12:45:31,152 - metanetmap.mapping - INFO -
#
# ----------------------------------------------
# 2025-09-13 12:45:31,152 - metanetmap.mapping - INFO - ---------------MATCH STEP 1-------------------
# 2025-09-13 12:45:31,152 - metanetmap.mapping - INFO - ----------------------------------------------
#
# 2025-09-13 12:45:31,152 - metanetmap.mapping - INFO - <1> Direct matching test between metabolites derived from metabolomic data on all metadata in the metabolic network
# 2025-09-13 12:45:31,152 - metanetmap.mapping - INFO - <2> Matching test between metabolites derived from metabolomic data on all metadata in the database conversion
# 2025-09-13 12:45:31,152 - metanetmap.mapping - INFO -
# ++ Match step for "CPD-17381":
# 2025-09-13 12:45:31,156 - metanetmap.mapping - INFO - --"CPD-17381" is present in database with the UNIQUE-ID "CPD-17381" and matches via "UNIQUE-ID"
# 2025-09-13 12:45:31,156 - metanetmap.mapping - INFO -
# ++ Match step for "CPD-25370":
# 2025-09-13 12:45:31,156 - metanetmap.mapping - INFO - --"CPD-25370" is present directly in "toys1" metabolic network with the ID "CPD-25370" via "UNIQUE-ID"
# 2025-09-13 12:45:31,156 - metanetmap.mapping - INFO - --"CPD-25370" is present in database with the UNIQUE-ID "CPD-25370" and matches via "UNIQUE-ID"
# 2025-09-13 12:45:31,157 - metanetmap.mapping - INFO -
# ++ Match step for "C9H16NO5":
# 2025-09-13 12:45:31,160 - metanetmap.mapping - INFO - --"C9H16NO5" is present directly in "toys3" metabolic network with the ID "pnto__R" via "UNIQUE-ID"
# 2025-09-13 12:45:31,160 - metanetmap.mapping - INFO - --""C9H16NO5"" has a partial match. We have a formula as identifier for this metabolite: "C9H16NO5"
# 2025-09-13 12:45:31,160 - metanetmap.mapping - INFO -
# ++ Match step for "4167":
# 2025-09-13 12:45:31,162 - metanetmap.mapping - INFO - --"4167" is present directly in "toys3" metabolic network with the ID "glc__D" via "CHEBI"
# 2025-09-13 12:45:31,162 - metanetmap.mapping - INFO - --"4167" is present in database with the UNIQUE-ID "Glucopyranose" and matches via "CHEBI"
# 2025-09-13 12:45:31,163 - metanetmap.mapping - INFO -
# ++ Match step for "84783":
# 2025-09-13 12:45:31,167 - metanetmap.mapping - INFO - --"84783" is a metabolite duplicate of "CPD-25370" and matches via "CHEBI"
# 2025-09-13 12:45:31,167 - metanetmap.mapping - INFO -
# ++ Match step for "16708":
# 2025-09-13 12:45:31,168 - metanetmap.mapping - INFO - --"16708" is present directly in "toys3" metabolic network with the ID "ade" via "CHEBI"
# 2025-09-13 12:45:31,168 - metanetmap.mapping - INFO - --"16708" is present in database with the UNIQUE-ID "ADENINE" and matches via "CHEBI"
# 2025-09-13 12:45:31,168 - metanetmap.mapping - INFO -
# ++ Match step for "36023":
# 2025-09-13 12:45:31,172 - metanetmap.mapping - INFO -
# ++ Match step for "90488":
# 2025-09-13 12:45:31,176 - metanetmap.mapping - INFO -
# ++ Match step for "15756":
# 2025-09-13 12:45:31,180 - metanetmap.mapping - INFO -
# ++ Match step for "123564.0":
# 2025-09-13 12:45:31,184 - metanetmap.mapping - INFO -
# ++ Match step for "L-methionine":
# 2025-09-13 12:45:31,188 - metanetmap.mapping - INFO - --"L-methionine" is present in database with the UNIQUE-ID "MET" and matches via "COMMON-NAME"
# 2025-09-13 12:45:31,188 - metanetmap.mapping - INFO -
# ++ Match step for "roquefortine C":
# 2025-09-13 12:45:31,191 - metanetmap.mapping - INFO - --"roquefortine C" is a metabolite duplicate of "CPD-17381" and matches via "COMMON-NAME"
# 2025-09-13 12:45:31,191 - metanetmap.mapping - INFO -
# ++ Match step for "Adenine":
# 2025-09-13 12:45:31,191 - metanetmap.mapping - INFO - --"Adenine" is present directly in "toys1" metabolic network with the ID "ADENINE" via "COMMON-NAME"
# 2025-09-13 12:45:31,191 - metanetmap.mapping - INFO - --"Adenine" is a metabolite duplicate of "16708" and matches via "COMMON-NAME"
# 2025-09-13 12:45:31,191 - metanetmap.mapping - INFO - --"Adenine" is a metabolite duplicate of "16708 _AND_ Adenine" and matches via "COMMON-NAME"
# 2025-09-13 12:45:31,192 - metanetmap.mapping - INFO -
# ++ Match step for "Beta-D-galactosyl-(1->3)-N-acetyl-beta-D-glucosaminyl-R":
# 2025-09-13 12:45:31,196 - metanetmap.mapping - INFO - --"Beta-D-galactosyl-(1->3)-N-acetyl-beta-D-glucosaminyl-R" is present in database with the UNIQUE-ID "beta-Gal-13-beta-GlcNac-R" and matches via "COMMON-NAME"
# 2025-09-13 12:45:31,196 - metanetmap.mapping - INFO - --"Beta-D-galactosyl-(1->3)-N-acetyl-beta-D-glucosaminyl-R" has a partial match. We have several UNIQUE-ID identifiers for this metabolite: "beta-Gal-13-beta-GlcNac-R" and "Gal-13-GlcN-R"
# 2025-09-13 12:45:31,196 - metanetmap.mapping - INFO -
# ++ Match step for "vaccenic":
# 2025-09-13 12:45:31,200 - metanetmap.mapping - INFO -
# ++ Match step for "delphinidin 3-O-(4-coumaroyl-rhamnosyl-(1->6)-glucoside":
# 2025-09-13 12:45:31,204 - metanetmap.mapping - INFO -
# ++ Match step for "methionine":
# 2025-09-13 12:45:31,208 - metanetmap.mapping - INFO - --"methionine" is a metabolite duplicate of "L-methionine" and matches via "COMMON-NAME"
# 2025-09-13 12:45:31,208 - metanetmap.mapping - INFO -
# ++ Match step for "8-O-methylfusarubin alcohol":
# 2025-09-13 12:45:31,212 - metanetmap.mapping - INFO - --"8-O-methylfusarubin alcohol" is present in database with the UNIQUE-ID "CPD-18186" and matches via "COMMON-NAME"
# 2025-09-13 12:45:31,212 - metanetmap.mapping - INFO -
# ++ Match step for "thionine":
# 2025-09-13 12:45:31,216 - metanetmap.mapping - INFO -
# ++ Match step for "beta-D-galactosyl-(1->3)-N-acetyl-beta-D-glucosaminyl-R":
# 2025-09-13 12:45:31,221 - metanetmap.mapping - INFO - --"beta-D-galactosyl-(1->3)-N-acetyl-beta-D-glucosaminyl-R" is a metabolite duplicate of "Beta-D-galactosyl-(1->3)-N-acetyl-beta-D-glucosaminyl-R" and matches via "COMMON-NAME"
# 2025-09-13 12:45:31,221 - metanetmap.mapping - INFO - --"beta-D-galactosyl-(1->3)-N-acetyl-beta-D-glucosaminyl-R" is a metabolite duplicate of "Beta-D-galactosyl-(1->3)-N-acetyl-beta-D-glucosaminyl-R _AND_ beta-D-galactosyl-(1->3)-N-acetyl-beta-D-glucosaminyl-R" and matches via "COMMON-NAME"
# 2025-09-13 12:45:31,221 - metanetmap.mapping - INFO - --"beta-D-galactosyl-(1->3)-N-acetyl-beta-D-glucosaminyl-R" is a metabolite duplicate of "Beta-D-galactosyl-(1->3)-N-acetyl-beta-D-glucosaminyl-R _AND_ beta-D-galactosyl-(1->3)-N-acetyl-beta-D-glucosaminyl-R _AND_ beta-D-galactosyl-(1->3)-N-acetyl-beta-D-glucosaminyl-R" and matches via "COMMON-NAME"
# 2025-09-13 12:45:31,221 - metanetmap.mapping - INFO - --"beta-D-galactosyl-(1->3)-N-acetyl-beta-D-glucosaminyl-R" is a metabolite duplicate of "Beta-D-galactosyl-(1->3)-N-acetyl-beta-D-glucosaminyl-R _AND_ beta-D-galactosyl-(1->3)-N-acetyl-beta-D-glucosaminyl-R _AND_ beta-D-galactosyl-(1->3)-N-acetyl-beta-D-glucosaminyl-R _AND_ beta-D-galactosyl-(1->3)-N-acetyl-beta-D-glucosaminyl-R" and matches via "COMMON-NAME"
# 2025-09-13 12:45:31,221 - metanetmap.mapping - INFO -
# ++ Match step for "orotic acid":
# 2025-09-13 12:45:31,224 - metanetmap.mapping - INFO - --"orotic acid" is present in database with the UNIQUE-ID "OROTATE" and matches via "SYNONYMS"
# 2025-09-13 12:45:31,224 - metanetmap.mapping - INFO -
# ++ Match step for "Carbamyl-phosphate":
# 2025-09-13 12:45:31,228 - metanetmap.mapping - INFO - --"Carbamyl-phosphate" is present directly in "toys2" metabolic network with the ID "Carbamyl-phosphate" via "SYNONYMS"
# 2025-09-13 12:45:31,228 - metanetmap.mapping - INFO - --"Carbamyl-phosphate" is present in database with the UNIQUE-ID "CARBAMOYL-P" and matches via "SYNONYMS"
# 2025-09-13 12:45:31,228 - metanetmap.mapping - INFO -
# ++ Match step for "pantothenic acid":
# 2025-09-13 12:45:31,232 - metanetmap.mapping - INFO - --"pantothenic acid" is present in database with the UNIQUE-ID "PANTOTHENATE" and matches via "ADD-COMPLEMENT"
# 2025-09-13 12:45:31,232 - metanetmap.mapping - INFO -
# ++ Match step for "aprut":
# 2025-09-13 12:45:31,236 - metanetmap.mapping - INFO - --"aprut" is present in database with the UNIQUE-ID "CPD-569" and matches via "BIGG"
# 2025-09-13 12:45:31,236 - metanetmap.mapping - INFO -
# ++ Match step for "f1p":
# 2025-09-13 12:45:31,238 - metanetmap.mapping - INFO - --"f1p" is present directly in "toys3" metabolic network with the ID "f1p" via "BIGG"
# 2025-09-13 12:45:31,238 - metanetmap.mapping - INFO - --"f1p" is present in database with the UNIQUE-ID "FRU1P" and matches via "BIGG"
# 2025-09-13 12:45:31,238 - metanetmap.mapping - INFO - --"f1p" is present in database with the UNIQUE-ID "CPD-15970" and matches via "BIGG"
# 2025-09-13 12:45:31,238 - metanetmap.mapping - INFO - --"f1p" has a partial match. We have several UNIQUE-ID identifiers for this metabolite: "CPD-15970 _AND_ FRU1P
# 2025-09-13 12:45:31,238 - metanetmap.mapping - INFO -
# ++ Match step for "crnmock":
# 2025-09-13 12:45:31,240 - metanetmap.mapping - INFO - --"crnmock" is present directly in "toys3" metabolic network with the ID "crnmock" via "BIGG"
# 2025-09-13 12:45:31,240 - metanetmap.mapping - INFO -
# ++ Match step for "InChIKey=CGBYBGVMDAPUIH-ARJAWSKDSA-L":
# 2025-09-13 12:45:31,244 - metanetmap.mapping - INFO - --"InChIKey=CGBYBGVMDAPUIH-ARJAWSKDSA-L" is present in database with the UNIQUE-ID "DIMETHYLMAL-CPD" and matches via "INCHI-KEY"
# 2025-09-13 12:45:31,244 - metanetmap.mapping - INFO -
# ++ Match step for "InChIKey=AVVWPBAENSWJCB-VSOTGSRCSA-C":
# 2025-09-13 12:45:31,248 - metanetmap.mapping - INFO -
# ++ Match step for "InChIKey=FSCYHDCTAZZSKN-DJNGBR":
# 2025-09-13 12:45:31,252 - metanetmap.mapping - INFO -
# ++ Match step for "CCCC(=O)OCC(/C=C=C1([C@](C)(O)C[C@@H](OC(=O)C)CC(C)(C)1))=C/C=C/C(\C)=C/C=C/C=C(C)/C=C/C=C(C)/C(=O)C[C@]23(C(C)(C)C[C@H](O)C[C@@](C)(O2)3)":
# 2025-09-13 12:45:31,257 - metanetmap.mapping - INFO - --"CCCC(=O)OCC(/C=C=C1([C@](C)(O)C[C@@H](OC(=O)C)CC(C)(C)1))=C/C=C/C(\C)=C/C=C/C=C(C)/C=C/C=C(C)/C(=O)C[C@]23(C(C)(C)C[C@H](O)C[C@@](C)(O2)3)" is present in database with the UNIQUE-ID "CPD-26454" and matches via "SMILES"
# 2025-09-13 12:45:31,257 - metanetmap.mapping - INFO -
# ++ Match step for "C(S)[C@@H](C(NCCC(=O)[O-])=O)NC(=O)CC[C@@H](C([O-])=O)NC(=O)[C@H](CS)NC(=O)CC[C@H]([NH3+])C([O-])":
# 2025-09-13 12:45:31,261 - metanetmap.mapping - INFO -
#
# ----------------------------------------------
# 2025-09-13 12:45:31,261 - metanetmap.mapping - INFO - ---------------MATCH STEP 2-------------------
# 2025-09-13 12:45:31,261 - metanetmap.mapping - INFO - ----------------------------------------------
#
# 2025-09-13 12:45:31,261 - metanetmap.mapping - INFO - <3> Matching test on metabolites that matched only on the database conversion data against all metadata from the metabolic network
#
# 2025-09-13 12:45:31,308 - metanetmap.mapping - INFO - --"Glucopyranose" is present in ['toys1'] metabolic network with the corresponding ID "Glucopyranose" via the match ID "glucopyranose"
# 2025-09-13 12:45:31,327 - metanetmap.mapping - INFO - --"Glucopyranose" is present in ['toys3'] metabolic network with the corresponding ID "glc__D" via the match ID "glc__d"
# 2025-09-13 12:45:31,340 - metanetmap.mapping - INFO - --"Glucopyranose" is present in ['toys1'] metabolic network with the corresponding ID "Glucopyranose" via the match ID "Glucopyranose"
# 2025-09-13 12:45:31,340 - metanetmap.mapping - INFO - --"ADENINE" is present in ['toys1'] metabolic network with the corresponding ID "ADENINE" via the match ID "adenine"
# 2025-09-13 12:45:31,341 - metanetmap.mapping - INFO - --"ADENINE" is present in ['toys1'] metabolic network with the corresponding ID "ADENINE" via the match ID "adenine"
# 2025-09-13 12:45:31,354 - metanetmap.mapping - INFO - --"ADENINE" is present in ['toys3'] metabolic network with the corresponding ID "ade" via the match ID "ade"
# 2025-09-13 12:45:31,356 - metanetmap.mapping - INFO - --"ADENINE" is present in ['toys1'] metabolic network with the corresponding ID "ADENINE" via the match ID "adenine"
# 2025-09-13 12:45:31,371 - metanetmap.mapping - INFO - --"ADENINE" is present in ['toys1'] metabolic network with the corresponding ID "ADENINE" via the match ID "ADENINE"
# 2025-09-13 12:45:31,372 - metanetmap.mapping - INFO - --"L-methionine" is present in ['toys1', 'toys2'] metabolic network with the corresponding ID "MET" via the match ID "met"
# 2025-09-13 12:45:31,372 - metanetmap.mapping - INFO - --"L-methionine" is present in ['toys1', 'toys2'] metabolic network with the corresponding ID "MET" via the match ID "met"
# 2025-09-13 12:45:31,378 - metanetmap.mapping - INFO - --"L-methionine" is present in ['toys1', 'toys2'] metabolic network with the corresponding ID "MET" via the match ID "met"
# 2025-09-13 12:45:31,378 - metanetmap.mapping - INFO - --"L-methionine" is present in ['toys1', 'toys2'] metabolic network with the corresponding ID "MET" via the match ID "met"
# 2025-09-13 12:45:31,392 - metanetmap.mapping - INFO - --"L-methionine" is present in ['toys3'] metabolic network with the corresponding ID "met__L" via the match ID "met__l"
# 2025-09-13 12:45:31,392 - metanetmap.mapping - INFO - --"L-methionine" is present in ['toys3'] metabolic network with the corresponding ID "met__L" via the match ID "met__l"
# 2025-09-13 12:45:31,423 - metanetmap.mapping - INFO - --"ADENINE" is present in ['toys1'] metabolic network with the corresponding ID "ADENINE" via the match ID "adenine"
# 2025-09-13 12:45:31,424 - metanetmap.mapping - INFO - --"ADENINE" is present in ['toys1'] metabolic network with the corresponding ID "ADENINE" via the match ID "adenine"
# 2025-09-13 12:45:31,437 - metanetmap.mapping - INFO - --"ADENINE" is present in ['toys3'] metabolic network with the corresponding ID "ade" via the match ID "ade"
# 2025-09-13 12:45:31,439 - metanetmap.mapping - INFO - --"ADENINE" is present in ['toys1'] metabolic network with the corresponding ID "ADENINE" via the match ID "adenine"
# 2025-09-13 12:45:31,454 - metanetmap.mapping - INFO - --"ADENINE" is present in ['toys1'] metabolic network with the corresponding ID "ADENINE" via the match ID "ADENINE"
# 2025-09-13 12:45:31,483 - metanetmap.mapping - INFO - --"Beta-D-galactosyl-(1->3)-N-acetyl-beta-D-glucosaminyl-R" is present in ['toys1', 'toys2'] metabolic network with the corresponding ID "Gal-13-GlcN-R" via the match ID "gal-13-glcn-r"
# 2025-09-13 12:45:31,500 - metanetmap.mapping - INFO - --"8-O-methylfusarubin alcohol" is present in ['toys2'] metabolic network with the corresponding ID "CPD-18186" via the match ID "cpd-18186"
# 2025-09-13 12:45:31,534 - metanetmap.mapping - INFO - --"orotic acid" is present in ['toys2'] metabolic network with the corresponding ID "orot" via the match ID "orotate"
# 2025-09-13 12:45:31,539 - metanetmap.mapping - INFO - --"orotic acid" is present in ['toys2'] metabolic network with the corresponding ID "orot" via the match ID "orotate"
# 2025-09-13 12:45:31,557 - metanetmap.mapping - INFO - --"orotic acid" is present in ['toys3'] metabolic network with the corresponding ID "orot" via the match ID "orot"
# 2025-09-13 12:45:31,633 - metanetmap.mapping - INFO - --"pantothenic acid" is present in ['toys2'] metabolic network with the corresponding ID "pnto__R" via the match ID "pantothenate"
# 2025-09-13 12:45:31,661 - metanetmap.mapping - INFO - --"pantothenic acid" is present in ['toys3'] metabolic network with the corresponding ID "pnto__R" via the match ID "pnto__r"
# 2025-09-13 12:45:31,786 - metanetmap.mapping - INFO - --"FRU1P" is present in ['toys3'] metabolic network with the corresponding ID "f1p" via the match ID "f1p"
# 2025-09-13 12:45:31,836 - metanetmap.mapping - INFO - --"CPD-15970" is present in ['toys3'] metabolic network with the corresponding ID "f1p" via the match ID "f1p"
# 2025-09-13 12:45:31,862 - metanetmap.mapping - INFO - --"InChIKey=CGBYBGVMDAPUIH-ARJAWSKDSA-L" is present in ['toys1'] metabolic network with the corresponding ID "DIMETHYLMAL-CPD" via the match ID "dimethylmal-cpd"
# 2025-09-13 12:45:31,919 - metanetmap.mapping - INFO - --"CCCC(=O)OCC(/C=C=C1([C@](C)(O)C[C@@H](OC(=O)C)CC(C)(C)1))=C/C=C/C(\C)=C/C=C/C=C(C)/C=C/C=C(C)/C(=O)C[C@]23(C(C)(C)C[C@H](O)C[C@@](C)(O2)3)" is present in ['toys2'] metabolic network with the corresponding ID "CPD-26454" via the match ID "cpd-26454"
# 2025-09-13 12:45:31,950 - metanetmap.mapping - INFO -
# -------------------- SUMMARY REPORT --------------------
#
# 2025-09-13 12:45:31,950 - metanetmap.mapping - INFO -
# Recap of Matches:
# 2025-09-13 12:45:31,950 - metanetmap.mapping - INFO -   + Matched metabolites: 14
# 2025-09-13 12:45:31,950 - metanetmap.mapping - INFO -   + Unmatched metabolites: 10
# 2025-09-13 12:45:31,950 - metanetmap.mapping - INFO -   + Partial matches: 3
# 2025-09-13 12:45:31,950 - metanetmap.mapping - INFO -
#  Match Details:
# 2025-09-13 12:45:31,950 - metanetmap.mapping - INFO -   --> Full match (database + SBML): 12
# 2025-09-13 12:45:31,950 - metanetmap.mapping - INFO -   --> Partial match + metabolic info: 3
# 2025-09-13 12:45:31,950 - metanetmap.mapping - INFO -   --> Match only in SBML: 2
# 2025-09-13 12:45:31,950 - metanetmap.mapping - INFO -
#  Unmatch Details:
# 2025-09-13 12:45:31,950 - metanetmap.mapping - INFO -   --> Full unmatch (no match in DB or SBML): 8
# 2025-09-13 12:45:31,950 - metanetmap.mapping - INFO -   --> Match in DB but not in SBML: 2
# 2025-09-13 12:45:31,950 - metanetmap.mapping - INFO -   --> Partial match in DB only: 0
# 2025-09-13 12:45:31,950 - metanetmap.mapping - INFO -
# --------------------------------------------------------
#
# Output file successfully written to: mapping/community/community_mapping_results_2025-09-13_12:45:29.tsv
#
# --- Total runtime 2.55 seconds ---
#  ---> MAPPING COMPLETED'

# %%
''' Show Community mode 

'''
import os
import pandas as pd

# 1. Set the directory path
directory = 'mapping/community/'

# 2. List all files in the directory
files = [f for f in os.listdir(directory) if os.path.isfile(os.path.join(directory, f))]

# 3. Check if exactly one file exists
if len(files) == 1:
    file_path = os.path.join(directory, files[0])
    print(f"Found file: {file_path}")
    
    # 4. Read the file (auto-detect TSV)
    if file_path.endswith('.tsv'):
        df = pd.read_csv(file_path, sep='\t')
    else:
        print("Unsupported file format.")
        df = None
    
    # 5. Display the table if loaded
    if df is not None:
        display(df)
else:
    print(f"Expected 1 file, found {len(files)}: {files}")
# Out:
# Found file: mapping/community/community_mapping_results_2025-09-13_12:45:29.tsv
#                                           Metabolites  \
# 0                      CPD-17381 _AND_ roquefortine C
# 1                               84783 _AND_ CPD-25370
# 2                                            C9H16NO5
# 3                                                4167
# 4                       L-methionine _AND_ methionine
# 5                                 16708 _AND_ Adenine
# 6   Beta-D-galactosyl-(1->3)-N-acetyl-beta-D-gluco...
# 7                         8-O-methylfusarubin alcohol
# 8                                         orotic acid
# 9                                  Carbamyl-phosphate
# 10                                   pantothenic acid
# 11                                              aprut
# 12                                                f1p
# 13                                            crnmock
# 14               InChIKey=CGBYBGVMDAPUIH-ARJAWSKDSA-L
# 15  CCCC(=O)OCC(/C=C=C1([C@](C)(O)C[C@@H](OC(=O)C)...
# 16                               36023 _AND_ vaccenic
# 17                                              90488
# 18               InChIKey=AVVWPBAENSWJCB-VSOTGSRCSA-C
# 19  delphinidin 3-O-(4-coumaroyl-rhamnosyl-(1->6)-...
# 20                                              15756
# 21  C(S)[C@@H](C(NCCC(=O)[O-])=O)NC(=O)CC[C@@H](C(...
# 22                     InChIKey=FSCYHDCTAZZSKN-DJNGBR
# 23                                           thionine
#
#                                 Match in database  \
# 0                                       CPD-17381
# 1                                       CPD-25370
# 2                                             NaN
# 3                                   Glucopyranose
# 4                                             MET
# 5                                         ADENINE
# 6   Gal-13-GlcN-R _AND_ beta-Gal-13-beta-GlcNac-R
# 7                                       CPD-18186
# 8                                         OROTATE
# 9                                     CARBAMOYL-P
# 10                                   PANTOTHENATE
# 11                                        CPD-569
# 12                          CPD-15970 _AND_ FRU1P
# 13                                            NaN
# 14                                DIMETHYLMAL-CPD
# 15                                      CPD-26454
# 16                                            NaN
# 17                                            NaN
# 18                                            NaN
# 19                                            NaN
# 20                                            NaN
# 21                                            NaN
# 22                                            NaN
# 23                                            NaN
#
#     Match in metabolic networks  \
# 0                           NaN
# 1                     ['toys1']
# 2                     ['toys3']
# 3            ['toys1', 'toys3']
# 4   ['toys1', 'toys2', 'toys3']
# 5            ['toys1', 'toys3']
# 6            ['toys1', 'toys2']
# 7                     ['toys2']
# 8            ['toys2', 'toys3']
# 9                     ['toys2']
# 10           ['toys2', 'toys3']
# 11                          NaN
# 12                    ['toys3']
# 13                    ['toys3']
# 14                    ['toys1']
# 15                    ['toys2']
# 16                          NaN
# 17                          NaN
# 18                          NaN
# 19                          NaN
# 20                          NaN
# 21                          NaN
# 22                          NaN
# 23                          NaN
#
#                                     Partial match Match via UNIQUE-ID  \
# 0                                             NaN                 YES
# 1                                             NaN                 YES
# 2                                        C9H16NO5                 YES
# 3                                             NaN                 NaN
# 4                                             NaN                 NaN
# 5                                             NaN                 NaN
# 6   Gal-13-GlcN-R _AND_ beta-Gal-13-beta-GlcNac-R                 NaN
# 7                                             NaN                 NaN
# 8                                             NaN                 NaN
# 9                                             NaN                 NaN
# 10                                            NaN                 NaN
# 11                                            NaN                 NaN
# 12                          CPD-15970 _AND_ FRU1P                 NaN
# 13                                            NaN                 NaN
# 14                                            NaN                 NaN
# 15                                            NaN                 NaN
# 16                                            NaN                 NaN
# 17                                            NaN                 NaN
# 18                                            NaN                 NaN
# 19                                            NaN                 NaN
# 20                                            NaN                 NaN
# 21                                            NaN                 NaN
# 22                                            NaN                 NaN
# 23                                            NaN                 NaN
#
#    Match via CHEBI Match via COMMON-NAME  Match via ABBREV-NAME  \
# 0              NaN                   YES                    NaN
# 1              YES                   NaN                    NaN
# 2              NaN                   NaN                    NaN
# 3              YES                   NaN                    NaN
# 4              NaN                   YES                    NaN
# 5              NaN                   YES                    NaN
# 6              NaN                   YES                    NaN
# 7              NaN                   YES                    NaN
# 8              NaN                   NaN                    NaN
# 9              NaN                   NaN                    NaN
# 10             NaN                   NaN                    NaN
# 11             NaN                   NaN                    NaN
# 12             NaN                   NaN                    NaN
# 13             NaN                   NaN                    NaN
# 14             NaN                   NaN                    NaN
# 15             NaN                   NaN                    NaN
# 16             NaN                   NaN                    NaN
# 17             NaN                   NaN                    NaN
# 18             NaN                   NaN                    NaN
# 19             NaN                   NaN                    NaN
# 20             NaN                   NaN                    NaN
# 21             NaN                   NaN                    NaN
# 22             NaN                   NaN                    NaN
# 23             NaN                   NaN                    NaN
#
#    Match via SYNONYMS Match via ADD-COMPLEMENT  ...  Match via BIGG  \
# 0                 NaN                      NaN  ...             NaN
# 1                 NaN                      NaN  ...             NaN
# 2                 NaN                      NaN  ...             NaN
# 3                 NaN                      NaN  ...             NaN
# 4                 NaN                      NaN  ...             NaN
# 5                 NaN                      NaN  ...             NaN
# 6                 NaN                      NaN  ...             NaN
# 7                 NaN                      NaN  ...             NaN
# 8                 YES                      NaN  ...             NaN
# 9                 YES                      NaN  ...             NaN
# 10                NaN                      YES  ...             NaN
# 11                NaN                      NaN  ...             YES
# 12                NaN                      NaN  ...             YES
# 13                NaN                      NaN  ...             YES
# 14                NaN                      NaN  ...             NaN
# 15                NaN                      NaN  ...             NaN
# 16                NaN                      NaN  ...             NaN
# 17                NaN                      NaN  ...             NaN
# 18                NaN                      NaN  ...             NaN
# 19                NaN                      NaN  ...             NaN
# 20                NaN                      NaN  ...             NaN
# 21                NaN                      NaN  ...             NaN
# 22                NaN                      NaN  ...             NaN
# 23                NaN                      NaN  ...             NaN
#
#     Match via HMDB  Match via METANETX Match via LIGAND-CPD  Match via REFMET  \
# 0              NaN                 NaN                  NaN               NaN
# 1              NaN                 NaN                  NaN               NaN
# 2              NaN                 NaN                  NaN               NaN
# 3              NaN                 NaN                  NaN               NaN
# 4              NaN                 NaN                  NaN               NaN
# 5              NaN                 NaN                  NaN               NaN
# 6              NaN                 NaN                  NaN               NaN
# 7              NaN                 NaN                  NaN               NaN
# 8              NaN                 NaN                  NaN               NaN
# 9              NaN                 NaN                  NaN               NaN
# 10             NaN                 NaN                  NaN               NaN
# 11             NaN                 NaN                  NaN               NaN
# 12             NaN                 NaN                  NaN               NaN
# 13             NaN                 NaN                  NaN               NaN
# 14             NaN                 NaN                  NaN               NaN
# 15             NaN                 NaN                  NaN               NaN
# 16             NaN                 NaN                  NaN               NaN
# 17             NaN                 NaN                  NaN               NaN
# 18             NaN                 NaN                  NaN               NaN
# 19             NaN                 NaN                  NaN               NaN
# 20             NaN                 NaN                  NaN               NaN
# 21             NaN                 NaN                  NaN               NaN
# 22             NaN                 NaN                  NaN               NaN
# 23             NaN                 NaN                  NaN               NaN
#
#     Match via PUBCHEM  Match via CAS  Match via INCHI-KEY  Match via SMILES  \
# 0                 NaN            NaN                  NaN               NaN
# 1                 NaN            NaN                  NaN               NaN
# 2                 NaN            NaN                  NaN               NaN
# 3                 NaN            NaN                  NaN               NaN
# 4                 NaN            NaN                  NaN               NaN
# 5                 NaN            NaN                  NaN               NaN
# 6                 NaN            NaN                  NaN               NaN
# 7                 NaN            NaN                  NaN               NaN
# 8                 NaN            NaN                  NaN               NaN
# 9                 NaN            NaN                  NaN               NaN
# 10                NaN            NaN                  NaN               NaN
# 11                NaN            NaN                  NaN               NaN
# 12                NaN            NaN                  NaN               NaN
# 13                NaN            NaN                  NaN               NaN
# 14                NaN            NaN                  YES               NaN
# 15                NaN            NaN                  NaN               YES
# 16                NaN            NaN                  NaN               NaN
# 17                NaN            NaN                  NaN               NaN
# 18                NaN            NaN                  NaN               NaN
# 19                NaN            NaN                  NaN               NaN
# 20                NaN            NaN                  NaN               NaN
# 21                NaN            NaN                  NaN               NaN
# 22                NaN            NaN                  NaN               NaN
# 23                NaN            NaN                  NaN               NaN
#
#     Match via FORMULA
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
# 5                 NaN
# 6                 NaN
# 7                 NaN
# 8                 NaN
# 9                 NaN
# 10                NaN
# 11                NaN
# 12                NaN
# 13                NaN
# 14                NaN
# 15                NaN
# 16                NaN
# 17                NaN
# 18                NaN
# 19                NaN
# 20                NaN
# 21                NaN
# 22                NaN
# 23                NaN
#
# [24 rows x 23 columns]

# %%
''' Run Community mode with partial match
    The "community" mode allows you to input a directory containing multiple metabolomics data files, as well as a directory containing multiple metabolic networks.

'''

# !metanetmap community -p -s ../src/metanetmap/toys_tests_data/toys/sbml/ -a ../src/metanetmap/toys_tests_data/toys/maf/ -d ../src/metanetmap/toys_tests_data/conversion_datatable_toys.tsv -o mapping/community_partial/
# Out:
# -----------------------------------------
#             MAPPING METABOLITES
# -----------------------------------------
#
# ------> Main package version <------
# numpy version: 2.3.3
# pandas version: 2.3.2
# cobra version: 0.29.1
# libchebipy version: 1.0.10
#
# Command run:
# Actual command run (from sys.argv): python /home/cmuller/miniconda3/envs/metanetmap/bin/metanetmap community -p -s ../src/metanetmap/toys_tests_data/toys/sbml/ -a ../src/metanetmap/toys_tests_data/toys/maf/ -d ../src/metanetmap/toys_tests_data/conversion_datatable_toys.tsv -o mapping/community_partial/
#
#
# ---->    MODE COMMUNITY    <----
# Load metabolomics data user path: ../src/metanetmap/toys_tests_data/toys/maf/ and metabolic networks user path: ../src/metanetmap/toys_tests_data/toys/sbml/
#
# ---------------PATHS-------------------
# List metabolomics data paths: ['../src/metanetmap/toys_tests_data/toys/maf/toys1.tsv', '../src/metanetmap/toys_tests_data/toys/maf/toys3.tsv', '../src/metanetmap/toys_tests_data/toys/maf/toys2.tsv']
# List metabolic networks paths: ['../src/metanetmap/toys_tests_data/toys/sbml/toys1.sbml', '../src/metanetmap/toys_tests_data/toys/sbml/toys3.xml', '../src/metanetmap/toys_tests_data/toys/sbml/toys2.sbml']
# 2025-09-13 12:45:34,709 - metanetmap.mapping - INFO -
#
# ----------------------------------------------
# 2025-09-13 12:45:34,710 - metanetmap.mapping - INFO - ---------------MATCH STEP 1-------------------
# 2025-09-13 12:45:34,710 - metanetmap.mapping - INFO - ----------------------------------------------
#
# 2025-09-13 12:45:34,710 - metanetmap.mapping - INFO - <1> Direct matching test between metabolites derived from metabolomic data on all metadata in the metabolic network
# 2025-09-13 12:45:34,710 - metanetmap.mapping - INFO - <2> Matching test between metabolites derived from metabolomic data on all metadata in the database conversion
# 2025-09-13 12:45:34,710 - metanetmap.mapping - INFO -
# ++ Match step for "CPD-17381":
# 2025-09-13 12:45:34,713 - metanetmap.mapping - INFO - --"CPD-17381" is present in database with the UNIQUE-ID "CPD-17381" and matches via "UNIQUE-ID"
# 2025-09-13 12:45:34,713 - metanetmap.mapping - INFO -
# ++ Match step for "CPD-25370":
# 2025-09-13 12:45:34,714 - metanetmap.mapping - INFO - --"CPD-25370" is present directly in "toys1" metabolic network with the ID "CPD-25370" via "UNIQUE-ID"
# 2025-09-13 12:45:34,714 - metanetmap.mapping - INFO - --"CPD-25370" is present in database with the UNIQUE-ID "CPD-25370" and matches via "UNIQUE-ID"
# 2025-09-13 12:45:34,714 - metanetmap.mapping - INFO -
# ++ Match step for "C9H16NO5":
# 2025-09-13 12:45:34,717 - metanetmap.mapping - INFO - --"C9H16NO5" is present directly in "toys3" metabolic network with the ID "pnto__R" via "UNIQUE-ID"
# 2025-09-13 12:45:34,717 - metanetmap.mapping - INFO - --""C9H16NO5"" has a partial match. We have a formula as identifier for this metabolite: "C9H16NO5"
# 2025-09-13 12:45:34,717 - metanetmap.mapping - INFO -
# ++ Match step for "4167":
# 2025-09-13 12:45:34,719 - metanetmap.mapping - INFO - --"4167" is present directly in "toys3" metabolic network with the ID "glc__D" via "CHEBI"
# 2025-09-13 12:45:34,719 - metanetmap.mapping - INFO - --"4167" is present in database with the UNIQUE-ID "Glucopyranose" and matches via "CHEBI"
# 2025-09-13 12:45:34,719 - metanetmap.mapping - INFO -
# ++ Match step for "84783":
# 2025-09-13 12:45:34,723 - metanetmap.mapping - INFO - --"84783" is a metabolite duplicate of "CPD-25370" and matches via "CHEBI"
# 2025-09-13 12:45:34,723 - metanetmap.mapping - INFO -
# ++ Match step for "16708":
# 2025-09-13 12:45:34,724 - metanetmap.mapping - INFO - --"16708" is present directly in "toys3" metabolic network with the ID "ade" via "CHEBI"
# 2025-09-13 12:45:34,724 - metanetmap.mapping - INFO - --"16708" is present in database with the UNIQUE-ID "ADENINE" and matches via "CHEBI"
# 2025-09-13 12:45:34,724 - metanetmap.mapping - INFO -
# ++ Match step for "36023":
# 2025-09-13 12:45:34,728 - metanetmap.mapping - INFO -
# ++ Match step for "90488":
# 2025-09-13 12:45:34,731 - metanetmap.mapping - INFO -
# ++ Match step for "15756":
# 2025-09-13 12:45:34,735 - metanetmap.mapping - INFO -
# ++ Match step for "123564.0":
# 2025-09-13 12:45:34,739 - metanetmap.mapping - INFO -
# ++ Match step for "L-methionine":
# 2025-09-13 12:45:34,742 - metanetmap.mapping - INFO - --"L-methionine" is present in database with the UNIQUE-ID "MET" and matches via "COMMON-NAME"
# 2025-09-13 12:45:34,742 - metanetmap.mapping - INFO -
# ++ Match step for "roquefortine C":
# 2025-09-13 12:45:34,746 - metanetmap.mapping - INFO - --"roquefortine C" is a metabolite duplicate of "CPD-17381" and matches via "COMMON-NAME"
# 2025-09-13 12:45:34,746 - metanetmap.mapping - INFO -
# ++ Match step for "Adenine":
# 2025-09-13 12:45:34,746 - metanetmap.mapping - INFO - --"Adenine" is present directly in "toys1" metabolic network with the ID "ADENINE" via "COMMON-NAME"
# 2025-09-13 12:45:34,746 - metanetmap.mapping - INFO - --"Adenine" is a metabolite duplicate of "16708" and matches via "COMMON-NAME"
# 2025-09-13 12:45:34,746 - metanetmap.mapping - INFO - --"Adenine" is a metabolite duplicate of "16708 _AND_ Adenine" and matches via "COMMON-NAME"
# 2025-09-13 12:45:34,746 - metanetmap.mapping - INFO -
# ++ Match step for "Beta-D-galactosyl-(1->3)-N-acetyl-beta-D-glucosaminyl-R":
# 2025-09-13 12:45:34,750 - metanetmap.mapping - INFO - --"Beta-D-galactosyl-(1->3)-N-acetyl-beta-D-glucosaminyl-R" is present in database with the UNIQUE-ID "beta-Gal-13-beta-GlcNac-R" and matches via "COMMON-NAME"
# 2025-09-13 12:45:34,751 - metanetmap.mapping - INFO - --"Beta-D-galactosyl-(1->3)-N-acetyl-beta-D-glucosaminyl-R" has a partial match. We have several UNIQUE-ID identifiers for this metabolite: "beta-Gal-13-beta-GlcNac-R" and "Gal-13-GlcN-R"
# 2025-09-13 12:45:34,751 - metanetmap.mapping - INFO -
# ++ Match step for "vaccenic":
# 2025-09-13 12:45:34,754 - metanetmap.mapping - INFO -
# ++ Match step for "delphinidin 3-O-(4-coumaroyl-rhamnosyl-(1->6)-glucoside":
# 2025-09-13 12:45:34,758 - metanetmap.mapping - INFO -
# ++ Match step for "methionine":
# 2025-09-13 12:45:34,762 - metanetmap.mapping - INFO - --"methionine" is a metabolite duplicate of "L-methionine" and matches via "COMMON-NAME"
# 2025-09-13 12:45:34,762 - metanetmap.mapping - INFO -
# ++ Match step for "8-O-methylfusarubin alcohol":
# 2025-09-13 12:45:34,765 - metanetmap.mapping - INFO - --"8-O-methylfusarubin alcohol" is present in database with the UNIQUE-ID "CPD-18186" and matches via "COMMON-NAME"
# 2025-09-13 12:45:34,765 - metanetmap.mapping - INFO -
# ++ Match step for "thionine":
# 2025-09-13 12:45:34,769 - metanetmap.mapping - INFO -
# ++ Match step for "beta-D-galactosyl-(1->3)-N-acetyl-beta-D-glucosaminyl-R":
# 2025-09-13 12:45:34,773 - metanetmap.mapping - INFO - --"beta-D-galactosyl-(1->3)-N-acetyl-beta-D-glucosaminyl-R" is a metabolite duplicate of "Beta-D-galactosyl-(1->3)-N-acetyl-beta-D-glucosaminyl-R" and matches via "COMMON-NAME"
# 2025-09-13 12:45:34,773 - metanetmap.mapping - INFO - --"beta-D-galactosyl-(1->3)-N-acetyl-beta-D-glucosaminyl-R" is a metabolite duplicate of "Beta-D-galactosyl-(1->3)-N-acetyl-beta-D-glucosaminyl-R _AND_ beta-D-galactosyl-(1->3)-N-acetyl-beta-D-glucosaminyl-R" and matches via "COMMON-NAME"
# 2025-09-13 12:45:34,773 - metanetmap.mapping - INFO - --"beta-D-galactosyl-(1->3)-N-acetyl-beta-D-glucosaminyl-R" is a metabolite duplicate of "Beta-D-galactosyl-(1->3)-N-acetyl-beta-D-glucosaminyl-R _AND_ beta-D-galactosyl-(1->3)-N-acetyl-beta-D-glucosaminyl-R _AND_ beta-D-galactosyl-(1->3)-N-acetyl-beta-D-glucosaminyl-R" and matches via "COMMON-NAME"
# 2025-09-13 12:45:34,773 - metanetmap.mapping - INFO - --"beta-D-galactosyl-(1->3)-N-acetyl-beta-D-glucosaminyl-R" is a metabolite duplicate of "Beta-D-galactosyl-(1->3)-N-acetyl-beta-D-glucosaminyl-R _AND_ beta-D-galactosyl-(1->3)-N-acetyl-beta-D-glucosaminyl-R _AND_ beta-D-galactosyl-(1->3)-N-acetyl-beta-D-glucosaminyl-R _AND_ beta-D-galactosyl-(1->3)-N-acetyl-beta-D-glucosaminyl-R" and matches via "COMMON-NAME"
# 2025-09-13 12:45:34,773 - metanetmap.mapping - INFO -
# ++ Match step for "orotic acid":
# 2025-09-13 12:45:34,777 - metanetmap.mapping - INFO - --"orotic acid" is present in database with the UNIQUE-ID "OROTATE" and matches via "SYNONYMS"
# 2025-09-13 12:45:34,777 - metanetmap.mapping - INFO -
# ++ Match step for "Carbamyl-phosphate":
# 2025-09-13 12:45:34,780 - metanetmap.mapping - INFO - --"Carbamyl-phosphate" is present directly in "toys2" metabolic network with the ID "Carbamyl-phosphate" via "SYNONYMS"
# 2025-09-13 12:45:34,780 - metanetmap.mapping - INFO - --"Carbamyl-phosphate" is present in database with the UNIQUE-ID "CARBAMOYL-P" and matches via "SYNONYMS"
# 2025-09-13 12:45:34,781 - metanetmap.mapping - INFO -
# ++ Match step for "pantothenic acid":
# 2025-09-13 12:45:34,785 - metanetmap.mapping - INFO - --"pantothenic acid" is present in database with the UNIQUE-ID "PANTOTHENATE" and matches via "ADD-COMPLEMENT"
# 2025-09-13 12:45:34,785 - metanetmap.mapping - INFO -
# ++ Match step for "aprut":
# 2025-09-13 12:45:34,789 - metanetmap.mapping - INFO - --"aprut" is present in database with the UNIQUE-ID "CPD-569" and matches via "BIGG"
# 2025-09-13 12:45:34,789 - metanetmap.mapping - INFO -
# ++ Match step for "f1p":
# 2025-09-13 12:45:34,790 - metanetmap.mapping - INFO - --"f1p" is present directly in "toys3" metabolic network with the ID "f1p" via "BIGG"
# 2025-09-13 12:45:34,790 - metanetmap.mapping - INFO - --"f1p" is present in database with the UNIQUE-ID "FRU1P" and matches via "BIGG"
# 2025-09-13 12:45:34,790 - metanetmap.mapping - INFO - --"f1p" is present in database with the UNIQUE-ID "CPD-15970" and matches via "BIGG"
# 2025-09-13 12:45:34,790 - metanetmap.mapping - INFO - --"f1p" has a partial match. We have several UNIQUE-ID identifiers for this metabolite: "CPD-15970 _AND_ FRU1P
# 2025-09-13 12:45:34,790 - metanetmap.mapping - INFO -
# ++ Match step for "crnmock":
# 2025-09-13 12:45:34,792 - metanetmap.mapping - INFO - --"crnmock" is present directly in "toys3" metabolic network with the ID "crnmock" via "BIGG"
# 2025-09-13 12:45:34,792 - metanetmap.mapping - INFO -
# ++ Match step for "InChIKey=CGBYBGVMDAPUIH-ARJAWSKDSA-L":
# 2025-09-13 12:45:34,795 - metanetmap.mapping - INFO - --"InChIKey=CGBYBGVMDAPUIH-ARJAWSKDSA-L" is present in database with the UNIQUE-ID "DIMETHYLMAL-CPD" and matches via "INCHI-KEY"
# 2025-09-13 12:45:34,795 - metanetmap.mapping - INFO -
# ++ Match step for "InChIKey=AVVWPBAENSWJCB-VSOTGSRCSA-C":
# 2025-09-13 12:45:34,799 - metanetmap.mapping - INFO -
# ++ Match step for "InChIKey=FSCYHDCTAZZSKN-DJNGBR":
# 2025-09-13 12:45:34,803 - metanetmap.mapping - INFO -
# ++ Match step for "CCCC(=O)OCC(/C=C=C1([C@](C)(O)C[C@@H](OC(=O)C)CC(C)(C)1))=C/C=C/C(\C)=C/C=C/C=C(C)/C=C/C=C(C)/C(=O)C[C@]23(C(C)(C)C[C@H](O)C[C@@](C)(O2)3)":
# 2025-09-13 12:45:34,808 - metanetmap.mapping - INFO - --"CCCC(=O)OCC(/C=C=C1([C@](C)(O)C[C@@H](OC(=O)C)CC(C)(C)1))=C/C=C/C(\C)=C/C=C/C=C(C)/C=C/C=C(C)/C(=O)C[C@]23(C(C)(C)C[C@H](O)C[C@@](C)(O2)3)" is present in database with the UNIQUE-ID "CPD-26454" and matches via "SMILES"
# 2025-09-13 12:45:34,808 - metanetmap.mapping - INFO -
# ++ Match step for "C(S)[C@@H](C(NCCC(=O)[O-])=O)NC(=O)CC[C@@H](C([O-])=O)NC(=O)[C@H](CS)NC(=O)CC[C@H]([NH3+])C([O-])":
# 2025-09-13 12:45:34,811 - metanetmap.mapping - INFO -
#
# ----------------------------------------------
# 2025-09-13 12:45:34,811 - metanetmap.mapping - INFO - ---------------MATCH STEP 2-------------------
# 2025-09-13 12:45:34,811 - metanetmap.mapping - INFO - ----------------------------------------------
#
# 2025-09-13 12:45:34,811 - metanetmap.mapping - INFO - <3> Matching test on metabolites that matched only on the database conversion data against all metadata from the metabolic network
#
# 2025-09-13 12:45:34,855 - metanetmap.mapping - INFO - --"Glucopyranose" is present in ['toys1'] metabolic network with the corresponding ID "Glucopyranose" via the match ID "glucopyranose"
# 2025-09-13 12:45:34,873 - metanetmap.mapping - INFO - --"Glucopyranose" is present in ['toys3'] metabolic network with the corresponding ID "glc__D" via the match ID "glc__d"
# 2025-09-13 12:45:34,885 - metanetmap.mapping - INFO - --"Glucopyranose" is present in ['toys1'] metabolic network with the corresponding ID "Glucopyranose" via the match ID "Glucopyranose"
# 2025-09-13 12:45:34,885 - metanetmap.mapping - INFO - --"ADENINE" is present in ['toys1'] metabolic network with the corresponding ID "ADENINE" via the match ID "adenine"
# 2025-09-13 12:45:34,886 - metanetmap.mapping - INFO - --"ADENINE" is present in ['toys1'] metabolic network with the corresponding ID "ADENINE" via the match ID "adenine"
# 2025-09-13 12:45:34,898 - metanetmap.mapping - INFO - --"ADENINE" is present in ['toys3'] metabolic network with the corresponding ID "ade" via the match ID "ade"
# 2025-09-13 12:45:34,900 - metanetmap.mapping - INFO - --"ADENINE" is present in ['toys1'] metabolic network with the corresponding ID "ADENINE" via the match ID "adenine"
# 2025-09-13 12:45:34,914 - metanetmap.mapping - INFO - --"ADENINE" is present in ['toys1'] metabolic network with the corresponding ID "ADENINE" via the match ID "ADENINE"
# 2025-09-13 12:45:34,914 - metanetmap.mapping - INFO - --"L-methionine" is present in ['toys1', 'toys2'] metabolic network with the corresponding ID "MET" via the match ID "met"
# 2025-09-13 12:45:34,915 - metanetmap.mapping - INFO - --"L-methionine" is present in ['toys1', 'toys2'] metabolic network with the corresponding ID "MET" via the match ID "met"
# 2025-09-13 12:45:34,921 - metanetmap.mapping - INFO - --"L-methionine" is present in ['toys1', 'toys2'] metabolic network with the corresponding ID "MET" via the match ID "met"
# 2025-09-13 12:45:34,921 - metanetmap.mapping - INFO - --"L-methionine" is present in ['toys1', 'toys2'] metabolic network with the corresponding ID "MET" via the match ID "met"
# 2025-09-13 12:45:34,934 - metanetmap.mapping - INFO - --"L-methionine" is present in ['toys3'] metabolic network with the corresponding ID "met__L" via the match ID "met__l"
# 2025-09-13 12:45:34,935 - metanetmap.mapping - INFO - --"L-methionine" is present in ['toys3'] metabolic network with the corresponding ID "met__L" via the match ID "met__l"
# 2025-09-13 12:45:34,963 - metanetmap.mapping - INFO - --"ADENINE" is present in ['toys1'] metabolic network with the corresponding ID "ADENINE" via the match ID "adenine"
# 2025-09-13 12:45:34,965 - metanetmap.mapping - INFO - --"ADENINE" is present in ['toys1'] metabolic network with the corresponding ID "ADENINE" via the match ID "adenine"
# 2025-09-13 12:45:34,977 - metanetmap.mapping - INFO - --"ADENINE" is present in ['toys3'] metabolic network with the corresponding ID "ade" via the match ID "ade"
# 2025-09-13 12:45:34,979 - metanetmap.mapping - INFO - --"ADENINE" is present in ['toys1'] metabolic network with the corresponding ID "ADENINE" via the match ID "adenine"
# 2025-09-13 12:45:34,993 - metanetmap.mapping - INFO - --"ADENINE" is present in ['toys1'] metabolic network with the corresponding ID "ADENINE" via the match ID "ADENINE"
# 2025-09-13 12:45:35,021 - metanetmap.mapping - INFO - --"Beta-D-galactosyl-(1->3)-N-acetyl-beta-D-glucosaminyl-R" is present in ['toys1', 'toys2'] metabolic network with the corresponding ID "Gal-13-GlcN-R" via the match ID "gal-13-glcn-r"
# 2025-09-13 12:45:35,036 - metanetmap.mapping - INFO - --"8-O-methylfusarubin alcohol" is present in ['toys2'] metabolic network with the corresponding ID "CPD-18186" via the match ID "cpd-18186"
# 2025-09-13 12:45:35,072 - metanetmap.mapping - INFO - --"orotic acid" is present in ['toys2'] metabolic network with the corresponding ID "orot" via the match ID "orotate"
# 2025-09-13 12:45:35,079 - metanetmap.mapping - INFO - --"orotic acid" is present in ['toys2'] metabolic network with the corresponding ID "orot" via the match ID "orotate"
# 2025-09-13 12:45:35,101 - metanetmap.mapping - INFO - --"orotic acid" is present in ['toys3'] metabolic network with the corresponding ID "orot" via the match ID "orot"
# 2025-09-13 12:45:35,174 - metanetmap.mapping - INFO - --"pantothenic acid" is present in ['toys2'] metabolic network with the corresponding ID "pnto__R" via the match ID "pantothenate"
# 2025-09-13 12:45:35,201 - metanetmap.mapping - INFO - --"pantothenic acid" is present in ['toys3'] metabolic network with the corresponding ID "pnto__R" via the match ID "pnto__r"
# 2025-09-13 12:45:35,322 - metanetmap.mapping - INFO - --"FRU1P" is present in ['toys3'] metabolic network with the corresponding ID "f1p" via the match ID "f1p"
# 2025-09-13 12:45:35,371 - metanetmap.mapping - INFO - --"CPD-15970" is present in ['toys3'] metabolic network with the corresponding ID "f1p" via the match ID "f1p"
# 2025-09-13 12:45:35,396 - metanetmap.mapping - INFO - --"InChIKey=CGBYBGVMDAPUIH-ARJAWSKDSA-L" is present in ['toys1'] metabolic network with the corresponding ID "DIMETHYLMAL-CPD" via the match ID "dimethylmal-cpd"
# 2025-09-13 12:45:35,450 - metanetmap.mapping - INFO - --"CCCC(=O)OCC(/C=C=C1([C@](C)(O)C[C@@H](OC(=O)C)CC(C)(C)1))=C/C=C/C(\C)=C/C=C/C=C(C)/C=C/C=C(C)/C(=O)C[C@]23(C(C)(C)C[C@H](O)C[C@@](C)(O2)3)" is present in ['toys2'] metabolic network with the corresponding ID "CPD-26454" via the match ID "cpd-26454"
# 2025-09-13 12:45:35,477 - metanetmap.mapping - INFO -
#
# ------------------------------------------------
# 2025-09-13 12:45:35,477 - metanetmap.mapping - INFO - ---------------PARTIAL MATCH -------------------
# 2025-09-13 12:45:35,477 - metanetmap.mapping - INFO - ----------------------------------------------
#
# 2025-09-13 12:45:35,477 - metanetmap.mapping - INFO - <4> Attempting to find new IDs for unmatched metabolites using multiple strategies: removing enantiomer specificity, using the core part of InChIKeys, or exploring parent/child relationships in CHEBI.
#
# 2025-09-13 12:45:35,479 - metanetmap.mapping - INFO -
# -----> CHEBI <-----
# 2025-09-13 12:45:35,484 - metanetmap.mapping - INFO -
#  ++CHEBI identification step for CHEBI:90488:
# 2025-09-13 12:45:37,018 - metanetmap.mapping - INFO - --CHEBI:90488 is phosphatidylinositol (18:1/20:4)
# 2025-09-13 12:45:38,878 - metanetmap.mapping - INFO -    --Parents are :
# 2025-09-13 12:45:38,878 - metanetmap.mapping - INFO -      -- CHEBI:90488 is related to 1-phosphatidyl-1D-myo-inositol
# 2025-09-13 12:45:38,878 - metanetmap.mapping - INFO -
#  ++CHEBI identification step for CHEBI:15756:
# 2025-09-13 12:45:40,477 - metanetmap.mapping - INFO - --CHEBI:15756 is hexadecanoic acid
# 2025-09-13 12:45:44,104 - metanetmap.mapping - INFO -    --Parents are :
# 2025-09-13 12:45:44,104 - metanetmap.mapping - INFO -      -- CHEBI:15756 is related to long-chain fatty acid
# 2025-09-13 12:45:44,104 - metanetmap.mapping - INFO -      -- CHEBI:15756 is related to straight-chain saturated fatty acid
# 2025-09-13 12:45:44,104 - metanetmap.mapping - INFO -    --Children are :
# 2025-09-13 12:45:44,104 - metanetmap.mapping - INFO -      -- CHEBI:15756 is related to 1-hexadecanoyl-2-methyl-sn-glycero-3-phosphocholine
# 2025-09-13 12:45:44,104 - metanetmap.mapping - INFO -
#  ++CHEBI identification step for CHEBI:36023:
# 2025-09-13 12:45:45,418 - metanetmap.mapping - INFO - --CHEBI:36023 is vaccenic acid
# 2025-09-13 12:45:49,911 - metanetmap.mapping - INFO -    --Parents are :
# 2025-09-13 12:45:49,912 - metanetmap.mapping - INFO -      -- CHEBI:vaccenic is related to octadecenoic acid
# 2025-09-13 12:45:49,912 - metanetmap.mapping - INFO -      -- CHEBI:vaccenic is related to straight-chain fatty acid
# 2025-09-13 12:45:49,912 - metanetmap.mapping - INFO -    --Children are :
# 2025-09-13 12:45:49,912 - metanetmap.mapping - INFO -      -- CHEBI:vaccenic is related to trans-vaccenic acid
# 2025-09-13 12:45:49,912 - metanetmap.mapping - INFO -      -- CHEBI:vaccenic is related to cis-vaccenic acid
# 2025-09-13 12:45:49,912 - metanetmap.mapping - INFO -
#  ++CHEBI identification step for CHEBI:36023:
# 2025-09-13 12:45:51,254 - metanetmap.mapping - INFO - --CHEBI:36023 is vaccenic acid
# 2025-09-13 12:45:55,626 - metanetmap.mapping - INFO -    --Parents are :
# 2025-09-13 12:45:55,627 - metanetmap.mapping - INFO -      -- CHEBI:36023 is related to octadecenoic acid
# 2025-09-13 12:45:55,627 - metanetmap.mapping - INFO -      -- CHEBI:36023 is related to straight-chain fatty acid
# 2025-09-13 12:45:55,627 - metanetmap.mapping - INFO -    --Children are :
# 2025-09-13 12:45:55,627 - metanetmap.mapping - INFO -      -- CHEBI:36023 is related to trans-vaccenic acid
# 2025-09-13 12:45:55,627 - metanetmap.mapping - INFO -      -- CHEBI:36023 is related to cis-vaccenic acid
# 2025-09-13 12:45:55,627 - metanetmap.mapping - INFO -
# -----> Inchey <-----
# 2025-09-13 12:45:55,627 - metanetmap.mapping - INFO - Inchey: {key} -> Short Inchey: {value}
# 2025-09-13 12:45:55,627 - metanetmap.mapping - INFO - Inchey: {key} -> Short Inchey: {value}
# 2025-09-13 12:45:55,627 - metanetmap.mapping - INFO -
# -----> Enantiomers <-----
# 2025-09-13 12:45:55,627 - metanetmap.mapping - INFO - -----> Remove enantiomers in database and in metadata of sbml <-----
# 2025-09-13 12:45:55,711 - metanetmap.mapping - INFO -
#
# ----------------------------------------------------
# 2025-09-13 12:45:55,711 - metanetmap.mapping - INFO - ---------------Retry MATCH STEP 1-------------------
# 2025-09-13 12:45:55,711 - metanetmap.mapping - INFO - ----------------------------------------------------
# 2025-09-13 12:45:55,711 - metanetmap.mapping - INFO -
# -----> Test: CHEBI <-----
# 2025-09-13 12:45:55,711 - metanetmap.mapping - INFO -
# ++ Match step for "90488":
# 2025-09-13 12:45:55,711 - metanetmap.mapping - INFO -
# --Try with phosphatidylinositol (18:1/20:4)":
# 2025-09-13 12:45:55,716 - metanetmap.mapping - INFO -
# --Try with 16749":
# 2025-09-13 12:45:55,720 - metanetmap.mapping - INFO -
# --Try with 1-phosphatidyl-1D-myo-inositol":
# 2025-09-13 12:45:55,724 - metanetmap.mapping - INFO -
# ++ Match step for "15756":
# 2025-09-13 12:45:55,724 - metanetmap.mapping - INFO -
# --Try with hexadecanoic acid":
# 2025-09-13 12:45:55,727 - metanetmap.mapping - INFO - --"15756" is present in database with the UNIQUE-ID "PALMITATE" and matches via "CHEBI"
# 2025-09-13 12:45:55,727 - metanetmap.mapping - INFO -
# --Try with 15904":
# 2025-09-13 12:45:55,730 - metanetmap.mapping - INFO - --"15756" has a partial match. We have several UNIQUE-ID identifiers for this metabolite: "PALMITATE" and "Long-Chain-Fatty-Acids"
# 2025-09-13 12:45:55,730 - metanetmap.mapping - INFO -
# --Try with long-chain fatty acid":
# 2025-09-13 12:45:55,734 - metanetmap.mapping - INFO -
# --Try with 39418":
# 2025-09-13 12:45:55,737 - metanetmap.mapping - INFO -       --"15756" has a partial match. A match was found with the ID: "39418" via: CHEBI
# 2025-09-13 12:45:55,737 - metanetmap.mapping - INFO -
# --Try with straight-chain saturated fatty acid":
# 2025-09-13 12:45:55,741 - metanetmap.mapping - INFO -
# --Try with 131689":
# 2025-09-13 12:45:55,743 - metanetmap.mapping - INFO -       --"15756" has a partial match. A match was found with the ID: "131689" via: CHEBI
# 2025-09-13 12:45:55,743 - metanetmap.mapping - INFO -
# --Try with 1-hexadecanoyl-2-methyl-sn-glycero-3-phosphocholine":
# 2025-09-13 12:45:55,747 - metanetmap.mapping - INFO -
# ++ Match step for "vaccenic":
# 2025-09-13 12:45:55,747 - metanetmap.mapping - INFO -
# --Try with vaccenic acid":
# 2025-09-13 12:45:55,751 - metanetmap.mapping - INFO - --"vaccenic" is present in database with the UNIQUE-ID "Vaccenate" and matches via "CHEBI"
# 2025-09-13 12:45:55,751 - metanetmap.mapping - INFO -
# --Try with 25634":
# 2025-09-13 12:45:55,755 - metanetmap.mapping - INFO -
# --Try with octadecenoic acid":
# 2025-09-13 12:45:55,759 - metanetmap.mapping - INFO -
# --Try with 59202":
# 2025-09-13 12:45:55,762 - metanetmap.mapping - INFO -
# --Try with straight-chain fatty acid":
# 2025-09-13 12:45:55,766 - metanetmap.mapping - INFO -
# --Try with 28727":
# 2025-09-13 12:45:55,770 - metanetmap.mapping - INFO -
# --Try with trans-vaccenic acid":
# 2025-09-13 12:45:55,774 - metanetmap.mapping - INFO - --"vaccenic" has a partial match. We have several UNIQUE-ID identifiers for this metabolite: "Vaccenate" and "CPD-17257"
# 2025-09-13 12:45:55,774 - metanetmap.mapping - INFO -
# --Try with 50464":
# 2025-09-13 12:45:55,777 - metanetmap.mapping - INFO -
# --Try with cis-vaccenic acid":
# 2025-09-13 12:45:55,781 - metanetmap.mapping - INFO - --"vaccenic" has a partial match. We have several UNIQUE-ID identifiers for this metabolite: "Vaccenate _AND_ CPD-17257" and "CPD-9247"
# 2025-09-13 12:45:55,781 - metanetmap.mapping - INFO -
# ++ Match step for "36023":
# 2025-09-13 12:45:55,781 - metanetmap.mapping - INFO -
# --Try with vaccenic acid":
# 2025-09-13 12:45:55,784 - metanetmap.mapping - INFO - --"36023" is a metabolite duplicate of "vaccenic" and matches via "CHEBI"
# 2025-09-13 12:45:55,785 - metanetmap.mapping - INFO - --"36023" is a metabolite duplicate of "vaccenic _AND_ 36023" and matches via "CHEBI"
# 2025-09-13 12:45:55,785 - metanetmap.mapping - INFO - --"36023" is a metabolite duplicate of "vaccenic _AND_ 36023 _AND_ 36023" and matches via "CHEBI"
# 2025-09-13 12:45:55,785 - metanetmap.mapping - INFO -
# --Try with 25634":
# 2025-09-13 12:45:55,788 - metanetmap.mapping - INFO -
# --Try with octadecenoic acid":
# 2025-09-13 12:45:55,792 - metanetmap.mapping - INFO -
# --Try with 59202":
# 2025-09-13 12:45:55,795 - metanetmap.mapping - INFO -
# --Try with straight-chain fatty acid":
# 2025-09-13 12:45:55,799 - metanetmap.mapping - INFO -
# --Try with 28727":
# 2025-09-13 12:45:55,803 - metanetmap.mapping - INFO -
# --Try with trans-vaccenic acid":
# 2025-09-13 12:45:55,807 - metanetmap.mapping - INFO -
# --Try with 50464":
# 2025-09-13 12:45:55,810 - metanetmap.mapping - INFO -
# --Try with cis-vaccenic acid":
# 2025-09-13 12:45:55,814 - metanetmap.mapping - INFO - --"36023" is a metabolite duplicate of "vaccenic _AND_ 36023 _AND_ 36023 _AND_ 36023" and matches via "CHEBI"
# 2025-09-13 12:45:55,814 - metanetmap.mapping - INFO - --"36023" is a metabolite duplicate of "vaccenic _AND_ 36023 _AND_ 36023 _AND_ 36023 _AND_ 36023" and matches via "CHEBI"
# 2025-09-13 12:45:55,814 - metanetmap.mapping - INFO - --"36023" is a metabolite duplicate of "vaccenic _AND_ 36023 _AND_ 36023 _AND_ 36023 _AND_ 36023 _AND_ 36023" and matches via "CHEBI"
# 2025-09-13 12:45:55,814 - metanetmap.mapping - INFO -
# -----> Test: Inchey <-----
# 2025-09-13 12:45:55,814 - metanetmap.mapping - INFO -
# ++ Match step for "InChIKey=AVVWPBAENSWJCB":
# 2025-09-13 12:45:55,814 - metanetmap.mapping - INFO -
# --Try with InChIKey=AVVWPBAENSWJCB-VSOTGSRCSA-C":
# 2025-09-13 12:45:55,818 - metanetmap.mapping - INFO - --"InChIKey=AVVWPBAENSWJCB-VSOTGSRCSA-C" is present in database with the UNIQUE-ID "CPD-24978" and matches via "Inchey"
# 2025-09-13 12:45:55,818 - metanetmap.mapping - INFO - --"InChIKey=AVVWPBAENSWJCB-VSOTGSRCSA-C" has a partial match. We have several UNIQUE-ID identifiers for this metabolite: "CPD-24978" and "CPD-25014"
# 2025-09-13 12:45:55,818 - metanetmap.mapping - INFO - --"InChIKey=AVVWPBAENSWJCB-VSOTGSRCSA-C" has a partial match. We have several UNIQUE-ID identifiers for this metabolite: "CPD-24978 _AND_ CPD-25014" and "CPD-25010"
# 2025-09-13 12:45:55,818 - metanetmap.mapping - INFO - --"InChIKey=AVVWPBAENSWJCB-VSOTGSRCSA-C" has a partial match. We have several UNIQUE-ID identifiers for this metabolite: "CPD-24978 _AND_ CPD-25014 _AND_ CPD-25010" and "CPD-16933"
# 2025-09-13 12:45:55,818 - metanetmap.mapping - INFO - --"InChIKey=AVVWPBAENSWJCB-VSOTGSRCSA-C" has a partial match. We have several UNIQUE-ID identifiers for this metabolite: "CPD-24978 _AND_ CPD-25014 _AND_ CPD-25010 _AND_ CPD-16933" and "CPD-24986"
# 2025-09-13 12:45:55,818 - metanetmap.mapping - INFO - --"InChIKey=AVVWPBAENSWJCB-VSOTGSRCSA-C" has a partial match. We have several UNIQUE-ID identifiers for this metabolite: "CPD-24978 _AND_ CPD-25014 _AND_ CPD-25010 _AND_ CPD-16933 _AND_ CPD-24986" and "CPD-24992"
# 2025-09-13 12:45:55,818 - metanetmap.mapping - INFO - --"InChIKey=AVVWPBAENSWJCB-VSOTGSRCSA-C" has a partial match. We have several UNIQUE-ID identifiers for this metabolite: "CPD-24978 _AND_ CPD-25014 _AND_ CPD-25010 _AND_ CPD-16933 _AND_ CPD-24986 _AND_ CPD-24992" and "CPD-25011"
# 2025-09-13 12:45:55,818 - metanetmap.mapping - INFO - --"InChIKey=AVVWPBAENSWJCB-VSOTGSRCSA-C" has a partial match. We have several UNIQUE-ID identifiers for this metabolite: "CPD-24978 _AND_ CPD-25014 _AND_ CPD-25010 _AND_ CPD-16933 _AND_ CPD-24986 _AND_ CPD-24992 _AND_ CPD-25011" and "CPD-25008"
# 2025-09-13 12:45:55,818 - metanetmap.mapping - INFO - --"InChIKey=AVVWPBAENSWJCB-VSOTGSRCSA-C" has a partial match. We have several UNIQUE-ID identifiers for this metabolite: "CPD-24978 _AND_ CPD-25014 _AND_ CPD-25010 _AND_ CPD-16933 _AND_ CPD-24986 _AND_ CPD-24992 _AND_ CPD-25011 _AND_ CPD-25008" and "CPD-25020"
# 2025-09-13 12:45:55,818 - metanetmap.mapping - INFO - --"InChIKey=AVVWPBAENSWJCB-VSOTGSRCSA-C" has a partial match. We have several UNIQUE-ID identifiers for this metabolite: "CPD-24978 _AND_ CPD-25014 _AND_ CPD-25010 _AND_ CPD-16933 _AND_ CPD-24986 _AND_ CPD-24992 _AND_ CPD-25011 _AND_ CPD-25008 _AND_ CPD-25020" and "CPD-24979"
# 2025-09-13 12:45:55,818 - metanetmap.mapping - INFO - --"InChIKey=AVVWPBAENSWJCB-VSOTGSRCSA-C" has a partial match. We have several UNIQUE-ID identifiers for this metabolite: "CPD-24978 _AND_ CPD-25014 _AND_ CPD-25010 _AND_ CPD-16933 _AND_ CPD-24986 _AND_ CPD-24992 _AND_ CPD-25011 _AND_ CPD-25008 _AND_ CPD-25020 _AND_ CPD-24979" and "CPD-24991"
# 2025-09-13 12:45:55,818 - metanetmap.mapping - INFO - --"InChIKey=AVVWPBAENSWJCB-VSOTGSRCSA-C" has a partial match. We have several UNIQUE-ID identifiers for this metabolite: "CPD-24978 _AND_ CPD-25014 _AND_ CPD-25010 _AND_ CPD-16933 _AND_ CPD-24986 _AND_ CPD-24992 _AND_ CPD-25011 _AND_ CPD-25008 _AND_ CPD-25020 _AND_ CPD-24979 _AND_ CPD-24991" and "CPD-24984"
# 2025-09-13 12:45:55,818 - metanetmap.mapping - INFO - --"InChIKey=AVVWPBAENSWJCB-VSOTGSRCSA-C" has a partial match. We have several UNIQUE-ID identifiers for this metabolite: "CPD-24978 _AND_ CPD-25014 _AND_ CPD-25010 _AND_ CPD-16933 _AND_ CPD-24986 _AND_ CPD-24992 _AND_ CPD-25011 _AND_ CPD-25008 _AND_ CPD-25020 _AND_ CPD-24979 _AND_ CPD-24991 _AND_ CPD-24984" and "CPD-24997"
# 2025-09-13 12:45:55,818 - metanetmap.mapping - INFO - --"InChIKey=AVVWPBAENSWJCB-VSOTGSRCSA-C" has a partial match. We have several UNIQUE-ID identifiers for this metabolite: "CPD-24978 _AND_ CPD-25014 _AND_ CPD-25010 _AND_ CPD-16933 _AND_ CPD-24986 _AND_ CPD-24992 _AND_ CPD-25011 _AND_ CPD-25008 _AND_ CPD-25020 _AND_ CPD-24979 _AND_ CPD-24991 _AND_ CPD-24984 _AND_ CPD-24997" and "CPD-25015"
# 2025-09-13 12:45:55,818 - metanetmap.mapping - INFO - --"InChIKey=AVVWPBAENSWJCB-VSOTGSRCSA-C" has a partial match. We have several UNIQUE-ID identifiers for this metabolite: "CPD-24978 _AND_ CPD-25014 _AND_ CPD-25010 _AND_ CPD-16933 _AND_ CPD-24986 _AND_ CPD-24992 _AND_ CPD-25011 _AND_ CPD-25008 _AND_ CPD-25020 _AND_ CPD-24979 _AND_ CPD-24991 _AND_ CPD-24984 _AND_ CPD-24997 _AND_ CPD-25015" and "CPD-25019"
# 2025-09-13 12:45:55,818 - metanetmap.mapping - INFO - --"InChIKey=AVVWPBAENSWJCB-VSOTGSRCSA-C" has a partial match. We have several UNIQUE-ID identifiers for this metabolite: "CPD-24978 _AND_ CPD-25014 _AND_ CPD-25010 _AND_ CPD-16933 _AND_ CPD-24986 _AND_ CPD-24992 _AND_ CPD-25011 _AND_ CPD-25008 _AND_ CPD-25020 _AND_ CPD-24979 _AND_ CPD-24991 _AND_ CPD-24984 _AND_ CPD-24997 _AND_ CPD-25015 _AND_ CPD-25019" and "CPD0-2486"
# 2025-09-13 12:45:55,818 - metanetmap.mapping - INFO - --"InChIKey=AVVWPBAENSWJCB-VSOTGSRCSA-C" has a partial match. We have several UNIQUE-ID identifiers for this metabolite: "CPD-24978 _AND_ CPD-25014 _AND_ CPD-25010 _AND_ CPD-16933 _AND_ CPD-24986 _AND_ CPD-24992 _AND_ CPD-25011 _AND_ CPD-25008 _AND_ CPD-25020 _AND_ CPD-24979 _AND_ CPD-24991 _AND_ CPD-24984 _AND_ CPD-24997 _AND_ CPD-25015 _AND_ CPD-25019 _AND_ CPD0-2486" and "CPD-25006"
# 2025-09-13 12:45:55,818 - metanetmap.mapping - INFO - --"InChIKey=AVVWPBAENSWJCB-VSOTGSRCSA-C" has a partial match. We have several UNIQUE-ID identifiers for this metabolite: "CPD-24978 _AND_ CPD-25014 _AND_ CPD-25010 _AND_ CPD-16933 _AND_ CPD-24986 _AND_ CPD-24992 _AND_ CPD-25011 _AND_ CPD-25008 _AND_ CPD-25020 _AND_ CPD-24979 _AND_ CPD-24991 _AND_ CPD-24984 _AND_ CPD-24997 _AND_ CPD-25015 _AND_ CPD-25019 _AND_ CPD0-2486 _AND_ CPD-25006" and "CPD-16934"
# 2025-09-13 12:45:55,818 - metanetmap.mapping - INFO - --"InChIKey=AVVWPBAENSWJCB-VSOTGSRCSA-C" has a partial match. We have several UNIQUE-ID identifiers for this metabolite: "CPD-24978 _AND_ CPD-25014 _AND_ CPD-25010 _AND_ CPD-16933 _AND_ CPD-24986 _AND_ CPD-24992 _AND_ CPD-25011 _AND_ CPD-25008 _AND_ CPD-25020 _AND_ CPD-24979 _AND_ CPD-24991 _AND_ CPD-24984 _AND_ CPD-24997 _AND_ CPD-25015 _AND_ CPD-25019 _AND_ CPD0-2486 _AND_ CPD-25006 _AND_ CPD-16934" and "CPD-24952"
# 2025-09-13 12:45:55,818 - metanetmap.mapping - INFO - --"InChIKey=AVVWPBAENSWJCB-VSOTGSRCSA-C" has a partial match. We have several UNIQUE-ID identifiers for this metabolite: "CPD-24978 _AND_ CPD-25014 _AND_ CPD-25010 _AND_ CPD-16933 _AND_ CPD-24986 _AND_ CPD-24992 _AND_ CPD-25011 _AND_ CPD-25008 _AND_ CPD-25020 _AND_ CPD-24979 _AND_ CPD-24991 _AND_ CPD-24984 _AND_ CPD-24997 _AND_ CPD-25015 _AND_ CPD-25019 _AND_ CPD0-2486 _AND_ CPD-25006 _AND_ CPD-16934 _AND_ CPD-24952" and "CPD-25013"
# 2025-09-13 12:45:55,818 - metanetmap.mapping - INFO - --"InChIKey=AVVWPBAENSWJCB-VSOTGSRCSA-C" has a partial match. We have several UNIQUE-ID identifiers for this metabolite: "CPD-24978 _AND_ CPD-25014 _AND_ CPD-25010 _AND_ CPD-16933 _AND_ CPD-24986 _AND_ CPD-24992 _AND_ CPD-25011 _AND_ CPD-25008 _AND_ CPD-25020 _AND_ CPD-24979 _AND_ CPD-24991 _AND_ CPD-24984 _AND_ CPD-24997 _AND_ CPD-25015 _AND_ CPD-25019 _AND_ CPD0-2486 _AND_ CPD-25006 _AND_ CPD-16934 _AND_ CPD-24952 _AND_ CPD-25013" and "CPD-24951"
# 2025-09-13 12:45:55,819 - metanetmap.mapping - INFO - --"InChIKey=AVVWPBAENSWJCB-VSOTGSRCSA-C" has a partial match. We have several UNIQUE-ID identifiers for this metabolite: "CPD-24978 _AND_ CPD-25014 _AND_ CPD-25010 _AND_ CPD-16933 _AND_ CPD-24986 _AND_ CPD-24992 _AND_ CPD-25011 _AND_ CPD-25008 _AND_ CPD-25020 _AND_ CPD-24979 _AND_ CPD-24991 _AND_ CPD-24984 _AND_ CPD-24997 _AND_ CPD-25015 _AND_ CPD-25019 _AND_ CPD0-2486 _AND_ CPD-25006 _AND_ CPD-16934 _AND_ CPD-24952 _AND_ CPD-25013 _AND_ CPD-24951" and "CPD-25012"
# 2025-09-13 12:45:55,819 - metanetmap.mapping - INFO - --"InChIKey=AVVWPBAENSWJCB-VSOTGSRCSA-C" has a partial match. We have several UNIQUE-ID identifiers for this metabolite: "CPD-24978 _AND_ CPD-25014 _AND_ CPD-25010 _AND_ CPD-16933 _AND_ CPD-24986 _AND_ CPD-24992 _AND_ CPD-25011 _AND_ CPD-25008 _AND_ CPD-25020 _AND_ CPD-24979 _AND_ CPD-24991 _AND_ CPD-24984 _AND_ CPD-24997 _AND_ CPD-25015 _AND_ CPD-25019 _AND_ CPD0-2486 _AND_ CPD-25006 _AND_ CPD-16934 _AND_ CPD-24952 _AND_ CPD-25013 _AND_ CPD-24951 _AND_ CPD-25012" and "CPD0-2485"
# 2025-09-13 12:45:55,819 - metanetmap.mapping - INFO - --"InChIKey=AVVWPBAENSWJCB-VSOTGSRCSA-C" has a partial match. We have several UNIQUE-ID identifiers for this metabolite: "CPD-24978 _AND_ CPD-25014 _AND_ CPD-25010 _AND_ CPD-16933 _AND_ CPD-24986 _AND_ CPD-24992 _AND_ CPD-25011 _AND_ CPD-25008 _AND_ CPD-25020 _AND_ CPD-24979 _AND_ CPD-24991 _AND_ CPD-24984 _AND_ CPD-24997 _AND_ CPD-25015 _AND_ CPD-25019 _AND_ CPD0-2486 _AND_ CPD-25006 _AND_ CPD-16934 _AND_ CPD-24952 _AND_ CPD-25013 _AND_ CPD-24951 _AND_ CPD-25012 _AND_ CPD0-2485" and "CPD-24996"
# 2025-09-13 12:45:55,819 - metanetmap.mapping - INFO - --"InChIKey=AVVWPBAENSWJCB-VSOTGSRCSA-C" has a partial match. We have several UNIQUE-ID identifiers for this metabolite: "CPD-24978 _AND_ CPD-25014 _AND_ CPD-25010 _AND_ CPD-16933 _AND_ CPD-24986 _AND_ CPD-24992 _AND_ CPD-25011 _AND_ CPD-25008 _AND_ CPD-25020 _AND_ CPD-24979 _AND_ CPD-24991 _AND_ CPD-24984 _AND_ CPD-24997 _AND_ CPD-25015 _AND_ CPD-25019 _AND_ CPD0-2486 _AND_ CPD-25006 _AND_ CPD-16934 _AND_ CPD-24952 _AND_ CPD-25013 _AND_ CPD-24951 _AND_ CPD-25012 _AND_ CPD0-2485 _AND_ CPD-24996" and "CPD-24985"
# 2025-09-13 12:45:55,819 - metanetmap.mapping - INFO - --"InChIKey=AVVWPBAENSWJCB-VSOTGSRCSA-C" has a partial match. We have several UNIQUE-ID identifiers for this metabolite: "CPD-24978 _AND_ CPD-25014 _AND_ CPD-25010 _AND_ CPD-16933 _AND_ CPD-24986 _AND_ CPD-24992 _AND_ CPD-25011 _AND_ CPD-25008 _AND_ CPD-25020 _AND_ CPD-24979 _AND_ CPD-24991 _AND_ CPD-24984 _AND_ CPD-24997 _AND_ CPD-25015 _AND_ CPD-25019 _AND_ CPD0-2486 _AND_ CPD-25006 _AND_ CPD-16934 _AND_ CPD-24952 _AND_ CPD-25013 _AND_ CPD-24951 _AND_ CPD-25012 _AND_ CPD0-2485 _AND_ CPD-24996 _AND_ CPD-24985" and "CPD-24990"
# 2025-09-13 12:45:55,819 - metanetmap.mapping - INFO - --"InChIKey=AVVWPBAENSWJCB-VSOTGSRCSA-C" has a partial match. We have several UNIQUE-ID identifiers for this metabolite: "CPD-24978 _AND_ CPD-25014 _AND_ CPD-25010 _AND_ CPD-16933 _AND_ CPD-24986 _AND_ CPD-24992 _AND_ CPD-25011 _AND_ CPD-25008 _AND_ CPD-25020 _AND_ CPD-24979 _AND_ CPD-24991 _AND_ CPD-24984 _AND_ CPD-24997 _AND_ CPD-25015 _AND_ CPD-25019 _AND_ CPD0-2486 _AND_ CPD-25006 _AND_ CPD-16934 _AND_ CPD-24952 _AND_ CPD-25013 _AND_ CPD-24951 _AND_ CPD-25012 _AND_ CPD0-2485 _AND_ CPD-24996 _AND_ CPD-24985 _AND_ CPD-24990" and "CPD-24983"
# 2025-09-13 12:45:55,819 - metanetmap.mapping - INFO - --"InChIKey=AVVWPBAENSWJCB-VSOTGSRCSA-C" has a partial match. We have several UNIQUE-ID identifiers for this metabolite: "CPD-24978 _AND_ CPD-25014 _AND_ CPD-25010 _AND_ CPD-16933 _AND_ CPD-24986 _AND_ CPD-24992 _AND_ CPD-25011 _AND_ CPD-25008 _AND_ CPD-25020 _AND_ CPD-24979 _AND_ CPD-24991 _AND_ CPD-24984 _AND_ CPD-24997 _AND_ CPD-25015 _AND_ CPD-25019 _AND_ CPD0-2486 _AND_ CPD-25006 _AND_ CPD-16934 _AND_ CPD-24952 _AND_ CPD-25013 _AND_ CPD-24951 _AND_ CPD-25012 _AND_ CPD0-2485 _AND_ CPD-24996 _AND_ CPD-24985 _AND_ CPD-24990 _AND_ CPD-24983" and "CPD-25009"
# 2025-09-13 12:45:55,819 - metanetmap.mapping - INFO - --"InChIKey=AVVWPBAENSWJCB-VSOTGSRCSA-C" has a partial match. We have several UNIQUE-ID identifiers for this metabolite: "CPD-24978 _AND_ CPD-25014 _AND_ CPD-25010 _AND_ CPD-16933 _AND_ CPD-24986 _AND_ CPD-24992 _AND_ CPD-25011 _AND_ CPD-25008 _AND_ CPD-25020 _AND_ CPD-24979 _AND_ CPD-24991 _AND_ CPD-24984 _AND_ CPD-24997 _AND_ CPD-25015 _AND_ CPD-25019 _AND_ CPD0-2486 _AND_ CPD-25006 _AND_ CPD-16934 _AND_ CPD-24952 _AND_ CPD-25013 _AND_ CPD-24951 _AND_ CPD-25012 _AND_ CPD0-2485 _AND_ CPD-24996 _AND_ CPD-24985 _AND_ CPD-24990 _AND_ CPD-24983 _AND_ CPD-25009" and "CPD-24993"
# 2025-09-13 12:45:55,819 - metanetmap.mapping - INFO - --"InChIKey=AVVWPBAENSWJCB-VSOTGSRCSA-C" has a partial match. We have several UNIQUE-ID identifiers for this metabolite: "CPD-24978 _AND_ CPD-25014 _AND_ CPD-25010 _AND_ CPD-16933 _AND_ CPD-24986 _AND_ CPD-24992 _AND_ CPD-25011 _AND_ CPD-25008 _AND_ CPD-25020 _AND_ CPD-24979 _AND_ CPD-24991 _AND_ CPD-24984 _AND_ CPD-24997 _AND_ CPD-25015 _AND_ CPD-25019 _AND_ CPD0-2486 _AND_ CPD-25006 _AND_ CPD-16934 _AND_ CPD-24952 _AND_ CPD-25013 _AND_ CPD-24951 _AND_ CPD-25012 _AND_ CPD0-2485 _AND_ CPD-24996 _AND_ CPD-24985 _AND_ CPD-24990 _AND_ CPD-24983 _AND_ CPD-25009 _AND_ CPD-24993" and "CPD-25005"
# 2025-09-13 12:45:55,819 - metanetmap.mapping - INFO - --"InChIKey=AVVWPBAENSWJCB-VSOTGSRCSA-C" has a partial match. We have several UNIQUE-ID identifiers for this metabolite: "CPD-24978 _AND_ CPD-25014 _AND_ CPD-25010 _AND_ CPD-16933 _AND_ CPD-24986 _AND_ CPD-24992 _AND_ CPD-25011 _AND_ CPD-25008 _AND_ CPD-25020 _AND_ CPD-24979 _AND_ CPD-24991 _AND_ CPD-24984 _AND_ CPD-24997 _AND_ CPD-25015 _AND_ CPD-25019 _AND_ CPD0-2486 _AND_ CPD-25006 _AND_ CPD-16934 _AND_ CPD-24952 _AND_ CPD-25013 _AND_ CPD-24951 _AND_ CPD-25012 _AND_ CPD0-2485 _AND_ CPD-24996 _AND_ CPD-24985 _AND_ CPD-24990 _AND_ CPD-24983 _AND_ CPD-25009 _AND_ CPD-24993 _AND_ CPD-25005" and "CPD-25004"
# 2025-09-13 12:45:55,819 - metanetmap.mapping - INFO - --"InChIKey=AVVWPBAENSWJCB-VSOTGSRCSA-C" has a partial match. We have several UNIQUE-ID identifiers for this metabolite: "CPD-24978 _AND_ CPD-25014 _AND_ CPD-25010 _AND_ CPD-16933 _AND_ CPD-24986 _AND_ CPD-24992 _AND_ CPD-25011 _AND_ CPD-25008 _AND_ CPD-25020 _AND_ CPD-24979 _AND_ CPD-24991 _AND_ CPD-24984 _AND_ CPD-24997 _AND_ CPD-25015 _AND_ CPD-25019 _AND_ CPD0-2486 _AND_ CPD-25006 _AND_ CPD-16934 _AND_ CPD-24952 _AND_ CPD-25013 _AND_ CPD-24951 _AND_ CPD-25012 _AND_ CPD0-2485 _AND_ CPD-24996 _AND_ CPD-24985 _AND_ CPD-24990 _AND_ CPD-24983 _AND_ CPD-25009 _AND_ CPD-24993 _AND_ CPD-25005 _AND_ CPD-25004" and "CPD-25007"
# 2025-09-13 12:45:55,819 - metanetmap.mapping - INFO -
# ++ Match step for "InChIKey=FSCYHDCTAZZSKN":
# 2025-09-13 12:45:55,819 - metanetmap.mapping - INFO -
# --Try with InChIKey=FSCYHDCTAZZSKN-DJNGBR":
# 2025-09-13 12:45:55,823 - metanetmap.mapping - INFO -
# -----> Test: Enantiomers <-----
# 2025-09-13 12:45:55,823 - metanetmap.mapping - INFO -
# ++ Match step for "delphinidin 3-O-(4-coumaroyl-rhamnosyl-(1->6)-glucoside":
# 2025-09-13 12:45:55,827 - metanetmap.mapping - INFO - --"delphinidin 3-O-(4-coumaroyl-rhamnosyl-(1->6)-glucoside" is present in database with the UNIQUE-ID "CPD-22089" and matches via "Enantiomers"
# 2025-09-13 12:45:55,827 - metanetmap.mapping - INFO -
# ++ Match step for "thionine":
# 2025-09-13 12:45:55,830 - metanetmap.mapping - INFO -
# ++ Match step for "C(S)[C@@H](C(NCCC(=O)[O-])=O)NC(=O)CC[C@@H](C([O-])=O)NC(=O)[C@H](CS)NC(=O)CC[C@H]([NH3+])C([O-])":
# 2025-09-13 12:45:55,835 - metanetmap.mapping - INFO -
#
# ----------------------------------------------------
# 2025-09-13 12:45:55,835 - metanetmap.mapping - INFO - ---------------Retry MATCH STEP 2-------------------
# 2025-09-13 12:45:55,835 - metanetmap.mapping - INFO - ----------------------------------------------------
# 2025-09-13 12:45:58,096 - metanetmap.mapping - INFO -
# -------------------- SUMMARY REPORT --------------------
#
# 2025-09-13 12:45:58,096 - metanetmap.mapping - INFO -
# Recap of Matches:
# 2025-09-13 12:45:58,096 - metanetmap.mapping - INFO -   + Matched metabolites: 15
# 2025-09-13 12:45:58,096 - metanetmap.mapping - INFO -   + Unmatched metabolites: 9
# 2025-09-13 12:45:58,096 - metanetmap.mapping - INFO -   + Partial matches: 7
# 2025-09-13 12:45:58,097 - metanetmap.mapping - INFO -
#  Match Details:
# 2025-09-13 12:45:58,097 - metanetmap.mapping - INFO -   --> Full match (database + SBML): 13
# 2025-09-13 12:45:58,097 - metanetmap.mapping - INFO -   --> Partial match + metabolic info: 4
# 2025-09-13 12:45:58,097 - metanetmap.mapping - INFO -   --> Match only in SBML: 2
# 2025-09-13 12:45:58,097 - metanetmap.mapping - INFO -
#  Unmatch Details:
# 2025-09-13 12:45:58,097 - metanetmap.mapping - INFO -   --> Full unmatch (no match in DB or SBML): 4
# 2025-09-13 12:45:58,097 - metanetmap.mapping - INFO -   --> Match in DB but not in SBML: 5
# 2025-09-13 12:45:58,097 - metanetmap.mapping - INFO -   --> Partial match in DB only: 3
# 2025-09-13 12:45:58,097 - metanetmap.mapping - INFO -
# --------------------------------------------------------
#
# Output file successfully written to: mapping/community_partial/community_mapping_results_partial_match_2025-09-13_12:45:32.tsv
#
# --- Total runtime 25.39 seconds ---
#  ---> MAPPING COMPLETED'

# %%
''' Show Community mode with partial match 

'''
import os
import pandas as pd

# 1. Set the directory path
directory = 'mapping/community_partial/'

# 2. List all files in the directory
files = [f for f in os.listdir(directory) if os.path.isfile(os.path.join(directory, f))]

# 3. Check if exactly one file exists
if len(files) == 1:
    file_path = os.path.join(directory, files[0])
    print(f"Found file: {file_path}")
    
    # 4. Read the file (auto-detect TSV)
    if file_path.endswith('.tsv'):
        df = pd.read_csv(file_path, sep='\t')
    else:
        print("Unsupported file format.")
        df = None
    
    # 5. Display the table if loaded
    if df is not None:
        display(df)
else:
    print(f"Expected 1 file, found {len(files)}: {files}")
# Out:
# Found file: mapping/community_partial/community_mapping_results_partial_match_2025-09-13_12:45:32.tsv
#                                           Metabolites  \
# 0                      CPD-17381 _AND_ roquefortine C
# 1                               84783 _AND_ CPD-25370
# 2                                            C9H16NO5
# 3                                                4167
# 4                       L-methionine _AND_ methionine
# 5                                 16708 _AND_ Adenine
# 6   Beta-D-galactosyl-(1->3)-N-acetyl-beta-D-gluco...
# 7                         8-O-methylfusarubin alcohol
# 8                                         orotic acid
# 9                                  Carbamyl-phosphate
# 10                                   pantothenic acid
# 11                                              aprut
# 12                                                f1p
# 13                                            crnmock
# 14               InChIKey=CGBYBGVMDAPUIH-ARJAWSKDSA-L
# 15  CCCC(=O)OCC(/C=C=C1([C@](C)(O)C[C@@H](OC(=O)C)...
# 16                                              15756
# 17                               36023 _AND_ vaccenic
# 18               InChIKey=AVVWPBAENSWJCB-VSOTGSRCSA-C
# 19  delphinidin 3-O-(4-coumaroyl-rhamnosyl-(1->6)-...
# 20                                              90488
# 21  C(S)[C@@H](C(NCCC(=O)[O-])=O)NC(=O)CC[C@@H](C(...
# 22                     InChIKey=FSCYHDCTAZZSKN-DJNGBR
# 23                                           thionine
#
#                                     Match in database  \
# 0                                           CPD-17381
# 1                                           CPD-25370
# 2                                                 NaN
# 3                                       Glucopyranose
# 4                                                 MET
# 5                                             ADENINE
# 6       Gal-13-GlcN-R _AND_ beta-Gal-13-beta-GlcNac-R
# 7                                           CPD-18186
# 8                                             OROTATE
# 9                                         CARBAMOYL-P
# 10                                       PANTOTHENATE
# 11                                            CPD-569
# 12                              CPD-15970 _AND_ FRU1P
# 13                                                NaN
# 14                                    DIMETHYLMAL-CPD
# 15                                          CPD-26454
# 16             Long-Chain-Fatty-Acids _AND_ PALMITATE
# 17           CPD-17257 _AND_ CPD-9247 _AND_ Vaccenate
# 18  CPD-16933 _AND_ CPD-16934 _AND_ CPD-24951 _AND...
# 19                                          CPD-22089
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
#
#     Match in metabolic networks  \
# 0                           NaN
# 1                     ['toys1']
# 2                     ['toys3']
# 3            ['toys1', 'toys3']
# 4   ['toys1', 'toys2', 'toys3']
# 5            ['toys1', 'toys3']
# 6            ['toys1', 'toys2']
# 7                     ['toys2']
# 8            ['toys2', 'toys3']
# 9                     ['toys2']
# 10           ['toys2', 'toys3']
# 11                          NaN
# 12                    ['toys3']
# 13                    ['toys3']
# 14                    ['toys1']
# 15                    ['toys2']
# 16                    ['toys3']
# 17                          NaN
# 18                          NaN
# 19                          NaN
# 20                          NaN
# 21                          NaN
# 22                          NaN
# 23                          NaN
#
#                                         Partial match Match via UNIQUE-ID  \
# 0                                                 NaN                 YES
# 1                                                 NaN                 YES
# 2                                            C9H16NO5                 YES
# 3                                                 NaN                 NaN
# 4                                                 NaN                 NaN
# 5                                                 NaN                 NaN
# 6       Gal-13-GlcN-R _AND_ beta-Gal-13-beta-GlcNac-R                 NaN
# 7                                                 NaN                 NaN
# 8                                                 NaN                 NaN
# 9                                                 NaN                 NaN
# 10                                                NaN                 NaN
# 11                                                NaN                 NaN
# 12                              CPD-15970 _AND_ FRU1P                 NaN
# 13                                                NaN                 NaN
# 14                                                NaN                 NaN
# 15                                                NaN                 NaN
# 16  131689 _AND_ 39418 _AND_ Long-Chain-Fatty-Acid...                 NaN
# 17           CPD-17257 _AND_ CPD-9247 _AND_ Vaccenate                 NaN
# 18  CPD-16933 _AND_ CPD-16934 _AND_ CPD-24951 _AND...                 NaN
# 19                                          CPD-22089                 NaN
# 20                                                NaN                 NaN
# 21                                                NaN                 NaN
# 22                                                NaN                 NaN
# 23                                                NaN                 NaN
#
#    Match via CHEBI Match via COMMON-NAME  Match via ABBREV-NAME  \
# 0              NaN                   YES                    NaN
# 1              YES                   NaN                    NaN
# 2              NaN                   NaN                    NaN
# 3              YES                   NaN                    NaN
# 4              NaN                   YES                    NaN
# 5              NaN                   YES                    NaN
# 6              NaN                   YES                    NaN
# 7              NaN                   YES                    NaN
# 8              NaN                   NaN                    NaN
# 9              NaN                   NaN                    NaN
# 10             NaN                   NaN                    NaN
# 11             NaN                   NaN                    NaN
# 12             NaN                   NaN                    NaN
# 13             NaN                   NaN                    NaN
# 14             NaN                   NaN                    NaN
# 15             NaN                   NaN                    NaN
# 16             YES                   NaN                    NaN
# 17             YES                   NaN                    NaN
# 18             NaN                   NaN                    NaN
# 19             NaN                   NaN                    NaN
# 20             NaN                   NaN                    NaN
# 21             NaN                   NaN                    NaN
# 22             NaN                   NaN                    NaN
# 23             NaN                   NaN                    NaN
#
#    Match via SYNONYMS Match via ADD-COMPLEMENT  ...  Match via BIGG  \
# 0                 NaN                      NaN  ...             NaN
# 1                 NaN                      NaN  ...             NaN
# 2                 NaN                      NaN  ...             NaN
# 3                 NaN                      NaN  ...             NaN
# 4                 NaN                      NaN  ...             NaN
# 5                 NaN                      NaN  ...             NaN
# 6                 NaN                      NaN  ...             NaN
# 7                 NaN                      NaN  ...             NaN
# 8                 YES                      NaN  ...             NaN
# 9                 YES                      NaN  ...             NaN
# 10                NaN                      YES  ...             NaN
# 11                NaN                      NaN  ...             YES
# 12                NaN                      NaN  ...             YES
# 13                NaN                      NaN  ...             YES
# 14                NaN                      NaN  ...             NaN
# 15                NaN                      NaN  ...             NaN
# 16                NaN                      NaN  ...             NaN
# 17                NaN                      NaN  ...             NaN
# 18                NaN                      NaN  ...             NaN
# 19                NaN                      NaN  ...             NaN
# 20                NaN                      NaN  ...             NaN
# 21                NaN                      NaN  ...             NaN
# 22                NaN                      NaN  ...             NaN
# 23                NaN                      NaN  ...             NaN
#
#     Match via HMDB  Match via METANETX Match via LIGAND-CPD  Match via REFMET  \
# 0              NaN                 NaN                  NaN               NaN
# 1              NaN                 NaN                  NaN               NaN
# 2              NaN                 NaN                  NaN               NaN
# 3              NaN                 NaN                  NaN               NaN
# 4              NaN                 NaN                  NaN               NaN
# 5              NaN                 NaN                  NaN               NaN
# 6              NaN                 NaN                  NaN               NaN
# 7              NaN                 NaN                  NaN               NaN
# 8              NaN                 NaN                  NaN               NaN
# 9              NaN                 NaN                  NaN               NaN
# 10             NaN                 NaN                  NaN               NaN
# 11             NaN                 NaN                  NaN               NaN
# 12             NaN                 NaN                  NaN               NaN
# 13             NaN                 NaN                  NaN               NaN
# 14             NaN                 NaN                  NaN               NaN
# 15             NaN                 NaN                  NaN               NaN
# 16             NaN                 NaN                  NaN               NaN
# 17             NaN                 NaN                  NaN               NaN
# 18             NaN                 NaN                  NaN               NaN
# 19             NaN                 NaN                  NaN               NaN
# 20             NaN                 NaN                  NaN               NaN
# 21             NaN                 NaN                  NaN               NaN
# 22             NaN                 NaN                  NaN               NaN
# 23             NaN                 NaN                  NaN               NaN
#
#     Match via PUBCHEM  Match via CAS  Match via INCHI-KEY  Match via SMILES  \
# 0                 NaN            NaN                  NaN               NaN
# 1                 NaN            NaN                  NaN               NaN
# 2                 NaN            NaN                  NaN               NaN
# 3                 NaN            NaN                  NaN               NaN
# 4                 NaN            NaN                  NaN               NaN
# 5                 NaN            NaN                  NaN               NaN
# 6                 NaN            NaN                  NaN               NaN
# 7                 NaN            NaN                  NaN               NaN
# 8                 NaN            NaN                  NaN               NaN
# 9                 NaN            NaN                  NaN               NaN
# 10                NaN            NaN                  NaN               NaN
# 11                NaN            NaN                  NaN               NaN
# 12                NaN            NaN                  NaN               NaN
# 13                NaN            NaN                  NaN               NaN
# 14                NaN            NaN                  YES               NaN
# 15                NaN            NaN                  NaN               YES
# 16                NaN            NaN                  NaN               NaN
# 17                NaN            NaN                  NaN               NaN
# 18                NaN            NaN                  NaN               NaN
# 19                NaN            NaN                  NaN               NaN
# 20                NaN            NaN                  NaN               NaN
# 21                NaN            NaN                  NaN               NaN
# 22                NaN            NaN                  NaN               NaN
# 23                NaN            NaN                  NaN               NaN
#
#     Match via FORMULA
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
# 5                 NaN
# 6                 NaN
# 7                 NaN
# 8                 NaN
# 9                 NaN
# 10                NaN
# 11                NaN
# 12                NaN
# 13                NaN
# 14                NaN
# 15                NaN
# 16                NaN
# 17                NaN
# 18                NaN
# 19                NaN
# 20                NaN
# 21                NaN
# 22                NaN
# 23                NaN
#
# [24 rows x 23 columns]

# %% [markdown]
# ## LOG exemple:

# %%
import os

# 1. Set the directory path
directory = 'mapping/classic_partial/logs'

# 2. List all files in the directory
files = [f for f in os.listdir(directory) if os.path.isfile(os.path.join(directory, f))]

# 3. Check if exactly one file exists
if len(files) == 1:
    file_path = os.path.join(directory, files[0])
    print(f"Found log file: {file_path}\n")

    # 4. Read and print the content of the log file
    with open(file_path, 'r', encoding='utf-8') as f:
        content = f.read()
        print(content)
else:
    print(f"Expected 1 file, found {len(files)}: {files}")
# Out:
# Found log file: mapping/classic_partial/logs/mapping_2025-09-13_12:45:26.log
#
# -----------------------------------------
#             MAPPING METABOLITES
# -----------------------------------------
#
# ------> Main package version <------
# numpy version: 2.3.3
# pandas version: 2.3.2
# cobra version: 0.29.1
# libchebipy version: 1.0.10
#
# Command run:
# Actual command run (from sys.argv): python /home/cmuller/miniconda3/envs/metanetmap/bin/metanetmap classic -p -s ../src/metanetmap/toys_tests_data/toys/sbml/ -a ../src/metanetmap/toys_tests_data/toys/maf/toys2.tsv -d ../src/metanetmap/toys_tests_data/conversion_datatable_toys.tsv -o mapping/classic_partial/
#
#
#
# ---->    MODE CLASSIC    <----
#
# Load metabolomics data user path: ../src/metanetmap/toys_tests_data/toys/maf/toys2.tsv and metabolic networks user path: ../src/metanetmap/toys_tests_data/toys/sbml/
#
#
# ---------------PATHS-------------------
# List metabolomics data paths: ['../src/metanetmap/toys_tests_data/toys/maf/toys2.tsv']
# List metabolic networks paths: ['../src/metanetmap/toys_tests_data/toys/sbml/toys1.sbml', '../src/metanetmap/toys_tests_data/toys/sbml/toys3.xml', '../src/metanetmap/toys_tests_data/toys/sbml/toys2.sbml']
#
# Output file successfully written to: mapping/classic_partial/mapping_results_partial_match_2025-09-13_12:45:26.tsv
#
# --- Total runtime 2.19 seconds ---
#  ---> MAPPING COMPLETED'

# %% [markdown]
# ## Remove generated data
# To clean directly the repository of the notebook

# %%
''' Run Community mode with partial match
    The "community" mode allows you to input a directory containing multiple metabolomics data files, as well as a directory containing multiple metabolic networks.

'''

# !rm -r mapping/
