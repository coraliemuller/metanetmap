# %% [markdown]
# # Using MetaNetMap

# %% [markdown]
# `MetaNetMap <https://github.com/coraliemuller/metanetmap>`_ is a Python tool dedicated to mapping metabolite information between metabolomic data and metabolic networks.
# The goal is to facilitate the identification of metabolites from **metabolomic data** that are present in one or more **metabolic networks** to facilitate further modelling, taking into consideration that data from the former likely has distinct identifiers from the latter.
#
# .. image:: ./pictures/MetaNetMap_overview.png
#    :alt: General overview of MetaNetMap
#    :width: 100%
#
# While some metabolites can be matched directly using common identifiers, many require more sophisticated approaches. MetaNetMap implements such strategies to improve mapping rates, including optional partial matching techniques. The picture above summarises the mapping procedure implemented in MetaNetMap.
#
#
# ### **Why using this tool to map metabolomic data?**
#
#
# Mapping metabolomic data to metabolic networks is a challenging task for several reasons:
#
# - **Identifier variability in metabolic networks:**
#   Automatic reconstruction of metabolic networks using different tools and associated databases often assigns distinct identifiers to the same metabolites. It is likely that those do not match the nomenclature of metabolomic annotations. To reconcile them, a first solution is to rely on metadata extracted from metabolic networks associating molecules to alternative databases. Additionally, third-party external databases such as `MetaNetX <https://www.metanetx.org>`_ can be used, in order to provide more matching possibilities.
#
# - **Metabolomic data complexity:**
#   Due to the difficulty of annotating metabolomic profiles, identifications are often partial, incomplete, and inconsistently represented. For example, enantiomers are frequently not precisely specified because they are almost indistinguishable by classical LC/MS methods.
#
# While a few metabolites can be matched manually with limited effort, large-scale metabolomic datasets require automated tools to perform mapping efficiently and accurately. MetaNetMap addresses these challenges by providing a robust framework for mapping metabolomic data to metabolic networks, leveraging multiple strategies to maximize matching success. In practice, MetaNetMap can match one or several metabolomic annotation tables to one or several metabolic networks.
#
# ### **Third-party database for matching**
#
# In case metadata from metabolic network do not match identifiers of the metabolomic data, a ``conversion_datatable`` file acts as a bridge between the metabolomic data and the metabolic networks.
#
# MetaNetMap enables the construction of such resource using MetaNetX or MetaCyc knowledge bases. In the former case, data from ``chem_xref.tsv`` and ``chem_prop.tsv`` MetaNetX files is used. In the latter case (requires a licence), metadata from the ``compounds.dat`` file is extracted. Additionally, users can provide another table with existing mapping data resulting from previous curation efforts for instance, referred to as *datatable_complementary*.
#
# The conversion table serves as a comprehensive knowledge base that allows MetaNetMap to search across all known identifiers for a given metabolite and match them between the input data and the metabolic networks.
#
# Refer to the related documentation :doc:`usage` to build your first mapping table using MetaNetX data.
#
# > <picture>
# >   <source media="(prefers-color-scheme: light)" srcset="https://raw.githubusercontent.com/Mqxx/GitHub-Markdown/main/blockquotes/badge/light-theme/info.svg">
# >   <img alt="Info" src="https://raw.githubusercontent.com/Mqxx/GitHub-Markdown/main/blockquotes/badge/dark-theme/info.svg">
# > </picture><br>
# > The ``test`` commands of MetaNetMap rely on MetaCyc database.
#
# > However, complete information from MetaCyc related to the ontology of metabolites and pathways is **not included** in the test option because of licensing restrictions.
# >    Only a simplified example (a "toy" version) of the ``conversion_datatable`` file is provided. If you have a MetaCyc licence, you can build the complete conversion table using the ``compounds.dat`` file from
# > MetaCyc database.
#
#
# This notebook is used to regenerate mapping with toys using Metacyc datatable. For more details about MetaNetX conversion datatable, please refers to [documentation](https://metanetmap.readthedocs.io/en/latest/index.html).
#
# To sum up, it covers the use of MetNetMap, as well as the results of our mapping.
#
#
# #### Table of contents:
# - [0. Requirements : Jupyter](#requirements)
# - [I. Data requirements](#data)
# - [II. General use of the MetaNetMap](#general)
#
#
#
# ***

# %% [markdown]
# ## 0. Requirements : Jupyter <a id="requirements"></a>
#
# /!\ In order to use this notebook, it mandatory to activate a specific environnement and set the jupyter kernel.
# If this step is not done, the tutorial is below.
#
#
# ### Conda environment
#
#
# - **Step 1** : Create a conda environemnt <a name="Conda"></a>
# Create your environnement :
#
# ```
# conda env create -n <name> python==3.11
# conda activate <name>
# ```
#
# - **Step 2** : Install python-dfba-sampling in the environment
#
# Install with pip:
#
# ```sh
# pip install metanetmap
# ```
#
# Or from source:
#
# ```sh
# git clone git@gitlab.inria.fr:mistic/metanetmap.git
# cd metanetmap
# pip install -r requirements.txt
# pip install -r requirements_dev.txt
# pip install .
# ```
#
#
# - **Step 3** : Install in the environment (still activated) jupyter :
#
# ```sh
# conda install jupyter
# conda install -n base nb_conda_kernels
# ```
#
# Your Jupyter notebook can now run on the kernel you will set, in our case this environnemnt. It will not working if the kernel is not selected.

# %% [markdown]
# _____________________________________________________

# %% [markdown]
# # I. Data requirements <a id="data"></a>
#
# ## Input data: <a id="inputs"></a>
# ### Summary of Input Files for Database Building Mode
#
# | File/Directory          | Description                                                 |
# |-------------------------|-------------------------------------------------------------|
# | `metacyc_compounds`       | Tabular file provided by the MetaCyc database                |
# | `chem_xref`       | Tabular file provided by the MetanetX database                |
# | `datatable_complementary` | Tabular file provided by the user (see details below)       |
# | `output -o`               | Output directory for mapping results and logs               |
#
# > <picture>
# >   <source media="(prefers-color-scheme: light)" srcset="https://raw.githubusercontent.com/Mqxx/GitHub-Markdown/main/blockquotes/badge/light-theme/info.svg">
# >   <img alt="Info" src="https://raw.githubusercontent.com/Mqxx/GitHub-Markdown/main/blockquotes/badge/dark-theme/info.svg">
# > </picture><br>
# > The ouput stucture will be show as 'input' for the Summary of Input Files for Mapping Modes just below.
#
#
# ### Overview structure
# <h3 style="color: green;">metacyc_compounds:</h3>
#
# ><picture>
# >   <source media="(prefers-color-scheme: light)" srcset="https://raw.githubusercontent.com/Mqxx/GitHub-Markdown/main/blockquotes/badge/light-theme/info.svg">
# >   <img alt="Info" src="https://raw.githubusercontent.com/Mqxx/GitHub-Markdown/main/blockquotes/badge/dark-theme/info.svg">
# > </picture><br>
# > The `datatable_complementary` is a tabular file provided by the user. It allows users to add their own custom identifiers in order to improve matching with their metabolomics data.icence for MetaCyc
#
# The following is a raw entry for a compound from a MetaCyc flat file `.dat` extension.
# The file is structured as key-value pairs, where each line represents a specific property or annotation of the compound.
#
# Some keys, such as `CHEMICAL-FORMULA`, `SYNONYMS`, or `DBLINKS`, may occur multiple times. Values can contain nested content, quotes, or formatting(e.g. HTML tags in names).
#
# Some Key Characteristics (non-exhaustive)
#
# | **Field**                | **Description**                                                                                        |
# |--------------------------|--------------------------------------------------------------------------------------------------------|
# | `UNIQUE-ID`              | Primary identifier of the compound in the MetaCyc database.                                            |
# | `TYPES`                  | Declares the type of entity — typically `Compound`, but can also be other biological entities.         |
# | `COMMON-NAME`            | Human-readable compound name. May contain HTML formatting.                                             |
# | `CHEMICAL-FORMULA`       | Chemical composition split across multiple lines, each specifying an element and its count.            |
# | `DBLINKS`                | Cross-references to external databases such as BiGG, ChEBI, HMDB, KEGG, PubChem, etc. Multiple lines.  |
# | `INCHI`                  | Standard InChI string describing the molecular structure.                                              |
# | `INCHI-KEY`              | Hashed InChI identifier (short, fixed-length string) used for quick comparison of chemical structures. |
# | `INSTANCE-NAME-TEMPLATE` | A template indicating how this compound ID is generated or structured (e.g., starts with `CPD-`).      |
# | `LOGP`                   | Octanol–water partition coefficient (logP), representing hydrophobicity.                               |
# | `MOLECULAR-WEIGHT`       | Average molecular weight based on atomic composition.                                                  |
# | `MONOISOTOPIC-MW`        | Exact mass using the most abundant isotope for each element.                                           |
# | `NON-STANDARD-INCHI`     | Alternative or non-standard InChI representation.                                                      |
# | `POLAR-SURFACE-AREA`     | Topological polar surface area (TPSA) of the molecule.                                                 |
# | `SMILES`                 | Simplified Molecular Input Line Entry System (SMILES) string representing the structure.               |
# | `SYNONYMS`               | Alternate or common names for the compound. Can appear on multiple lines.                              |
#
# ____________________________________
#
# <h3 style="color: green;">datatable_complementary:</h3>
# Tabular file provided by the user
#
# | UNIQUE-ID        | ADD-COMPLEMENT                      | BIGG | SEED |
# |------------------|-------------------------------------|------|------|
# | CPD-7100         | (2S)-2-isopropyl-3-oxosuccinic acid |      |      |
# | DI-H-OROTATE     | (S)-dihydroorotic acid              |      |      |
# | SHIKIMATE-5P     | 3-phosphoshikimic acid              |      |      |
# | DIAMINONONANOATE | 7,8-diaminononanoate                | dann |      |
#
# > <picture>
# >   <source media="(prefers-color-scheme: light)" srcset="https://raw.githubusercontent.com/Mqxx/GitHub-Markdown/main/blockquotes/badge/light-theme/info.svg">
# >   <img alt="Info" src="https://raw.githubusercontent.com/Mqxx/GitHub-Markdown/main/blockquotes/badge/dark-theme/info.svg">
# > </picture><br>
# > The `datatable_complementary` is a tabular file provided by the user. It allows users to add their own custom identifiers in order to improve matching with their metabolomics data.
#
#
# **Requirements and structure:**
#
# - The **first column must be** a ``UNIQUE-ID`` that links to the MetaCyc database.
# - All **following columns are free** and may contain any identifiers or names. Their column names will be automatically included in the main conversion datatable.
# - The file must be in tabular format (e.g., TSV), with headers.
#
#
# <h4 style="color: red;">Important notes:</h4>
#
# - If you have a metabolite **without a matching ``UNIQUE-ID`` in MetaCyc**, you may assign it a **custom or fictional ID** in the first column.
# - This fictional ``UNIQUE-ID`` will still be included in the conversion table, and **will be used if a match is found based on the name or identifier you provided.**
# - Be sure to keep track of any custom or fictional IDs you create, so you can filter or manage them later if needed.

# %% [markdown]
# ___________________

# %% [markdown]
# ### Summary of Input Files for Mapping Modes  <a id="input-mode"></a>
#
# | File/Directory        | Description                                                 |
# |-----------------------|-------------------------------------------------------------|
# | `metabolic_networks`  | Path to the directory with `.sbml` and/or `.xml` files      |
# | `metabolomics_data`   | Tabulated file (see note below for details)                 |
# | `datatable_conversion`| Tabulated file, first column is the `UNIQUE-ID` in MetaCyc  |
#
#
# > <picture>
# >   <source media="(prefers-color-scheme: light)" srcset="https://raw.githubusercontent.com/Mqxx/GitHub-Markdown/main/blockquotes/badge/light-theme/info.svg">
# >   <img alt="Info" src="https://raw.githubusercontent.com/Mqxx/GitHub-Markdown/main/blockquotes/badge/dark-theme/info.svg">
# > </picture><br>
# > For `metabolomics_data`:
# > Column names must follow a specific naming convention to be properly processed by the tool during the mapping step.
# >
# > Recognized column names include:
# >
# > `UNIQUE-ID`, `CHEBI`, `COMMON-NAME`, `ABBREV-NAME`, `SYNONYMS`, `ADD-COMPLEMENT`, `MOLECULAR-WEIGHT`, `MONOISOTOPIC-MW`, `SEED`, `BIGG`, `HMDB`, `METANETX`, `LIGAND-CPD`, `REFMET`, `PUBCHEM`, `CAS`, `INCHI-KEY`, `SMILES`
#
#
# ### Overview structure
#
# <h3 style="color: green;">metabolomics_data:</h3>
#
#   > **Note:**
#   > For **metabolomics_data**:
#   > Column names must follow a specific naming convention and each line is a metabolite.
#   > Metabolomic data files must include column names that follow a specific naming convention in order to be properly processed by the tool during the mapping step.
#   >
#   > The following column names are recognized:
#   >
#   > `UNIQUE-ID`, `CHEBI`, `COMMON-NAME`, `ABBREV-NAME`, `SYNONYMS`,
#   > `ADD-COMPLEMENT`, `MOLECULAR-WEIGHT`, `MONOISOTOPIC-MW`, `SEED`,
#   > `BIGG`, `HMDB`, `METANETX`, `LIGAND-CPD`, `REFMET`, `PUBCHEM`,
#   > `CAS`, `INCHI-KEY`, `SMILES`
#
#
# **Raw Metabolomic data:**
#
# | UNIQUE-ID  | CHEBI       | COMMON-NAME           | M/Z       | INCHI-KEY                               |
# |------------|-------------|----------------------|-----------|----------------------------------------|
# |            | CHEBI:4167  |                      | 179       |                                        |
# |            |             | L-methionine         | 150       |                                        |
# | CPD-17381  |             | roquefortine C       | 389.185   |                                        |
# |            |             |                      |           | InChIKey=CGBYBGVMDAPUIH-ARJAWSKDSA-L  |
# | CPD-25370  | 84783       |                      | 701.58056 |                                        |
# |            | CHEBI:16708 | Adenine              |           |                                        |
#
#
# ---
#
# <h3 style="color: green;">Metabolic networks: </h3>
#
# ```xml
# <?xml version="1.0" encoding="UTF-8"?>
# <sbml xmlns="http://www.sbml.org/sbml/level3/version1/core"
#       level="3" version="1">
#   <model id="example_model" name="Example Metabolic Model">
#     <!-- Compartments -->
#     <listOfCompartments>
#       <compartment id="cytosol" name="Cytosol" constant="true"/>
#     </listOfCompartments>
#
#     <listOfSpecies>
#       <species id="glucose_c" name="Glucose" compartment="cytosol" initialAmount="1.0" hasOnlySubstanceUnits="false" boundaryCondition="false" constant="false">
#         <annotation>
#           <rdf:RDF xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#">
#             <rdf:Description rdf:about="#glucose_c">
#               <bqbiol:is>
#                 <rdf:Bag>
#                   <rdf:li rdf:resource="http://identifiers.org/chebi/CHEBI:17234"/>
#                   <rdf:li rdf:resource="http://identifiers.org/inchikey/WQZGKKKJIJFFOK-GASJEMHNSA-N"/>
#                 </rdf:Bag>
#               </bqbiol:is>
#             </rdf:Description>
#           </rdf:RDF>
#         </annotation>
#       </species>
#     </listOfSpecies>
#
#   </model>
# </sbml>
# ```
#
# For **metabolic network data**, we typically extract the ID and name, as well as all possible metadata present in the networks, for example: (chebi, InChIKey...) via annotation.
#
# | Element              | Description                                                                   |
# |----------------------|-------------------------------------------------------------------------------|
# | `species`            | Defines a metabolite within a compartment                                     |
# | `annotation`         | Contains **metadata** in RDF format, including standardized cross-references  |
# | `chebi` / `inchikey` | Links to standardized identifiers for interoperability                        |
#
# ---
#
# <h3 style="color: green;">Datatable_conversion: </h3>
#
# The ``datatable_conversion`` file acts as a bridge between the metabolomic data and the metabolic networks.
# It combines all structured information extracted from the MetaCyc ``compounds.dat`` file, along with any additional identifiers or metadata provided by the user through the ``datatable_complementary`` file.
# This unified table serves as a comprehensive knowledge base that allows the tool to search across all known identifiers for a given metabolite, and match them between the input metabolomic data and the metabolic networks.
# By leveraging both the MetaCyc database and user-provided knowledge, the ``datatable_conversion`` enables robust and flexible mapping across diverse data sources.
#
#
# | UNIQUE-ID    | CHEBI  | COMMON-NAME           | ABBREV-NAME | SYNONYMS                                            | ADD-COMPLEMENT | MOLECULAR-WEIGHT | MONOISOTOPIC-MW  | SEED | BIGG   |
# |--------------|--------|-----------------------|-------------|-----------------------------------------------------|----------------|------------------|------------------|------|--------|
# | CPD-17257    | 30828  | trans-vaccenate       |             | ["trans-vaccenic acid","(E)-11-octadecenoic acid"]  |                | 281.457          | 282.2558803356   |      |        |
# | CPD-24978    | 50258  | alpha-L-allofuranose  |             |                                                     |                | 180.157          | 180.0633881178   |      |        |
# | CPD-25014    | 147718 | alpha-D-talofuranoses |             |                                                     |                | 180.157          | 180.0633881178   |      |        |
# | CPD-25010    | 153460 | alpha-D-mannofuranose |             |                                                     |                | 180.157          | 180.0633881178   |      |        |
# | Glucopyranose| 4167   | D-glucopyranose       |             | ["6-(hydroxymethyl)tetrahydropyran-2,3,4,5-tetraol"]|                | 180.157          | 180.0633881178   |      | glc__D |
#
#
# Without other columns created with the datatable_complementary, the general keys are listed below:
#
# | Column Name        | Description                                                                                                                                        |
# |--------------------|----------------------------------------------------------------------------------------------------------------------------------------------------|
# | `UNIQUE-ID`        | The unique identifier for the compound, typically from the MetaCyc database (e.g., `CPD-17257`).                                                   |
# | `CHEBI`            | The corresponding ChEBI identifier (if available), used for chemical standardization and interoperability.                                         |
# | `COMMON-NAME`      | The common name of the metabolite as found in MetaCyc or other databases.                                                                          |
# | `ABBREV-NAME`      | Abbreviated name for the metabolite, if defined. Often used in metabolic modeling tools (e.g., COBRA models).                                      |
# | `SYNONYMS`         | A list of alternative names for the metabolite. These may include IUPAC names, trivial names, and other variants used in the literature/databases. |
# | `ADD-COMPLEMENT`   | Reserved for additional manually added metadata or complement terms, if applicable.                                                                |
# | `MOLECULAR-WEIGHT` | The molecular weight (nominal or average) of the metabolite.                                                                                       |
# | `MONOISOTOPIC-MW`  | The monoisotopic molecular weight — i.e., the exact mass based on the most abundant isotope of each element.                                       |
# | `SEED`             | Identifier from the SEED database, if available.                                                                                                   |
# | `BIGG`             | Identifier from the BiGG Models database, if available. Typically used in genome-scale metabolic models.                                           |

# %% [markdown]
# # Output Data
#
# ### Summary of Output File for Database Building Mode
#
# | File/Directory         | Description                                                 |
# |------------------------|-------------------------------------------------------------|
# | `datatable_conversion` | Tabulated file, first column is the `UNIQUE-ID` in MetaCyc  |
# | `logs`                 | Directory providing more detailed information               |
#
# ___
#
# > <picture>
# >   <source media="(prefers-color-scheme: light)" srcset="https://raw.githubusercontent.com/Mqxx/GitHub-Markdown/main/blockquotes/badge/light-theme/info.svg">
# >   <img alt="Info" src="https://raw.githubusercontent.com/Mqxx/GitHub-Markdown/main/blockquotes/badge/dark-theme/info.svg">
# > </picture><br>
# > The `datatable_conversion` file acts as a bridge between the metabolomics data and the metabolic networks.
# > It combines structured data from the MetaCyc `compounds.dat` file with user-provided identifiers or metadata from `datatable_complementary`.
# >
# > This unified table enables comprehensive and flexible mapping across diverse data sources.
# >
# > The `logs` directory contains detailed processing information, helpful for debugging, auditing, and understanding how the tool performed the mapping.
#
# ---
#
# ### Summary of Output File for Mapping Modes
#
# | File/Directory         | Description                                                    |
# |------------------------|----------------------------------------------------------------|
# | `mapping_results`      | Tabulated file with match/unmatch results                      |
# | `logs`                 | Directory providing more detailed information                  |
# | `MNM_mafs`             | Directory with rewriting of mafs files with MNM_ID identifiers |
#
#
# <h3 style="color: green;">mapping_results: </h3>
#
# #### Output File Format
#
# - In **community mode**, the file is named: `community_mapping_results_YYYY-MM-DD_HH:MM:SS.tsv`
# - In **classic mode**, the file is named: `mapping_results_YYYY-MM-DD_HH:MM:SS.tsv`
# - If **partial match** is activated, the filename will include `partial_match` to indicate this.
#
# #### Output file Content and Column Structure
#
#    1. **MNM_ID**
#
#       A unique identifier assigned to each metabolite entry in MAF files, used to clearly track and distinguish individual rows after the mapping process.
#
#    2. **Metabolite matches**
#
#       Lists the metabolite names that matched.
#       If multiple matches are found for a single input (i.e., duplicates), they are joined using ``_AND_``.
#
#    3. **MetaCyc/MetaNetX UNIQUE-ID match (from `conversion_datatable`)**
#
#       Indicates whether a match was found through the MetaCyc/MetaNetX conversion table using a ``UNIQUE-ID``.
#       If two UNIQUE-IDs match the same input, they are separated by ``_AND_`` and flagged as uncertain.
#       These entries are also reflected in the **partial** column due to ambiguity.
#
#    4. **Input file match (metabolomics data)**
#
#       In **classic mode**, this column shows the identifier from the input file that matched with the SBML model.
#       In **community mode**, this column contains a list (e.g., ``[data1, data4]``) indicating the specific files in which matches were found.
#       Additional details about the exact identifiers used in the networks can be found in the logs.
#
#
#    5. **Match IDS in metabolic networks(For comminuty mode only)**
#
#       This column provides the metabolite IDs that correspond to the matches found in the metabolic networks.
#
#    6. **Partial match**
#
#       This column contains any uncertain or ambiguous matches:
#
#       - Duplicates (same metabolite matched multiple entries)
#       - Matches resulting from post-processing (enabled when partial matching is active), such as:
#         - ChEBI ontology expansion
#         - InChIKey simplification
#         - Enantiomer removal
#
#       These matches require manual review and are also logged in detail.
#
#    6. **Other columns**
#
#       The remaining columns correspond to identifiers or metadata from the metabolomics data.
#       Each cell contains ``YES`` to indicate that a match was found on the ID of that column in the metabolomics data.
#
#
# <h3 style="color: green;">MNM_mafs</h3>
#
# **Metabolomic data rewritten by MetaNetMap:**
#
# This directory is generated in the output folder, and the MAF files are then rewritten with a unique identifier assigned to each row corresponding to a metabolite.
# This ensures fast and unambiguous tracking of all IDs associated with a given row, and prevents confusion in cases where metabolites from different rows map to the same metabolite in the metabolic network—an ambiguity that is then reported in the *Partial match* column.
#
# If multiple MAF files are provided, the IDs are assigned progressively, taking into account the IDs already generated from previously processed MAF files.
# For example, if two MAFs contain 10 and 15 metabolites respectively, the first file will receive IDs **from 1 to 10**, and the second **from 11 to 26**.
#
# > <picture>
# >   <source media="(prefers-color-scheme: light)" srcset="https://raw.githubusercontent.com/Mqxx/GitHub-Markdown/main/blockquotes/badge/light-theme/info.svg">
# >   <img alt="Info" src="https://raw.githubusercontent.com/Mqxx/GitHub-Markdown/main/blockquotes/badge/dark-theme/info.svg">
# > </picture><br>
# > The IDs are assigned according to the order in which the tool reads the files.
#
# > The first file processed will receive the first IDs, and so on. This order may not correspond to the user’s intended ordering unless the files have been checked and sorted beforehand.
#
#
# | MNM_ID | UNIQUE-ID  | CHEBI       | COMMON-NAME           | M/Z       | INCHI-KEY                               |
# |------------|------------|-------------|----------------------|-----------|----------------------------------------|
# | MNM1   |            | CHEBI:4167  |                      | 179       |                                        |
# | MNM2   |            |             | L-methionine         | 150       |                                        |
# | MNM3   | CPD-17381  |             | roquefortine C       | 389.185   |                                        |
# | MNM4   |            |             |                      |           | InChIKey=CGBYBGVMDAPUIH-ARJAWSKDSA-L  |
# | MNM5   | CPD-25370  | 84783       |                      | 701.58056 |                                        |
# | MNM6   |            | CHEBI:16708 | Adenine              |           |                                        |
#
# <h3 style="color: green;">log: </h3>
#
# Provides more information about each step and the corresponding results.
#
# ```
#
#     -----------------------------------------
#                 MAPPING METABOLITES
#     -----------------------------------------
#
#     ------ Main package version ------
#     numpy version: 2.3.2
#     pandas version: 2.3.2
#     cobra version: 0.29.1
#     libchebipy version: 1.0.10
#
#     Command run:
#     Actual command run (from sys.argv): python /home/cmuller/miniconda3/envs/test2/bin/metanetmap -t -c -p
#
#     #---------------------------#
#           Test COMMUNITY
#     #---------------------------#
#
#      Test with .. code-block:: noneatching test between metabolites derived from metabolomic data on  all metadata in the metabolic network
#     <2> Matching test between metabolites derived from metabolomic data on all metadata in the database conversion
#
#     ++ Match step for "CPD-17381":
#     -- "CPD-17381" is present in database with the UNIQUE-ID "CPD-17381" and matches via "UNIQUE-ID"
#
#     ++ Match step for "CPD-25370":
#     -- "CPD-25370" is present directly in "toys1" metabolic network with the ID "CPD-25370" via "UNIQUE-ID"
#     -- "CPD-25370" is present in database with the UNIQUE-ID "CPD-25370" and matches via "UNIQUE-ID"
#
#     ++ Match step for "C9H16NO5":
#     -- "C9H16NO5" is present directly in "toys3" metabolic network with the ID "pnto__R" via "UNIQUE-ID"
#     -- ""C9H16NO5"" has a partial match. We have a formula as identifier for this metabolite: "C9H16NO5"
#
#     ++ Match step for "4167":
#     -- "4167" is present directly in "toys3" metabolic network with the ID "glc__D" via "CHEBI"
#     .....
#
#     --"NO" is present directly in metabolic network with the corresponding ID "NITRIC-OXIDE" via the match ID "nitric-oxide"
#
#
#     ......
#
#     ----------------------------------------------
#     ---------------MATCH STEP 2-------------------
#     ----------------------------------------------
#
#     <3> Matching test on metabolites that matched only on the database conversion data against all metadata from the metabolic network
#
#     --"Glycocholic acid" is present directly in metabolic network with the corresponding ID "GLYCOCHOLIC_ACID" via the match ID "glycocholic_acid"
#     --"gamma-Tocopherol" is present directly in metabolic network with the corresponding ID "GAMA-TOCOPHEROL" via the match ID "gama-tocopherol"
#
#     .......
#
#
#     -------------------- SUMMARY REPORT --------------------
#
#
#     Recap of Matches:
#       + Matched metabolites: 103
#       + Unmatched metabolites: 43740
#       + Partial matches: 15
#
#      Match Details:
#       -- Full match (database + SBML): 103
#       -- Partial match + metabolic info: 10
#       -- Match only in SBML: 0
#
#      Unmatch Details:
#       -- Full unmatch (no match in DB or SBML): 43514
#       -- Match in DB but not in SBML: 226
#       -- Partial match in DB only: 5
#
#     --------------------------------------------------------
#
#
#     --- Total runtime 1478.55 seconds ---
#      --- MAPPING COMPLETED'

# %% [markdown]
# __________________

# %% [markdown]
# # II. General use of the MetaNetMap
#
# #### a. Build database_conversion
#
# */!\ Warning:* This step requires the MetaCyc database or MetaNetX database. Metacyc information related to the ontology of metabolites and pathways is not included in this test.
# You must provide your own ``compounds.dat`` file from MetaCyc or use MetaNetX files ``chem_xref.tsv`` and ``chem_prop.tsv`` wich are open source.
#
# The ``datatable_conversion`` file acts as a bridge between the metabolomics data and the metabolic networks.
# It combines all structured information extracted from the MetaCyc ``compounds.dat`` or from MetaNetX files ``chem_xref.tsv`` and ``chem_prop.tsv``files, along with any additional identifiers or metadata provided by the user through the ``datatable_complementary`` file.
#
# This unified table serves as a comprehensive knowledge base that allows the tool to search across all known identifiers for a given metabolite and match them between the input data and the metabolic networks.
#
# By leveraging both the MetaCyc database and user-provided enhancements, the ``datatable_conversion`` enables robust and flexible mapping across diverse data sources.
# <a id="general"></a>

# %%
''' Run database building mode**:  

'''
#for Metacyc
# Commented out because we don’t have the MetaCyc compounds.dat file,
# so it can’t be run directly with MetaCyc data.
#!metanetmap build_db --db metacyc -f  <your_path_to_metacyc_compounds.dat>  --compfiles ../src/metanetmap/build_datatable_conversion/datatable_complementary_file  --out_db <output>


##for MetaNetX -> can be time comnsuming because it download inputs files
#!metanetmap build_db --db metanetx -f  <your_path_to_metanetx_chem_prop>  <your_path_to_metanetx_chem_xref> --compfiles ../src/metanetmap/build_datatable_conversion/datatable_complementary --out_db <output>
# !metanetmap build_db --db metanetx --out_db build/
# Out:
# 1275.42s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# -----------------------------------------
#             BUILD CONVERTION TABLE
# -----------------------------------------
#
#
# Command run:
# Actual command run (from sys.argv): python /home/cmuller/miniconda3/envs/metanetmap/bin/metanetmap build_db --db metanetx --out_db build/
# Downloading chem_prop.tsv from https://www.metanetx.org/cgi-bin/mnxget/mnxref/chem_prop.tsv...
# chem_prop.tsv successfully downloaded to build/metanetx_db/chem_prop.tsv
# File exists: build/metanetx_db/chem_prop.tsv
# Downloading chem_xref.tsv from https://www.metanetx.org/cgi-bin/mnxget/mnxref/chem_xref.tsv...
# chem_xref.tsv successfully downloaded to build/metanetx_db/chem_xref.tsv
# File exists: build/metanetx_db/chem_xref.tsv
#
# ---> Run construction of the datatable for MetaNetX
# /!\  No complementary file added
# Final merged table generated: build/metanetx_conversion_datatable.tsv
#
# --- Total runtime 314.70 seconds ---
#  ---> Construction of the database completed

# %%
''' Show Build mode (display first 10 rows) '''

import os
import pandas as pd

# 1. Set the file path directly
file_path = 'build/metanetx_conversion_datatable.tsv'  

# 2. Check if the file exists
if os.path.isfile(file_path):
    print(f"Found file: {file_path}")

    # 3. Read the file (auto-detect TSV)
    if file_path.endswith('.tsv'):
        df = pd.read_csv(file_path, sep='\t')
    else:
        print("Unsupported file format.")
        df = None

    # 4. Display only the first 10 rows if loaded
    if df is not None:
        display(df.head(10))
else:
    print(f"File not found: {file_path}")

# !rm -r build/
# Out:
# Found file: build/metanetx_conversion_datatable.tsv
#   UNIQUE-ID        CHEBI COMMON_NAME  ABBREV_NAME  SYNONYMS  ADD-COMPLEMENT  \
# 0   BIOMASS          NaN     BIOMASS          NaN       NaN             NaN
# 1    MNXM01          NaN         PMF          NaN       NaN             NaN
# 2    MNXM02  chebi:13365       OH(-)          NaN       NaN             NaN
# 3    MNXM02  chebi:13419       OH(-)          NaN       NaN             NaN
# 4    MNXM02  chebi:16234       OH(-)          NaN       NaN             NaN
# 5    MNXM02  chebi:29356       OH(-)          NaN       NaN             NaN
# 6    MNXM02  chebi:44641       OH(-)          NaN       NaN             NaN
# 7    MNXM02   chebi:5594       OH(-)          NaN       NaN             NaN
# 8    MNXM03  chebi:29412      H3O(+)          NaN       NaN             NaN
# 9     MNXM1  chebi:10744        H(+)          NaN       NaN             NaN
#
#    MOLECULAR_WEIGHT      SEED BIGG         HMDB  METACYC  REFMET  PUBCHEM  \
# 0               NaN  cpd11416  NaN          NaN      NaN     NaN      NaN
# 1           1.00794       NaN  NaN          NaN      NaN     NaN      NaN
# 2          17.00700  cpd15275  oh1  HMDB0001039       OH     NaN      NaN
# 3          17.00700  cpd15275  oh1  HMDB0001039       OH     NaN      NaN
# 4          17.00700  cpd15275  oh1  HMDB0001039       OH     NaN      NaN
# 5          17.00700  cpd15275  oh1  HMDB0001039       OH     NaN      NaN
# 6          17.00700  cpd15275  oh1  HMDB0001039       OH     NaN      NaN
# 7          17.00700  cpd15275  oh1  HMDB0001039       OH     NaN      NaN
# 8          19.02300       NaN  NaN          NaN  OXONIUM     NaN      NaN
# 9           1.00794  cpd00067    h  HMDB0059597   PROTON     NaN      NaN
#
#        VMH  CAS                  INCHI  NON-STANDARD-INCHI  \
# 0      NaN  NaN                    NaN                 NaN
# 1      NaN  NaN           InChI=1S/p+1                 NaN
# 2      oh1  NaN  InChI=1S/H2O/h1H2/p-1                 NaN
# 3      oh1  NaN  InChI=1S/H2O/h1H2/p-1                 NaN
# 4      oh1  NaN  InChI=1S/H2O/h1H2/p-1                 NaN
# 5      oh1  NaN  InChI=1S/H2O/h1H2/p-1                 NaN
# 6      oh1  NaN  InChI=1S/H2O/h1H2/p-1                 NaN
# 7      oh1  NaN  InChI=1S/H2O/h1H2/p-1                 NaN
# 8      NaN  NaN  InChI=1S/H2O/h1H2/p+1                 NaN
# 9  HC02115  NaN           InChI=1S/p+1                 NaN
#
#                      INCHI_KEY           SMILES
# 0                          NaN              NaN
# 1  GPRLSGONYQIRFK-UHFFFAOYSA-N             [H+]
# 2  XLYOFNOQVPJJNP-UHFFFAOYSA-M          [H][O-]
# 3  XLYOFNOQVPJJNP-UHFFFAOYSA-M          [H][O-]
# 4  XLYOFNOQVPJJNP-UHFFFAOYSA-M          [H][O-]
# 5  XLYOFNOQVPJJNP-UHFFFAOYSA-M          [H][O-]
# 6  XLYOFNOQVPJJNP-UHFFFAOYSA-M          [H][O-]
# 7  XLYOFNOQVPJJNP-UHFFFAOYSA-M          [H][O-]
# 8  XLYOFNOQVPJJNP-UHFFFAOYSA-O  [H][O+]([H])[H]
# 9  GPRLSGONYQIRFK-UHFFFAOYSA-N             [H+]
# 1602.55s - pydevd: Sending message related to process being replaced timed-out after 5 seconds

# %% [markdown]
# #### b. Run mapping mode : To run step below, you don't need ti run Build mode, which can be time-consuming, and it doesn't use the same conversion datatable.
#
# You can run MetaNetMap in two different modes (classic, Community) with a partial match option :
#
# Rappel partial match:
# - **Partial match**:
# The **partial match** is optional, as it can be time-consuming. It is a post-processing step applied to metabolites or IDs that were not successfully mapped during the initial run. These unmatched entries are re-evaluated using specific strategies, which increase the chances of finding a match (e.g., via CHEBI, INCHIKEY, or enantiomer simplification).
#
# After this processing step, the entire mapping pipeline is re-executed, taking the modifications into account.
#
# **The following treatments are applied:**
#
# - **CHEBI** *(only if a CHEBI column exists in the metabolomics data)*:
#   For each row containing a CHEBI ID, the Python library `libCHEBI` is used to retrieve the full CHEBI ontology of the metabolite. These related terms are then remapped against the target databases.
#
# - **INCHIKEY**:
#   An INCHIKEY is structured as `XXXXXXXXXXXXXX-YYYYYYYAB-Z`. The first block (`X`) represents the core molecular structure. We extract only this primary structure to increase the chances of a match during the second mapping phase.
#
# - **Enantiomers**:
#   Stereochemistry indicators (L, D, R, S) are removed from both the metabolomics data and the databases. This improves matching rates, since stereochemical information is often missing in metabolomics datasets.

# %%
''' Run Classic mode
    The classic mode allows you to input a single metabolomics data file and a directory containing multiple metabolic networks.
'''

# !metanetmap classic -s ../src/metanetmap/toys_tests_data/toys/sbml/toys2.sbml -a ../src/metanetmap/toys_tests_data/toys/maf/ -d ../src/metanetmap/toys_tests_data/conversion_datatable_toys.tsv -o mapping/classic/
# Out:
# 1608.06s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# -----------------------------------------
#             MAPPING METABOLITES
# -----------------------------------------
#
# ------> Main package version <------
# numpy version: 2.3.3
# pandas version: 2.3.2
# cobra version: 0.29.1
#
# Command run:
# Actual command run (from sys.argv): python /home/cmuller/miniconda3/envs/metanetmap/bin/metanetmap classic -s ../src/metanetmap/toys_tests_data/toys/sbml/toys2.sbml -a ../src/metanetmap/toys_tests_data/toys/maf/ -d ../src/metanetmap/toys_tests_data/conversion_datatable_toys.tsv -o mapping/classic/
#
#
#
# ---->    MODE CLASSIC    <----
#
# Load metabolomics data user path: ../src/metanetmap/toys_tests_data/toys/maf/ and metabolic networks user path: ../src/metanetmap/toys_tests_data/toys/sbml/toys2.sbml
#
#
# ---------------PATHS-------------------
# List metabolomics data paths: ['../src/metanetmap/toys_tests_data/toys/maf/toys1.tsv', '../src/metanetmap/toys_tests_data/toys/maf/toys3.tsv', '../src/metanetmap/toys_tests_data/toys/maf/toys2.tsv']
# List metabolic networks paths: ['../src/metanetmap/toys_tests_data/toys/sbml/toys2.sbml']
#
#
# Output file successfully written to: mapping/classic/MNM_mafs/MNM_toys1.tsv
#
# Output file successfully written to: mapping/classic/MNM_mafs/MNM_toys3.tsv
#
# Output file successfully written to: mapping/classic/MNM_mafs/MNM_toys2.tsv
#
#
# ----------------------------------------------
# ---------------MATCH STEP 1-------------------
# ----------------------------------------------
#
# <1> Direct matching test between metabolites derived from metabolomic data on all metadata in the metabolic network
# <2> Matching test between metabolites derived from metabolomic data on all metadata in the database conversion
#
# ++ Match step for "CPD-17381":
# --"CPD-17381" is present in database with the UNIQUE-ID "CPD-17381" and matches via "UNIQUE-ID"
#
# ++ Match step for "CPD-25370":
# --"CPD-25370" is present in database with the UNIQUE-ID "CPD-25370" and matches via "UNIQUE-ID"
#
# ++ Match step for "CHEBI:4167":
# --"CHEBI:4167" is present in database with the UNIQUE-ID "Glucopyranose" and matches via "CHEBI"
#
# ++ Match step for "CHEBI:84783":
# --"CHEBI:84783" is a metabolite duplicate of "CPD-25370" and matches via "CHEBI"
#
# ++ Match step for "CHEBI:16708":
# --"CHEBI:16708" is present in database with the UNIQUE-ID "ADENINE" and matches via "CHEBI"
#
# ++ Match step for "CHEBI:36023":
#
# ++ Match step for "CHEBI:90488":
#
# ++ Match step for "CHEBI:15756":
#
# ++ Match step for "CHEBI:123564":
#
# ++ Match step for "L-methionine":
# --"L-methionine" is present directly in metabolic network with the ID "['MET']" via "COMMON-NAME"
# --"L-methionine" is present in database with the UNIQUE-ID "MET" and matches via "COMMON-NAME"
#
# ++ Match step for "roquefortine C":
# --"roquefortine C" is a metabolite duplicate of "CPD-17381" and matches via "COMMON-NAME"
#
# ++ Match step for "Adenine":
# --"Adenine" is a metabolite duplicate of "CHEBI:16708" and matches via "COMMON-NAME"
#
# ++ Match step for "Beta-D-galactosyl-(1->3)-N-acetyl-beta-D-glucosaminyl-R":
# --"Beta-D-galactosyl-(1->3)-N-acetyl-beta-D-glucosaminyl-R" is present in database with the UNIQUE-ID "beta-Gal-13-beta-GlcNac-R" and matches via "COMMON-NAME"
# --"Beta-D-galactosyl-(1->3)-N-acetyl-beta-D-glucosaminyl-R" has a partial match. We have several UNIQUE-ID identifiers for this metabolite: "beta-Gal-13-beta-GlcNac-R" and "Gal-13-GlcN-R"
#
# ++ Match step for "vaccenic":
#
# ++ Match step for "delphinidin 3-O-(4-coumaroyl-rhamnosyl-(1->6)-glucoside":
#
# ++ Match step for "methionine":
# --"methionine" is a metabolite duplicate of "L-methionine" and matches via "COMMON-NAME"
# --"methionine" is a metabolite duplicate of "L-methionine" and matches via "COMMON-NAME"
#
# ++ Match step for "8-O-methylfusarubin alcohol":
# --"8-O-methylfusarubin alcohol" is present directly in metabolic network with the ID "['CPD-18186']" via "COMMON-NAME"
# --"8-O-methylfusarubin alcohol" is present in database with the UNIQUE-ID "CPD-18186" and matches via "COMMON-NAME"
#
# ++ Match step for "thionine":
#
# ++ Match step for "beta-D-galactosyl-(1->3)-N-acetyl-beta-D-glucosaminyl-R":
# --"beta-D-galactosyl-(1->3)-N-acetyl-beta-D-glucosaminyl-R" is a metabolite duplicate of "Beta-D-galactosyl-(1->3)-N-acetyl-beta-D-glucosaminyl-R" and matches via "COMMON-NAME"
#
# ++ Match step for "orotic acid":
# --"orotic acid" is present in database with the UNIQUE-ID "OROTATE" and matches via "SYNONYMS"
#
# ++ Match step for "Carbamyl-phosphate":
# --"Carbamyl-phosphate" is present directly in metabolic network with the ID "['Carbamyl-phosphate']" via "SYNONYMS"
# --"Carbamyl-phosphate" is present in database with the UNIQUE-ID "CARBAMOYL-P" and matches via "SYNONYMS"
#
# ++ Match step for "pantothenic acid":
# --"pantothenic acid" is present in database with the UNIQUE-ID "PANTOTHENATE" and matches via "ADD-COMPLEMENT"
#
# ++ Match step for "aprut":
# --"aprut" is present in database with the UNIQUE-ID "CPD-569" and matches via "BIGG"
#
# ++ Match step for "f1p":
# --"f1p" is present in database with the UNIQUE-ID "FRU1P" and matches via "BIGG"
# --"f1p" has a partial match. We have several UNIQUE-ID identifiers for this metabolite: "FRU1P" and "CPD-15970"
#
# ++ Match step for "crnmock":
#
# ++ Match step for "INCHIKEY=CGBYBGVMDAPUIH-ARJAWSKDSA-L":
# --"INCHIKEY=CGBYBGVMDAPUIH-ARJAWSKDSA-L" is present in database with the UNIQUE-ID "DIMETHYLMAL-CPD" and matches via "INCHI-KEY"
#
# ++ Match step for "INCHIKEY=AVVWPBAENSWJCB-VSOTGSRCSA-C":
#
# ++ Match step for "INCHIKEY=FSCYHDCTAZZSKN-DJNGBR":
#
# ++ Match step for "CCCC(=O)OCC(/C=C=C1([C@](C)(O)C[C@@H](OC(=O)C)CC(C)(C)1))=C/C=C/C(\C)=C/C=C/C=C(C)/C=C/C=C(C)/C(=O)C[C@]23(C(C)(C)C[C@H](O)C[C@@](C)(O2)3)":
# --"CCCC(=O)OCC(/C=C=C1([C@](C)(O)C[C@@H](OC(=O)C)CC(C)(C)1))=C/C=C/C(\C)=C/C=C/C=C(C)/C=C/C=C(C)/C(=O)C[C@]23(C(C)(C)C[C@H](O)C[C@@](C)(O2)3)" is present in database with the UNIQUE-ID "CPD-26454" and matches via "SMILES"
#
# ++ Match step for "C(S)[C@@H](C(NCCC(=O)[O-])=O)NC(=O)CC[C@@H](C([O-])=O)NC(=O)[C@H](CS)NC(=O)CC[C@H]([NH3+])C([O-])":
#
# ++ Match step for "C9H16NO5":
#
#
# ----------------------------------------------
# ---------------MATCH STEP 2-------------------
# ----------------------------------------------
#
# <3> Matching test on metabolites that matched only on the database conversion data against all metadata from the metabolic network
#
# --"Beta-D-galactosyl-(1->3)-N-acetyl-beta-D-glucosaminyl-R" is present directly in metabolic network with the corresponding ID "Gal-13-GlcN-R" via the match ID "gal-13-glcn-r"
# --"orotic acid" is present directly in metabolic network with the corresponding ID "OROTATE" via the match ID "orotate"
# --"pantothenic acid" is present directly in metabolic network with the corresponding ID "PANTOTHENATE" via the match ID "pantothenate"
# --"CCCC(=O)OCC(/C=C=C1([C@](C)(O)C[C@@H](OC(=O)C)CC(C)(C)1))=C/C=C/C(\C)=C/C=C/C=C(C)/C=C/C=C(C)/C(=O)C[C@]23(C(C)(C)C[C@H](O)C[C@@](C)(O2)3)" is present directly in metabolic network with the corresponding ID "CPD-26454" via the match ID "cpd-26454"
#
# -------------------- SUMMARY REPORT --------------------
#
#
# Recap of Matches:
#   + Matched metabolites: 7
#   + Unmatched metabolites: 17
#   + Partial matches: 3
#
#  Match Details:
#   --> Full match (database + SBML): 7
#   --> Partial match + metabolic info: 2
#   --> Match only in SBML: 0
#
#  Unmatch Details:
#   --> Full unmatch (no match in DB or SBML): 10
#   --> Match in DB but not in SBML: 7
#   --> Partial match in DB only: 1
#
# --------------------------------------------------------
#
# Output file successfully written to: mapping/classic/mapping_results_2025-12-15_15_40_32.tsv
#
# --- Total runtime 0.05 seconds ---
#  ---> MAPPING COMPLETED'

# %%
''' Show Mafs rewritten with new MNM_IDs
'''
import os
import pandas as pd

# 1. Set the directory path
directory = 'mapping/classic/MNM_mafs/'

# 2. List all files in the directory
files = [f for f in os.listdir(directory) if os.path.isfile(os.path.join(directory, f))]

# 3. Check if exactly one file exists
if len(files) > 1:
    file_path = os.path.join(directory, files[0])
    print(f"Found file: {file_path}")
    
    # 4. Read the file (auto-detect TSV)
    if file_path.endswith('.tsv'):
        df = pd.read_csv(file_path, sep='\t')
    else:
        print("Unsupported file format.")
        df = None
    
    # 5. Display the table if loaded
    if df is not None:
        display(df)
else:
    print(f"Expected 1 file, found {len(files)}: {files}")
# Out:
# Found file: mapping/classic/MNM_mafs/MNM_toys3.tsv
#   MNM_ID  UNIQUE-ID        CHEBI  \
# 0   MNM8        NaN          NaN
# 1   MNM9        NaN          NaN
# 2  MNM10        NaN          NaN
# 3  MNM11        NaN          NaN
# 4  MNM12        NaN  CHEBI:36023
# 5  MNM13        NaN  CHEBI:90488
# 6  MNM14        NaN          NaN
# 7  MNM15        NaN          NaN
# 8  MNM16        NaN  CHEBI:15756
#
#                                          COMMON-NAME  M/Z  \
# 0                                                NaN  NaN
# 1                                                NaN  NaN
# 2                                                NaN  NaN
# 3                                                NaN  NaN
# 4                                           vaccenic  NaN
# 5                                                NaN  NaN
# 6                                                NaN  NaN
# 7  delphinidin 3-O-(4-coumaroyl-rhamnosyl-(1?6)-g...  NaN
# 8                                                NaN  NaN
#
#                               INCHI-KEY  SMILES  SYNONYMS     BIGG   FORMULA
# 0                                   NaN     NaN       NaN    aprut       NaN
# 1                                   NaN     NaN       NaN      f1p       NaN
# 2                                   NaN     NaN       NaN  crnmock       NaN
# 3                                   NaN     NaN       NaN      NaN  C9H16NO5
# 4                                   NaN     NaN       NaN      NaN       NaN
# 5                                   NaN     NaN       NaN      NaN       NaN
# 6  InChIKey=AVVWPBAENSWJCB-VSOTGSRCSA-C     NaN       NaN      NaN       NaN
# 7                                   NaN     NaN       NaN      NaN       NaN
# 8                                   NaN     NaN       NaN      NaN       NaN

# %%
''' Show Classic mode results

'''
import os
import pandas as pd

# 1. Set the directory path
directory = 'mapping/classic/'

# 2. List all files in the directory
files = [f for f in os.listdir(directory) if os.path.isfile(os.path.join(directory, f))]

# 3. Check if exactly one file exists
if len(files) == 1:
    file_path = os.path.join(directory, files[0])
    print(f"Found file: {file_path}")
    
    # 4. Read the file (auto-detect TSV)
    if file_path.endswith('.tsv'):
        df = pd.read_csv(file_path, sep='\t')
    else:
        print("Unsupported file format.")
        df = None
    
    # 5. Display the table if loaded
    if df is not None:
        display(df)
else:
    print(f"Expected 1 file, found {len(files)}: {files}")
# Out:
# Found file: mapping/classic/mapping_results_2025-12-15_15_40_32.tsv
#               MNM_ID                                Metabolites in mafs  \
# 0               MNM3                     CPD-17381 _AND_ roquefortine C
# 1               MNM5                        CHEBI:84783 _AND_ CPD-25370
# 2               MNM1                                         CHEBI:4167
# 3               MNM6                          Adenine _AND_ CHEBI:16708
# 4   MNM2 _AND_ MNM19                      L-methionine _AND_ methionine
# 5   MNM7 _AND_ MNM27  Beta-D-galactosyl-(1->3)-N-acetyl-beta-D-gluco...
# 6              MNM20                        8-O-methylfusarubin alcohol
# 7              MNM17                                        orotic acid
# 8              MNM18                                 Carbamyl-phosphate
# 9              MNM21                                   pantothenic acid
# 10              MNM8                                              aprut
# 11              MNM9                                                f1p
# 12              MNM4               INCHIKEY=CGBYBGVMDAPUIH-ARJAWSKDSA-L
# 13             MNM22  CCCC(=O)OCC(/C=C=C1([C@](C)(O)C[C@@H](OC(=O)C)...
# 14             MNM10                                            crnmock
# 15             MNM11                                           C9H16NO5
# 16             MNM12                         CHEBI:36023 _AND_ vaccenic
# 17             MNM13                                        CHEBI:90488
# 18             MNM14               INCHIKEY=AVVWPBAENSWJCB-VSOTGSRCSA-C
# 19             MNM15  delphinidin 3-O-(4-coumaroyl-rhamnosyl-(1->6)-...
# 20             MNM16                                        CHEBI:15756
# 21             MNM23  C(S)[C@@H](C(NCCC(=O)[O-])=O)NC(=O)CC[C@@H](C(...
# 22             MNM24                     INCHIKEY=FSCYHDCTAZZSKN-DJNGBR
# 23             MNM26                                           thionine
#
#                                 Match in database Match in metabolic networks  \
# 0                                       CPD-17381                         NaN
# 1                                       CPD-25370                         NaN
# 2                                   Glucopyranose                         NaN
# 3                                         ADENINE                         NaN
# 4                                             MET                     ['MET']
# 5   Gal-13-GlcN-R _AND_ beta-Gal-13-beta-GlcNac-R           ['Gal-13-GlcN-R']
# 6                                       CPD-18186               ['CPD-18186']
# 7                                         OROTATE                 ['OROTATE']
# 8                                     CARBAMOYL-P      ['Carbamyl-phosphate']
# 9                                    PANTOTHENATE            ['PANTOTHENATE']
# 10                                        CPD-569                         NaN
# 11                          CPD-15970 _AND_ FRU1P                         NaN
# 12                                DIMETHYLMAL-CPD                         NaN
# 13                                      CPD-26454               ['CPD-26454']
# 14                                            NaN                         NaN
# 15                                            NaN                         NaN
# 16                                            NaN                         NaN
# 17                                            NaN                         NaN
# 18                                            NaN                         NaN
# 19                                            NaN                         NaN
# 20                                            NaN                         NaN
# 21                                            NaN                         NaN
# 22                                            NaN                         NaN
# 23                                            NaN                         NaN
#
#                                         Partial match Match via UNIQUE-ID  \
# 0                                                 NaN                 YES
# 1                                                 NaN                 YES
# 2                                                 NaN                 NaN
# 3                                                 NaN                 NaN
# 4                                    MNM2 _AND_ MNM19                 NaN
# 5   Gal-13-GlcN-R _AND_ beta-Gal-13-beta-GlcNac-R ...                 NaN
# 6                                                 NaN                 NaN
# 7                                                 NaN                 NaN
# 8                                                 NaN                 NaN
# 9                                                 NaN                 NaN
# 10                                                NaN                 NaN
# 11                              CPD-15970 _AND_ FRU1P                 NaN
# 12                                                NaN                 NaN
# 13                                                NaN                 NaN
# 14                                                NaN                 NaN
# 15                                                NaN                 NaN
# 16                                                NaN                 NaN
# 17                                                NaN                 NaN
# 18                                                NaN                 NaN
# 19                                                NaN                 NaN
# 20                                                NaN                 NaN
# 21                                                NaN                 NaN
# 22                                                NaN                 NaN
# 23                                                NaN                 NaN
#
#    Match via CHEBI Match via COMMON-NAME  Match via ABBREV-NAME  \
# 0              NaN                   YES                    NaN
# 1              YES                   NaN                    NaN
# 2              YES                   NaN                    NaN
# 3              YES                   YES                    NaN
# 4              NaN                   YES                    NaN
# 5              NaN                   YES                    NaN
# 6              NaN                   YES                    NaN
# 7              NaN                   NaN                    NaN
# 8              NaN                   NaN                    NaN
# 9              NaN                   NaN                    NaN
# 10             NaN                   NaN                    NaN
# 11             NaN                   NaN                    NaN
# 12             NaN                   NaN                    NaN
# 13             NaN                   NaN                    NaN
# 14             NaN                   NaN                    NaN
# 15             NaN                   NaN                    NaN
# 16             NaN                   NaN                    NaN
# 17             NaN                   NaN                    NaN
# 18             NaN                   NaN                    NaN
# 19             NaN                   NaN                    NaN
# 20             NaN                   NaN                    NaN
# 21             NaN                   NaN                    NaN
# 22             NaN                   NaN                    NaN
# 23             NaN                   NaN                    NaN
#
#    Match via SYNONYMS  ... Match via LIGAND-CPD  Match via REFMET  \
# 0                 NaN  ...                  NaN               NaN
# 1                 NaN  ...                  NaN               NaN
# 2                 NaN  ...                  NaN               NaN
# 3                 NaN  ...                  NaN               NaN
# 4                 NaN  ...                  NaN               NaN
# 5                 NaN  ...                  NaN               NaN
# 6                 NaN  ...                  NaN               NaN
# 7                 YES  ...                  NaN               NaN
# 8                 YES  ...                  NaN               NaN
# 9                 NaN  ...                  NaN               NaN
# 10                NaN  ...                  NaN               NaN
# 11                NaN  ...                  NaN               NaN
# 12                NaN  ...                  NaN               NaN
# 13                NaN  ...                  NaN               NaN
# 14                NaN  ...                  NaN               NaN
# 15                NaN  ...                  NaN               NaN
# 16                NaN  ...                  NaN               NaN
# 17                NaN  ...                  NaN               NaN
# 18                NaN  ...                  NaN               NaN
# 19                NaN  ...                  NaN               NaN
# 20                NaN  ...                  NaN               NaN
# 21                NaN  ...                  NaN               NaN
# 22                NaN  ...                  NaN               NaN
# 23                NaN  ...                  NaN               NaN
#
#     Match via PUBCHEM  Match via VMH Match via CAS  Match via INCHI  \
# 0                 NaN            NaN           NaN              NaN
# 1                 NaN            NaN           NaN              NaN
# 2                 NaN            NaN           NaN              NaN
# 3                 NaN            NaN           NaN              NaN
# 4                 NaN            NaN           NaN              NaN
# 5                 NaN            NaN           NaN              NaN
# 6                 NaN            NaN           NaN              NaN
# 7                 NaN            NaN           NaN              NaN
# 8                 NaN            NaN           NaN              NaN
# 9                 NaN            NaN           NaN              NaN
# 10                NaN            NaN           NaN              NaN
# 11                NaN            NaN           NaN              NaN
# 12                NaN            NaN           NaN              NaN
# 13                NaN            NaN           NaN              NaN
# 14                NaN            NaN           NaN              NaN
# 15                NaN            NaN           NaN              NaN
# 16                NaN            NaN           NaN              NaN
# 17                NaN            NaN           NaN              NaN
# 18                NaN            NaN           NaN              NaN
# 19                NaN            NaN           NaN              NaN
# 20                NaN            NaN           NaN              NaN
# 21                NaN            NaN           NaN              NaN
# 22                NaN            NaN           NaN              NaN
# 23                NaN            NaN           NaN              NaN
#
#     Match via NON-STANDARD-INCHI  Match via INCHI-KEY  Match via SMILES  \
# 0                            NaN                  NaN               NaN
# 1                            NaN                  NaN               NaN
# 2                            NaN                  NaN               NaN
# 3                            NaN                  NaN               NaN
# 4                            NaN                  NaN               NaN
# 5                            NaN                  NaN               NaN
# 6                            NaN                  NaN               NaN
# 7                            NaN                  NaN               NaN
# 8                            NaN                  NaN               NaN
# 9                            NaN                  NaN               NaN
# 10                           NaN                  NaN               NaN
# 11                           NaN                  NaN               NaN
# 12                           NaN                  YES               NaN
# 13                           NaN                  NaN               YES
# 14                           NaN                  NaN               NaN
# 15                           NaN                  NaN               NaN
# 16                           NaN                  NaN               NaN
# 17                           NaN                  NaN               NaN
# 18                           NaN                  NaN               NaN
# 19                           NaN                  NaN               NaN
# 20                           NaN                  NaN               NaN
# 21                           NaN                  NaN               NaN
# 22                           NaN                  NaN               NaN
# 23                           NaN                  NaN               NaN
#
#     Match via FORMULA
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
# 5                 NaN
# 6                 NaN
# 7                 NaN
# 8                 NaN
# 9                 NaN
# 10                NaN
# 11                NaN
# 12                NaN
# 13                NaN
# 14                NaN
# 15                NaN
# 16                NaN
# 17                NaN
# 18                NaN
# 19                NaN
# 20                NaN
# 21                NaN
# 22                NaN
# 23                NaN
#
# [24 rows x 28 columns]

# %% [markdown]
# ## Output File Content and Column Structure
#
# | **Column Name**                  | **Description**                                                                                                                                                       |
# |----------------------------------|-----------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# | `MNM_ID`                     | A unique identifier assigned to each metabolite entry in the MAF file, used to clearly track and distinguish individual rows after the mapping process. |
# | `Metabolites in mafs`                     | Name of the input metabolite (from the experimental data). May be a name, SMILES, InChIKey, or identifier. If multiple matches are found, they are joined with "\_AND\_".                                                       |
# | `Match in database`             | Main match found in the reference database (e.g., MetaCyc). May be a MetaCyc ID like `CPD-XXXX` or a named entity. Multiple matches are joined with "\_AND\_" and flagged in **Partial Match**.                                                   |
# | `Match in metabolic networks`    | List of metabolite matches in the metabolic network (SBML model). Typically uses short IDs like `met__L`. Returned as a list: `['met__L']`. In community mode, the list indicates each SBML model where the metabolite is present. The name is in the log for more details  |
# | ``Match IDS in metabolic networks`` | ONLY IN COMMUNITY: Metabolite identifiers corresponding to the matches found in the metabolic networks.                                                                                                                                        |
# | `Partial match`                  | Shows ambiguous or post-processed matches, e.g.: <br> - Duplicates <br> - CHEBI ontology expansion <br> - INCHIKEY simplification <br> - Enantiomer removal         |
# | `Match via UNIQUE-ID`           | Indicates whether a match was found using the MetaCyc `UNIQUE-ID` from the `datatable_conversion`. Displays `YES` if matched.                                        |
# | `Match via CHEBI`               | Match based on **ChEBI** identifier. Displays `YES` if a ChEBI ID in the data matched the network.                                                                   |
# | `Match via COMMON-NAME`         | Match based on common (non-abbreviated) name of the metabolite. E.g., `"methionine"`.                                                                                |
# | `Match via ABBREV-NAME`         | Match based on abbreviated names, often from SBML or COBRA models. E.g., `"met__L"`, `"pnto__R"`.                                                                    |
# | `Match via SYNONYMS`            | Match using any of the listed synonyms for the metabolite. Useful when matching trivial or alternate names.                                                          |
# | `Match via ADD-COMPLEMENT`      | Match using manually added complementary fields (from `ADD-COMPLEMENT` column in your input data).                                                                   |
# | `Match via BIGG`                | Match using **BiGG Models** identifiers. Typically abbreviated and used in genome-scale models.                                                                      |
# | `Match via HMDB`                | Match via **Human Metabolome Database (HMDB)** identifiers.                                                                                                           |
# | `Match via METANETX`            | Match via **MetaNetX** IDs, used for cross-database integration.                                                                                                     |
# | `Match via LIGAND-CPD`          | Match via identifiers from **KEGG Ligand** or other ligand-based databases.                                                                                          |
# | `Match via REFMET`              | Match via **RefMet**, a reference nomenclature system for metabolomics.                                                                                              |
# | `Match via PUBCHEM`             | Match via **PubChem Compound IDs (CIDs)**.                                                                                                                            |
# | `Match via CAS`                 | Match using **CAS numbers** (Chemical Abstracts Service).                                                                                                             |
# | `Match via INCHI-KEY`           | Match based on the **InChIKey**, a hashed version of the InChI chemical identifier.                                                                                   |
# | `Match via SMILES`              | Match via the **SMILES** string (Simplified Molecular Input Line Entry System) representing the molecular structure.                                                  |
# | `Match via FORMULA`             | Match based on **molecular formula**, e.g., `C6H12O6`.                                                                                                                |
# | `Input File Match`              | - **Classic mode**: Matched identifier from the original input file. <br> - **Community mode**: List of input files where the match was found, e.g., `[data1, data3]`. |

# %%
''' Run Classic mode with partial match
    The classic mode allows you to input a single metabolomics data file and a directory containing multiple metabolic networks.

'''

# !metanetmap classic -p -s ../src/metanetmap/toys_tests_data/toys/sbml/toys2.sbml -a ../src/metanetmap/toys_tests_data/toys/maf/ -d ../src/metanetmap/toys_tests_data/conversion_datatable_toys.tsv -o mapping/classic_partial/
# Out:
# 1614.46s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# -----------------------------------------
#             MAPPING METABOLITES
# -----------------------------------------
#
# ------> Main package version <------
# numpy version: 2.3.3
# pandas version: 2.3.2
# cobra version: 0.29.1
#
# Command run:
# Actual command run (from sys.argv): python /home/cmuller/miniconda3/envs/metanetmap/bin/metanetmap classic -p -s ../src/metanetmap/toys_tests_data/toys/sbml/toys2.sbml -a ../src/metanetmap/toys_tests_data/toys/maf/ -d ../src/metanetmap/toys_tests_data/conversion_datatable_toys.tsv -o mapping/classic_partial/
#
#
#
# ---->    MODE CLASSIC    <----
#
# Load metabolomics data user path: ../src/metanetmap/toys_tests_data/toys/maf/ and metabolic networks user path: ../src/metanetmap/toys_tests_data/toys/sbml/toys2.sbml
#
#
# ---------------PATHS-------------------
# List metabolomics data paths: ['../src/metanetmap/toys_tests_data/toys/maf/toys1.tsv', '../src/metanetmap/toys_tests_data/toys/maf/toys3.tsv', '../src/metanetmap/toys_tests_data/toys/maf/toys2.tsv']
# List metabolic networks paths: ['../src/metanetmap/toys_tests_data/toys/sbml/toys2.sbml']
#
#
# Output file successfully written to: mapping/classic_partial/MNM_mafs/MNM_toys1.tsv
#
# Output file successfully written to: mapping/classic_partial/MNM_mafs/MNM_toys3.tsv
#
# Output file successfully written to: mapping/classic_partial/MNM_mafs/MNM_toys2.tsv
#
#
# ----------------------------------------------
# ---------------MATCH STEP 1-------------------
# ----------------------------------------------
#
# <1> Direct matching test between metabolites derived from metabolomic data on all metadata in the metabolic network
# <2> Matching test between metabolites derived from metabolomic data on all metadata in the database conversion
#
# ++ Match step for "CPD-17381":
# --"CPD-17381" is present in database with the UNIQUE-ID "CPD-17381" and matches via "UNIQUE-ID"
#
# ++ Match step for "CPD-25370":
# --"CPD-25370" is present in database with the UNIQUE-ID "CPD-25370" and matches via "UNIQUE-ID"
#
# ++ Match step for "CHEBI:4167":
# --"CHEBI:4167" is present in database with the UNIQUE-ID "Glucopyranose" and matches via "CHEBI"
#
# ++ Match step for "CHEBI:84783":
# --"CHEBI:84783" is a metabolite duplicate of "CPD-25370" and matches via "CHEBI"
#
# ++ Match step for "CHEBI:16708":
# --"CHEBI:16708" is present in database with the UNIQUE-ID "ADENINE" and matches via "CHEBI"
#
# ++ Match step for "CHEBI:36023":
#
# ++ Match step for "CHEBI:90488":
#
# ++ Match step for "CHEBI:15756":
#
# ++ Match step for "CHEBI:123564":
#
# ++ Match step for "L-methionine":
# --"L-methionine" is present directly in metabolic network with the ID "['MET']" via "COMMON-NAME"
# --"L-methionine" is present in database with the UNIQUE-ID "MET" and matches via "COMMON-NAME"
#
# ++ Match step for "roquefortine C":
# --"roquefortine C" is a metabolite duplicate of "CPD-17381" and matches via "COMMON-NAME"
#
# ++ Match step for "Adenine":
# --"Adenine" is a metabolite duplicate of "CHEBI:16708" and matches via "COMMON-NAME"
#
# ++ Match step for "Beta-D-galactosyl-(1->3)-N-acetyl-beta-D-glucosaminyl-R":
# --"Beta-D-galactosyl-(1->3)-N-acetyl-beta-D-glucosaminyl-R" is present in database with the UNIQUE-ID "beta-Gal-13-beta-GlcNac-R" and matches via "COMMON-NAME"
# --"Beta-D-galactosyl-(1->3)-N-acetyl-beta-D-glucosaminyl-R" has a partial match. We have several UNIQUE-ID identifiers for this metabolite: "beta-Gal-13-beta-GlcNac-R" and "Gal-13-GlcN-R"
#
# ++ Match step for "vaccenic":
#
# ++ Match step for "delphinidin 3-O-(4-coumaroyl-rhamnosyl-(1->6)-glucoside":
#
# ++ Match step for "methionine":
# --"methionine" is a metabolite duplicate of "L-methionine" and matches via "COMMON-NAME"
# --"methionine" is a metabolite duplicate of "L-methionine" and matches via "COMMON-NAME"
#
# ++ Match step for "8-O-methylfusarubin alcohol":
# --"8-O-methylfusarubin alcohol" is present directly in metabolic network with the ID "['CPD-18186']" via "COMMON-NAME"
# --"8-O-methylfusarubin alcohol" is present in database with the UNIQUE-ID "CPD-18186" and matches via "COMMON-NAME"
#
# ++ Match step for "thionine":
#
# ++ Match step for "beta-D-galactosyl-(1->3)-N-acetyl-beta-D-glucosaminyl-R":
# --"beta-D-galactosyl-(1->3)-N-acetyl-beta-D-glucosaminyl-R" is a metabolite duplicate of "Beta-D-galactosyl-(1->3)-N-acetyl-beta-D-glucosaminyl-R" and matches via "COMMON-NAME"
#
# ++ Match step for "orotic acid":
# --"orotic acid" is present in database with the UNIQUE-ID "OROTATE" and matches via "SYNONYMS"
#
# ++ Match step for "Carbamyl-phosphate":
# --"Carbamyl-phosphate" is present directly in metabolic network with the ID "['Carbamyl-phosphate']" via "SYNONYMS"
# --"Carbamyl-phosphate" is present in database with the UNIQUE-ID "CARBAMOYL-P" and matches via "SYNONYMS"
#
# ++ Match step for "pantothenic acid":
# --"pantothenic acid" is present in database with the UNIQUE-ID "PANTOTHENATE" and matches via "ADD-COMPLEMENT"
#
# ++ Match step for "aprut":
# --"aprut" is present in database with the UNIQUE-ID "CPD-569" and matches via "BIGG"
#
# ++ Match step for "f1p":
# --"f1p" is present in database with the UNIQUE-ID "FRU1P" and matches via "BIGG"
# --"f1p" has a partial match. We have several UNIQUE-ID identifiers for this metabolite: "FRU1P" and "CPD-15970"
#
# ++ Match step for "crnmock":
#
# ++ Match step for "INCHIKEY=CGBYBGVMDAPUIH-ARJAWSKDSA-L":
# --"INCHIKEY=CGBYBGVMDAPUIH-ARJAWSKDSA-L" is present in database with the UNIQUE-ID "DIMETHYLMAL-CPD" and matches via "INCHI-KEY"
#
# ++ Match step for "INCHIKEY=AVVWPBAENSWJCB-VSOTGSRCSA-C":
#
# ++ Match step for "INCHIKEY=FSCYHDCTAZZSKN-DJNGBR":
#
# ++ Match step for "CCCC(=O)OCC(/C=C=C1([C@](C)(O)C[C@@H](OC(=O)C)CC(C)(C)1))=C/C=C/C(\C)=C/C=C/C=C(C)/C=C/C=C(C)/C(=O)C[C@]23(C(C)(C)C[C@H](O)C[C@@](C)(O2)3)":
# --"CCCC(=O)OCC(/C=C=C1([C@](C)(O)C[C@@H](OC(=O)C)CC(C)(C)1))=C/C=C/C(\C)=C/C=C/C=C(C)/C=C/C=C(C)/C(=O)C[C@]23(C(C)(C)C[C@H](O)C[C@@](C)(O2)3)" is present in database with the UNIQUE-ID "CPD-26454" and matches via "SMILES"
#
# ++ Match step for "C(S)[C@@H](C(NCCC(=O)[O-])=O)NC(=O)CC[C@@H](C([O-])=O)NC(=O)[C@H](CS)NC(=O)CC[C@H]([NH3+])C([O-])":
#
# ++ Match step for "C9H16NO5":
#
#
# ----------------------------------------------
# ---------------MATCH STEP 2-------------------
# ----------------------------------------------
#
# <3> Matching test on metabolites that matched only on the database conversion data against all metadata from the metabolic network
#
# --"Beta-D-galactosyl-(1->3)-N-acetyl-beta-D-glucosaminyl-R" is present directly in metabolic network with the corresponding ID "Gal-13-GlcN-R" via the match ID "gal-13-glcn-r"
# --"orotic acid" is present directly in metabolic network with the corresponding ID "OROTATE" via the match ID "orotate"
# --"pantothenic acid" is present directly in metabolic network with the corresponding ID "PANTOTHENATE" via the match ID "pantothenate"
# --"CCCC(=O)OCC(/C=C=C1([C@](C)(O)C[C@@H](OC(=O)C)CC(C)(C)1))=C/C=C/C(\C)=C/C=C/C=C(C)/C=C/C=C(C)/C(=O)C[C@]23(C(C)(C)C[C@H](O)C[C@@](C)(O2)3)" is present directly in metabolic network with the corresponding ID "CPD-26454" via the match ID "cpd-26454"
#
#
# ------------------------------------------------
# ---------------PARTIAL MATCH -------------------
# ----------------------------------------------
#
# <4> Attempting to find new IDs for unmatched metabolites using multiple strategies: removing enantiomer specificity, using the core part of InChIKeys, or exploring parent/child relationships in CHEBI.
#
#
# -----> CHEBI <-----
# Fetching ChEBI data:   0%|                                | 0/4 [00:00<?, ?it/s]
#  ++CHEBI identification step for CHEBI:36023:
#
#  ++CHEBI identification step for CHEBI:15756:
#
#  ++CHEBI identification step for CHEBI:36023:
#
#  ++CHEBI identification step for CHEBI:90488:
# --CHEBI:36023 is CHEBI:36023
#    --Parents are :
#      -- CHEBI:36023 is related to octadecenoic acid
#      -- CHEBI:36023 is related to straight-chain fatty acid
#    --Children are :
#      -- CHEBI:36023 is related to trans-vaccenic acid
#      -- CHEBI:36023 is related to cis-vaccenic acid
# --CHEBI:90488 is CHEBI:90488
#    --Parents are :
#      -- CHEBI:90488 is related to 1-phosphatidyl-1D-myo-inositol
# Fetching ChEBI data:  25%|██████                  | 1/4 [00:00<00:00,  3.43it/s]--CHEBI:36023 is CHEBI:36023
#    --Parents are :
#      -- vaccenic is related to octadecenoic acid
#      -- vaccenic is related to straight-chain fatty acid
#    --Children are :
#      -- vaccenic is related to trans-vaccenic acid
#      -- vaccenic is related to cis-vaccenic acid
# --CHEBI:15756 is CHEBI:15756
#    --Parents are :
#      -- CHEBI:15756 is related to straight-chain saturated fatty acid
#      -- CHEBI:15756 is related to long-chain fatty acid
#    --Children are :
#      -- CHEBI:15756 is related to 1-hexadecanoyl-2-methyl-sn-glycero-3-phosphocholine
# Fetching ChEBI data: 100%|████████████████████████| 4/4 [00:00<00:00, 10.83it/s]
#
# -----> inchikey <-----
# inchikey: INCHIKEY=FSCYHDCTAZZSKN-DJNGBR -> Short inchikey: ['INCHIKEY=FSCYHDCTAZZSKN']
# inchikey: INCHIKEY=AVVWPBAENSWJCB-VSOTGSRCSA-C -> Short inchikey: ['INCHIKEY=AVVWPBAENSWJCB']
#
# -----> Enantiomers <-----
# -----> Remove enantiomers in database and in metadata of sbml <-----
#
#
# ----------------------------------------------------
# ---------------Retry MATCH STEP 1-------------------
# ----------------------------------------------------
#
# -----> Test: CHEBI <-----
#
# ++ Match step for "CHEBI:36023":
#
# --Try with CHEBI:36023":
#
# --Try with vaccenic acid":
# --"CHEBI:36023" is present in database with the UNIQUE-ID "Vaccenate" and matches via "CHEBI"
#
# --Try with CHEBI:25634":
#
# --Try with octadecenoic acid":
#
# --Try with CHEBI:59202":
#
# --Try with straight-chain fatty acid":
#
# --Try with CHEBI:28727":
#
# --Try with trans-vaccenic acid":
# --"CHEBI:36023" has a partial match. We have several UNIQUE-ID identifiers for this metabolite: "Vaccenate" and "CPD-17257"
#
# --Try with CHEBI:50464":
#
# --Try with cis-vaccenic acid":
# --"CHEBI:36023" has a partial match. We have several UNIQUE-ID identifiers for this metabolite: "Vaccenate _AND_ CPD-17257" and "CPD-9247"
#
# ++ Match step for "CHEBI:90488":
#
# --Try with CHEBI:90488":
#
# --Try with phosphatidylinositol (18:1/20:4)":
#
# --Try with CHEBI:16749":
#
# --Try with 1-phosphatidyl-1D-myo-inositol":
#
# ++ Match step for "vaccenic":
#
# --Try with CHEBI:36023":
#
# --Try with vaccenic acid":
# --"vaccenic" is present in database with the UNIQUE-ID "Vaccenate" and matches via "CHEBI"
#
# --Try with CHEBI:25634":
#
# --Try with octadecenoic acid":
#
# --Try with CHEBI:59202":
#
# --Try with straight-chain fatty acid":
#
# --Try with CHEBI:28727":
#
# --Try with trans-vaccenic acid":
# --"vaccenic" has a partial match. We have several UNIQUE-ID identifiers for this metabolite: "Vaccenate" and "CPD-17257"
#
# --Try with CHEBI:50464":
#
# --Try with cis-vaccenic acid":
# --"vaccenic" is a metabolite duplicate of "CHEBI:36023" and matches via "CHEBI"
#
# ++ Match step for "CHEBI:15756":
#
# --Try with CHEBI:15756":
#
# --Try with hexadecanoic acid":
# --"CHEBI:15756" is present in database with the UNIQUE-ID "PALMITATE" and matches via "CHEBI"
#
# --Try with PALMITATE":
#
# --Try with CHEBI:39418":
#
# --Try with straight-chain saturated fatty acid":
#
# --Try with CHEBI:15904":
# --"CHEBI:15756" has a partial match. We have several UNIQUE-ID identifiers for this metabolite: "PALMITATE" and "Long-Chain-Fatty-Acids"
#
# --Try with long-chain fatty acid":
#
# --Try with CHEBI:131689":
#
# --Try with 1-hexadecanoyl-2-methyl-sn-glycero-3-phosphocholine":
#
# -----> Test: Inchey <-----
#
# ++ Match step for "INCHIKEY=FSCYHDCTAZZSKN":
#
# --Try with INCHIKEY=FSCYHDCTAZZSKN-DJNGBR":
#
# ++ Match step for "INCHIKEY=AVVWPBAENSWJCB":
#
# --Try with INCHIKEY=AVVWPBAENSWJCB-VSOTGSRCSA-C":
# --"INCHIKEY=AVVWPBAENSWJCB-VSOTGSRCSA-C" is present in database with the UNIQUE-ID "CPD-24978" and matches via "inchikey"
# --"INCHIKEY=AVVWPBAENSWJCB-VSOTGSRCSA-C" has a partial match. We have several UNIQUE-ID identifiers for this metabolite: "CPD-24978" and "CPD-25014"
# --"INCHIKEY=AVVWPBAENSWJCB-VSOTGSRCSA-C" has a partial match. We have several UNIQUE-ID identifiers for this metabolite: "CPD-24978 _AND_ CPD-25014" and "CPD-25010"
# --"INCHIKEY=AVVWPBAENSWJCB-VSOTGSRCSA-C" has a partial match. We have several UNIQUE-ID identifiers for this metabolite: "CPD-24978 _AND_ CPD-25014 _AND_ CPD-25010" and "CPD-16933"
# --"INCHIKEY=AVVWPBAENSWJCB-VSOTGSRCSA-C" has a partial match. We have several UNIQUE-ID identifiers for this metabolite: "CPD-24978 _AND_ CPD-25014 _AND_ CPD-25010 _AND_ CPD-16933" and "CPD-24986"
# --"INCHIKEY=AVVWPBAENSWJCB-VSOTGSRCSA-C" has a partial match. We have several UNIQUE-ID identifiers for this metabolite: "CPD-24978 _AND_ CPD-25014 _AND_ CPD-25010 _AND_ CPD-16933 _AND_ CPD-24986" and "CPD-24992"
# --"INCHIKEY=AVVWPBAENSWJCB-VSOTGSRCSA-C" has a partial match. We have several UNIQUE-ID identifiers for this metabolite: "CPD-24978 _AND_ CPD-25014 _AND_ CPD-25010 _AND_ CPD-16933 _AND_ CPD-24986 _AND_ CPD-24992" and "CPD-25011"
# --"INCHIKEY=AVVWPBAENSWJCB-VSOTGSRCSA-C" has a partial match. We have several UNIQUE-ID identifiers for this metabolite: "CPD-24978 _AND_ CPD-25014 _AND_ CPD-25010 _AND_ CPD-16933 _AND_ CPD-24986 _AND_ CPD-24992 _AND_ CPD-25011" and "CPD-25008"
# --"INCHIKEY=AVVWPBAENSWJCB-VSOTGSRCSA-C" has a partial match. We have several UNIQUE-ID identifiers for this metabolite: "CPD-24978 _AND_ CPD-25014 _AND_ CPD-25010 _AND_ CPD-16933 _AND_ CPD-24986 _AND_ CPD-24992 _AND_ CPD-25011 _AND_ CPD-25008" and "CPD-25020"
# --"INCHIKEY=AVVWPBAENSWJCB-VSOTGSRCSA-C" has a partial match. We have several UNIQUE-ID identifiers for this metabolite: "CPD-24978 _AND_ CPD-25014 _AND_ CPD-25010 _AND_ CPD-16933 _AND_ CPD-24986 _AND_ CPD-24992 _AND_ CPD-25011 _AND_ CPD-25008 _AND_ CPD-25020" and "CPD-24979"
# --"INCHIKEY=AVVWPBAENSWJCB-VSOTGSRCSA-C" has a partial match. We have several UNIQUE-ID identifiers for this metabolite: "CPD-24978 _AND_ CPD-25014 _AND_ CPD-25010 _AND_ CPD-16933 _AND_ CPD-24986 _AND_ CPD-24992 _AND_ CPD-25011 _AND_ CPD-25008 _AND_ CPD-25020 _AND_ CPD-24979" and "CPD-24991"
# --"INCHIKEY=AVVWPBAENSWJCB-VSOTGSRCSA-C" has a partial match. We have several UNIQUE-ID identifiers for this metabolite: "CPD-24978 _AND_ CPD-25014 _AND_ CPD-25010 _AND_ CPD-16933 _AND_ CPD-24986 _AND_ CPD-24992 _AND_ CPD-25011 _AND_ CPD-25008 _AND_ CPD-25020 _AND_ CPD-24979 _AND_ CPD-24991" and "CPD-24984"
# --"INCHIKEY=AVVWPBAENSWJCB-VSOTGSRCSA-C" has a partial match. We have several UNIQUE-ID identifiers for this metabolite: "CPD-24978 _AND_ CPD-25014 _AND_ CPD-25010 _AND_ CPD-16933 _AND_ CPD-24986 _AND_ CPD-24992 _AND_ CPD-25011 _AND_ CPD-25008 _AND_ CPD-25020 _AND_ CPD-24979 _AND_ CPD-24991 _AND_ CPD-24984" and "CPD-24997"
# --"INCHIKEY=AVVWPBAENSWJCB-VSOTGSRCSA-C" has a partial match. We have several UNIQUE-ID identifiers for this metabolite: "CPD-24978 _AND_ CPD-25014 _AND_ CPD-25010 _AND_ CPD-16933 _AND_ CPD-24986 _AND_ CPD-24992 _AND_ CPD-25011 _AND_ CPD-25008 _AND_ CPD-25020 _AND_ CPD-24979 _AND_ CPD-24991 _AND_ CPD-24984 _AND_ CPD-24997" and "CPD-25015"
# --"INCHIKEY=AVVWPBAENSWJCB-VSOTGSRCSA-C" has a partial match. We have several UNIQUE-ID identifiers for this metabolite: "CPD-24978 _AND_ CPD-25014 _AND_ CPD-25010 _AND_ CPD-16933 _AND_ CPD-24986 _AND_ CPD-24992 _AND_ CPD-25011 _AND_ CPD-25008 _AND_ CPD-25020 _AND_ CPD-24979 _AND_ CPD-24991 _AND_ CPD-24984 _AND_ CPD-24997 _AND_ CPD-25015" and "CPD-25019"
# --"INCHIKEY=AVVWPBAENSWJCB-VSOTGSRCSA-C" has a partial match. We have several UNIQUE-ID identifiers for this metabolite: "CPD-24978 _AND_ CPD-25014 _AND_ CPD-25010 _AND_ CPD-16933 _AND_ CPD-24986 _AND_ CPD-24992 _AND_ CPD-25011 _AND_ CPD-25008 _AND_ CPD-25020 _AND_ CPD-24979 _AND_ CPD-24991 _AND_ CPD-24984 _AND_ CPD-24997 _AND_ CPD-25015 _AND_ CPD-25019" and "CPD0-2486"
# --"INCHIKEY=AVVWPBAENSWJCB-VSOTGSRCSA-C" has a partial match. We have several UNIQUE-ID identifiers for this metabolite: "CPD-24978 _AND_ CPD-25014 _AND_ CPD-25010 _AND_ CPD-16933 _AND_ CPD-24986 _AND_ CPD-24992 _AND_ CPD-25011 _AND_ CPD-25008 _AND_ CPD-25020 _AND_ CPD-24979 _AND_ CPD-24991 _AND_ CPD-24984 _AND_ CPD-24997 _AND_ CPD-25015 _AND_ CPD-25019 _AND_ CPD0-2486" and "CPD-25006"
# --"INCHIKEY=AVVWPBAENSWJCB-VSOTGSRCSA-C" has a partial match. We have several UNIQUE-ID identifiers for this metabolite: "CPD-24978 _AND_ CPD-25014 _AND_ CPD-25010 _AND_ CPD-16933 _AND_ CPD-24986 _AND_ CPD-24992 _AND_ CPD-25011 _AND_ CPD-25008 _AND_ CPD-25020 _AND_ CPD-24979 _AND_ CPD-24991 _AND_ CPD-24984 _AND_ CPD-24997 _AND_ CPD-25015 _AND_ CPD-25019 _AND_ CPD0-2486 _AND_ CPD-25006" and "CPD-16934"
# --"INCHIKEY=AVVWPBAENSWJCB-VSOTGSRCSA-C" has a partial match. We have several UNIQUE-ID identifiers for this metabolite: "CPD-24978 _AND_ CPD-25014 _AND_ CPD-25010 _AND_ CPD-16933 _AND_ CPD-24986 _AND_ CPD-24992 _AND_ CPD-25011 _AND_ CPD-25008 _AND_ CPD-25020 _AND_ CPD-24979 _AND_ CPD-24991 _AND_ CPD-24984 _AND_ CPD-24997 _AND_ CPD-25015 _AND_ CPD-25019 _AND_ CPD0-2486 _AND_ CPD-25006 _AND_ CPD-16934" and "CPD-24952"
# --"INCHIKEY=AVVWPBAENSWJCB-VSOTGSRCSA-C" has a partial match. We have several UNIQUE-ID identifiers for this metabolite: "CPD-24978 _AND_ CPD-25014 _AND_ CPD-25010 _AND_ CPD-16933 _AND_ CPD-24986 _AND_ CPD-24992 _AND_ CPD-25011 _AND_ CPD-25008 _AND_ CPD-25020 _AND_ CPD-24979 _AND_ CPD-24991 _AND_ CPD-24984 _AND_ CPD-24997 _AND_ CPD-25015 _AND_ CPD-25019 _AND_ CPD0-2486 _AND_ CPD-25006 _AND_ CPD-16934 _AND_ CPD-24952" and "CPD-25013"
# --"INCHIKEY=AVVWPBAENSWJCB-VSOTGSRCSA-C" has a partial match. We have several UNIQUE-ID identifiers for this metabolite: "CPD-24978 _AND_ CPD-25014 _AND_ CPD-25010 _AND_ CPD-16933 _AND_ CPD-24986 _AND_ CPD-24992 _AND_ CPD-25011 _AND_ CPD-25008 _AND_ CPD-25020 _AND_ CPD-24979 _AND_ CPD-24991 _AND_ CPD-24984 _AND_ CPD-24997 _AND_ CPD-25015 _AND_ CPD-25019 _AND_ CPD0-2486 _AND_ CPD-25006 _AND_ CPD-16934 _AND_ CPD-24952 _AND_ CPD-25013" and "CPD-24951"
# --"INCHIKEY=AVVWPBAENSWJCB-VSOTGSRCSA-C" has a partial match. We have several UNIQUE-ID identifiers for this metabolite: "CPD-24978 _AND_ CPD-25014 _AND_ CPD-25010 _AND_ CPD-16933 _AND_ CPD-24986 _AND_ CPD-24992 _AND_ CPD-25011 _AND_ CPD-25008 _AND_ CPD-25020 _AND_ CPD-24979 _AND_ CPD-24991 _AND_ CPD-24984 _AND_ CPD-24997 _AND_ CPD-25015 _AND_ CPD-25019 _AND_ CPD0-2486 _AND_ CPD-25006 _AND_ CPD-16934 _AND_ CPD-24952 _AND_ CPD-25013 _AND_ CPD-24951" and "CPD-25012"
# --"INCHIKEY=AVVWPBAENSWJCB-VSOTGSRCSA-C" has a partial match. We have several UNIQUE-ID identifiers for this metabolite: "CPD-24978 _AND_ CPD-25014 _AND_ CPD-25010 _AND_ CPD-16933 _AND_ CPD-24986 _AND_ CPD-24992 _AND_ CPD-25011 _AND_ CPD-25008 _AND_ CPD-25020 _AND_ CPD-24979 _AND_ CPD-24991 _AND_ CPD-24984 _AND_ CPD-24997 _AND_ CPD-25015 _AND_ CPD-25019 _AND_ CPD0-2486 _AND_ CPD-25006 _AND_ CPD-16934 _AND_ CPD-24952 _AND_ CPD-25013 _AND_ CPD-24951 _AND_ CPD-25012" and "CPD0-2485"
# --"INCHIKEY=AVVWPBAENSWJCB-VSOTGSRCSA-C" has a partial match. We have several UNIQUE-ID identifiers for this metabolite: "CPD-24978 _AND_ CPD-25014 _AND_ CPD-25010 _AND_ CPD-16933 _AND_ CPD-24986 _AND_ CPD-24992 _AND_ CPD-25011 _AND_ CPD-25008 _AND_ CPD-25020 _AND_ CPD-24979 _AND_ CPD-24991 _AND_ CPD-24984 _AND_ CPD-24997 _AND_ CPD-25015 _AND_ CPD-25019 _AND_ CPD0-2486 _AND_ CPD-25006 _AND_ CPD-16934 _AND_ CPD-24952 _AND_ CPD-25013 _AND_ CPD-24951 _AND_ CPD-25012 _AND_ CPD0-2485" and "CPD-24996"
# --"INCHIKEY=AVVWPBAENSWJCB-VSOTGSRCSA-C" has a partial match. We have several UNIQUE-ID identifiers for this metabolite: "CPD-24978 _AND_ CPD-25014 _AND_ CPD-25010 _AND_ CPD-16933 _AND_ CPD-24986 _AND_ CPD-24992 _AND_ CPD-25011 _AND_ CPD-25008 _AND_ CPD-25020 _AND_ CPD-24979 _AND_ CPD-24991 _AND_ CPD-24984 _AND_ CPD-24997 _AND_ CPD-25015 _AND_ CPD-25019 _AND_ CPD0-2486 _AND_ CPD-25006 _AND_ CPD-16934 _AND_ CPD-24952 _AND_ CPD-25013 _AND_ CPD-24951 _AND_ CPD-25012 _AND_ CPD0-2485 _AND_ CPD-24996" and "CPD-24985"
# --"INCHIKEY=AVVWPBAENSWJCB-VSOTGSRCSA-C" has a partial match. We have several UNIQUE-ID identifiers for this metabolite: "CPD-24978 _AND_ CPD-25014 _AND_ CPD-25010 _AND_ CPD-16933 _AND_ CPD-24986 _AND_ CPD-24992 _AND_ CPD-25011 _AND_ CPD-25008 _AND_ CPD-25020 _AND_ CPD-24979 _AND_ CPD-24991 _AND_ CPD-24984 _AND_ CPD-24997 _AND_ CPD-25015 _AND_ CPD-25019 _AND_ CPD0-2486 _AND_ CPD-25006 _AND_ CPD-16934 _AND_ CPD-24952 _AND_ CPD-25013 _AND_ CPD-24951 _AND_ CPD-25012 _AND_ CPD0-2485 _AND_ CPD-24996 _AND_ CPD-24985" and "CPD-24990"
# --"INCHIKEY=AVVWPBAENSWJCB-VSOTGSRCSA-C" has a partial match. We have several UNIQUE-ID identifiers for this metabolite: "CPD-24978 _AND_ CPD-25014 _AND_ CPD-25010 _AND_ CPD-16933 _AND_ CPD-24986 _AND_ CPD-24992 _AND_ CPD-25011 _AND_ CPD-25008 _AND_ CPD-25020 _AND_ CPD-24979 _AND_ CPD-24991 _AND_ CPD-24984 _AND_ CPD-24997 _AND_ CPD-25015 _AND_ CPD-25019 _AND_ CPD0-2486 _AND_ CPD-25006 _AND_ CPD-16934 _AND_ CPD-24952 _AND_ CPD-25013 _AND_ CPD-24951 _AND_ CPD-25012 _AND_ CPD0-2485 _AND_ CPD-24996 _AND_ CPD-24985 _AND_ CPD-24990" and "CPD-24983"
# --"INCHIKEY=AVVWPBAENSWJCB-VSOTGSRCSA-C" has a partial match. We have several UNIQUE-ID identifiers for this metabolite: "CPD-24978 _AND_ CPD-25014 _AND_ CPD-25010 _AND_ CPD-16933 _AND_ CPD-24986 _AND_ CPD-24992 _AND_ CPD-25011 _AND_ CPD-25008 _AND_ CPD-25020 _AND_ CPD-24979 _AND_ CPD-24991 _AND_ CPD-24984 _AND_ CPD-24997 _AND_ CPD-25015 _AND_ CPD-25019 _AND_ CPD0-2486 _AND_ CPD-25006 _AND_ CPD-16934 _AND_ CPD-24952 _AND_ CPD-25013 _AND_ CPD-24951 _AND_ CPD-25012 _AND_ CPD0-2485 _AND_ CPD-24996 _AND_ CPD-24985 _AND_ CPD-24990 _AND_ CPD-24983" and "CPD-25009"
# --"INCHIKEY=AVVWPBAENSWJCB-VSOTGSRCSA-C" has a partial match. We have several UNIQUE-ID identifiers for this metabolite: "CPD-24978 _AND_ CPD-25014 _AND_ CPD-25010 _AND_ CPD-16933 _AND_ CPD-24986 _AND_ CPD-24992 _AND_ CPD-25011 _AND_ CPD-25008 _AND_ CPD-25020 _AND_ CPD-24979 _AND_ CPD-24991 _AND_ CPD-24984 _AND_ CPD-24997 _AND_ CPD-25015 _AND_ CPD-25019 _AND_ CPD0-2486 _AND_ CPD-25006 _AND_ CPD-16934 _AND_ CPD-24952 _AND_ CPD-25013 _AND_ CPD-24951 _AND_ CPD-25012 _AND_ CPD0-2485 _AND_ CPD-24996 _AND_ CPD-24985 _AND_ CPD-24990 _AND_ CPD-24983 _AND_ CPD-25009" and "CPD-24993"
# --"INCHIKEY=AVVWPBAENSWJCB-VSOTGSRCSA-C" has a partial match. We have several UNIQUE-ID identifiers for this metabolite: "CPD-24978 _AND_ CPD-25014 _AND_ CPD-25010 _AND_ CPD-16933 _AND_ CPD-24986 _AND_ CPD-24992 _AND_ CPD-25011 _AND_ CPD-25008 _AND_ CPD-25020 _AND_ CPD-24979 _AND_ CPD-24991 _AND_ CPD-24984 _AND_ CPD-24997 _AND_ CPD-25015 _AND_ CPD-25019 _AND_ CPD0-2486 _AND_ CPD-25006 _AND_ CPD-16934 _AND_ CPD-24952 _AND_ CPD-25013 _AND_ CPD-24951 _AND_ CPD-25012 _AND_ CPD0-2485 _AND_ CPD-24996 _AND_ CPD-24985 _AND_ CPD-24990 _AND_ CPD-24983 _AND_ CPD-25009 _AND_ CPD-24993" and "CPD-25005"
# --"INCHIKEY=AVVWPBAENSWJCB-VSOTGSRCSA-C" has a partial match. We have several UNIQUE-ID identifiers for this metabolite: "CPD-24978 _AND_ CPD-25014 _AND_ CPD-25010 _AND_ CPD-16933 _AND_ CPD-24986 _AND_ CPD-24992 _AND_ CPD-25011 _AND_ CPD-25008 _AND_ CPD-25020 _AND_ CPD-24979 _AND_ CPD-24991 _AND_ CPD-24984 _AND_ CPD-24997 _AND_ CPD-25015 _AND_ CPD-25019 _AND_ CPD0-2486 _AND_ CPD-25006 _AND_ CPD-16934 _AND_ CPD-24952 _AND_ CPD-25013 _AND_ CPD-24951 _AND_ CPD-25012 _AND_ CPD0-2485 _AND_ CPD-24996 _AND_ CPD-24985 _AND_ CPD-24990 _AND_ CPD-24983 _AND_ CPD-25009 _AND_ CPD-24993 _AND_ CPD-25005" and "CPD-25004"
# --"INCHIKEY=AVVWPBAENSWJCB-VSOTGSRCSA-C" has a partial match. We have several UNIQUE-ID identifiers for this metabolite: "CPD-24978 _AND_ CPD-25014 _AND_ CPD-25010 _AND_ CPD-16933 _AND_ CPD-24986 _AND_ CPD-24992 _AND_ CPD-25011 _AND_ CPD-25008 _AND_ CPD-25020 _AND_ CPD-24979 _AND_ CPD-24991 _AND_ CPD-24984 _AND_ CPD-24997 _AND_ CPD-25015 _AND_ CPD-25019 _AND_ CPD0-2486 _AND_ CPD-25006 _AND_ CPD-16934 _AND_ CPD-24952 _AND_ CPD-25013 _AND_ CPD-24951 _AND_ CPD-25012 _AND_ CPD0-2485 _AND_ CPD-24996 _AND_ CPD-24985 _AND_ CPD-24990 _AND_ CPD-24983 _AND_ CPD-25009 _AND_ CPD-24993 _AND_ CPD-25005 _AND_ CPD-25004" and "CPD-25007"
#
# -----> Test: Enantiomers <-----
#
# ++ Match step for "delphinidin 3-O-(4-coumaroyl-rhamnosyl-(1->6)-glucoside":
# --"delphinidin 3-O-(4-coumaroyl-rhamnosyl-(1->6)-glucoside" is present in database with the UNIQUE-ID "CPD-22089" and matches via "Enantiomers"
#
# ++ Match step for "crnmock":
#
# ++ Match step for "thionine":
#
# ++ Match step for "C(S)[C@@H](C(NCCC(=O)[O-])=O)NC(=O)CC[C@@H](C([O-])=O)NC(=O)[C@H](CS)NC(=O)CC[C@H]([NH3+])C([O-])":
#
# ++ Match step for "C9H16NO5":
#
#
# ----------------------------------------------------
# ---------------Retry MATCH STEP 2-------------------
# ----------------------------------------------------
#
# -------------------- SUMMARY REPORT --------------------
#
#
# Recap of Matches:
#   + Matched metabolites: 7
#   + Unmatched metabolites: 17
#   + Partial matches: 7
#
#  Match Details:
#   --> Full match (database + SBML): 7
#   --> Partial match + metabolic info: 2
#   --> Match only in SBML: 0
#
#  Unmatch Details:
#   --> Full unmatch (no match in DB or SBML): 6
#   --> Match in DB but not in SBML: 11
#   --> Partial match in DB only: 5
#
# --------------------------------------------------------
#
# Output file successfully written to: mapping/classic_partial/mapping_results_partial_match_2025-12-15_15_40_38.tsv
#
# --- Total runtime 0.47 seconds ---
#  ---> MAPPING COMPLETED'

# %%
''' Show Classic mode partial match results

'''
import os
import pandas as pd

# 1. Set the directory path
directory = 'mapping/classic_partial/'

# 2. List all files in the directory
files = [f for f in os.listdir(directory) if os.path.isfile(os.path.join(directory, f))]

# 3. Check if exactly one file exists
if len(files) == 1:
    file_path = os.path.join(directory, files[0])
    print(f"Found file: {file_path}")
    
    # 4. Read the file (auto-detect TSV)
    if file_path.endswith('.tsv'):
        df = pd.read_csv(file_path, sep='\t')
    else:
        print("Unsupported file format.")
        df = None
    
    # 5. Display the table if loaded
    if df is not None:
        display(df)
else:
    print(f"Expected 1 file, found {len(files)}: {files}")
# Out:
# Found file: mapping/classic_partial/mapping_results_partial_match_2025-12-15_15_40_38.tsv
#               MNM_ID                                Metabolites in mafs  \
# 0               MNM3                     CPD-17381 _AND_ roquefortine C
# 1               MNM5                        CHEBI:84783 _AND_ CPD-25370
# 2               MNM1                                         CHEBI:4167
# 3               MNM6                          Adenine _AND_ CHEBI:16708
# 4   MNM2 _AND_ MNM19                      L-methionine _AND_ methionine
# 5   MNM7 _AND_ MNM27  Beta-D-galactosyl-(1->3)-N-acetyl-beta-D-gluco...
# 6              MNM20                        8-O-methylfusarubin alcohol
# 7              MNM17                                        orotic acid
# 8              MNM18                                 Carbamyl-phosphate
# 9              MNM21                                   pantothenic acid
# 10              MNM8                                              aprut
# 11              MNM9                                                f1p
# 12              MNM4               INCHIKEY=CGBYBGVMDAPUIH-ARJAWSKDSA-L
# 13             MNM22  CCCC(=O)OCC(/C=C=C1([C@](C)(O)C[C@@H](OC(=O)C)...
# 14             MNM12                         CHEBI:36023 _AND_ vaccenic
# 15             MNM16                                        CHEBI:15756
# 16             MNM14               INCHIKEY=AVVWPBAENSWJCB-VSOTGSRCSA-C
# 17             MNM15  delphinidin 3-O-(4-coumaroyl-rhamnosyl-(1->6)-...
# 18             MNM10                                            crnmock
# 19             MNM11                                           C9H16NO5
# 20             MNM13                                        CHEBI:90488
# 21             MNM23  C(S)[C@@H](C(NCCC(=O)[O-])=O)NC(=O)CC[C@@H](C(...
# 22             MNM24                     INCHIKEY=FSCYHDCTAZZSKN-DJNGBR
# 23             MNM26                                           thionine
#
#                                     Match in database  \
# 0                                           CPD-17381
# 1                                           CPD-25370
# 2                                       Glucopyranose
# 3                                             ADENINE
# 4                                                 MET
# 5       Gal-13-GlcN-R _AND_ beta-Gal-13-beta-GlcNac-R
# 6                                           CPD-18186
# 7                                             OROTATE
# 8                                         CARBAMOYL-P
# 9                                        PANTOTHENATE
# 10                                            CPD-569
# 11                              CPD-15970 _AND_ FRU1P
# 12                                    DIMETHYLMAL-CPD
# 13                                          CPD-26454
# 14           CPD-17257 _AND_ CPD-9247 _AND_ Vaccenate
# 15             Long-Chain-Fatty-Acids _AND_ PALMITATE
# 16  CPD-16933 _AND_ CPD-16934 _AND_ CPD-24951 _AND...
# 17                                          CPD-22089
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
#
#    Match in metabolic networks  \
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4                      ['MET']
# 5            ['Gal-13-GlcN-R']
# 6                ['CPD-18186']
# 7                  ['OROTATE']
# 8       ['Carbamyl-phosphate']
# 9             ['PANTOTHENATE']
# 10                         NaN
# 11                         NaN
# 12                         NaN
# 13               ['CPD-26454']
# 14                         NaN
# 15                         NaN
# 16                         NaN
# 17                         NaN
# 18                         NaN
# 19                         NaN
# 20                         NaN
# 21                         NaN
# 22                         NaN
# 23                         NaN
#
#                                         Partial match Match via UNIQUE-ID  \
# 0                                                 NaN                 YES
# 1                                                 NaN                 YES
# 2                                                 NaN                 NaN
# 3                                                 NaN                 NaN
# 4                                    MNM2 _AND_ MNM19                 NaN
# 5   Gal-13-GlcN-R _AND_ beta-Gal-13-beta-GlcNac-R ...                 NaN
# 6                                                 NaN                 NaN
# 7                                                 NaN                 NaN
# 8                                                 NaN                 NaN
# 9                                                 NaN                 NaN
# 10                                                NaN                 NaN
# 11                              CPD-15970 _AND_ FRU1P                 NaN
# 12                                                NaN                 NaN
# 13                                                NaN                 NaN
# 14           CPD-17257 _AND_ CPD-9247 _AND_ Vaccenate                 NaN
# 15             Long-Chain-Fatty-Acids _AND_ PALMITATE                 NaN
# 16  CPD-16933 _AND_ CPD-16934 _AND_ CPD-24951 _AND...                 NaN
# 17                                          CPD-22089                 NaN
# 18                                                NaN                 NaN
# 19                                                NaN                 NaN
# 20                                                NaN                 NaN
# 21                                                NaN                 NaN
# 22                                                NaN                 NaN
# 23                                                NaN                 NaN
#
#    Match via CHEBI Match via COMMON-NAME  Match via ABBREV-NAME  \
# 0              NaN                   YES                    NaN
# 1              YES                   NaN                    NaN
# 2              YES                   NaN                    NaN
# 3              YES                   YES                    NaN
# 4              NaN                   YES                    NaN
# 5              NaN                   YES                    NaN
# 6              NaN                   YES                    NaN
# 7              NaN                   NaN                    NaN
# 8              NaN                   NaN                    NaN
# 9              NaN                   NaN                    NaN
# 10             NaN                   NaN                    NaN
# 11             NaN                   NaN                    NaN
# 12             NaN                   NaN                    NaN
# 13             NaN                   NaN                    NaN
# 14             YES                   NaN                    NaN
# 15             YES                   NaN                    NaN
# 16             NaN                   NaN                    NaN
# 17             NaN                   NaN                    NaN
# 18             NaN                   NaN                    NaN
# 19             NaN                   NaN                    NaN
# 20             NaN                   NaN                    NaN
# 21             NaN                   NaN                    NaN
# 22             NaN                   NaN                    NaN
# 23             NaN                   NaN                    NaN
#
#    Match via SYNONYMS  ... Match via LIGAND-CPD  Match via REFMET  \
# 0                 NaN  ...                  NaN               NaN
# 1                 NaN  ...                  NaN               NaN
# 2                 NaN  ...                  NaN               NaN
# 3                 NaN  ...                  NaN               NaN
# 4                 NaN  ...                  NaN               NaN
# 5                 NaN  ...                  NaN               NaN
# 6                 NaN  ...                  NaN               NaN
# 7                 YES  ...                  NaN               NaN
# 8                 YES  ...                  NaN               NaN
# 9                 NaN  ...                  NaN               NaN
# 10                NaN  ...                  NaN               NaN
# 11                NaN  ...                  NaN               NaN
# 12                NaN  ...                  NaN               NaN
# 13                NaN  ...                  NaN               NaN
# 14                NaN  ...                  NaN               NaN
# 15                NaN  ...                  NaN               NaN
# 16                NaN  ...                  NaN               NaN
# 17                NaN  ...                  NaN               NaN
# 18                NaN  ...                  NaN               NaN
# 19                NaN  ...                  NaN               NaN
# 20                NaN  ...                  NaN               NaN
# 21                NaN  ...                  NaN               NaN
# 22                NaN  ...                  NaN               NaN
# 23                NaN  ...                  NaN               NaN
#
#     Match via PUBCHEM  Match via VMH Match via CAS  Match via INCHI  \
# 0                 NaN            NaN           NaN              NaN
# 1                 NaN            NaN           NaN              NaN
# 2                 NaN            NaN           NaN              NaN
# 3                 NaN            NaN           NaN              NaN
# 4                 NaN            NaN           NaN              NaN
# 5                 NaN            NaN           NaN              NaN
# 6                 NaN            NaN           NaN              NaN
# 7                 NaN            NaN           NaN              NaN
# 8                 NaN            NaN           NaN              NaN
# 9                 NaN            NaN           NaN              NaN
# 10                NaN            NaN           NaN              NaN
# 11                NaN            NaN           NaN              NaN
# 12                NaN            NaN           NaN              NaN
# 13                NaN            NaN           NaN              NaN
# 14                NaN            NaN           NaN              NaN
# 15                NaN            NaN           NaN              NaN
# 16                NaN            NaN           NaN              NaN
# 17                NaN            NaN           NaN              NaN
# 18                NaN            NaN           NaN              NaN
# 19                NaN            NaN           NaN              NaN
# 20                NaN            NaN           NaN              NaN
# 21                NaN            NaN           NaN              NaN
# 22                NaN            NaN           NaN              NaN
# 23                NaN            NaN           NaN              NaN
#
#     Match via NON-STANDARD-INCHI  Match via INCHI-KEY  Match via SMILES  \
# 0                            NaN                  NaN               NaN
# 1                            NaN                  NaN               NaN
# 2                            NaN                  NaN               NaN
# 3                            NaN                  NaN               NaN
# 4                            NaN                  NaN               NaN
# 5                            NaN                  NaN               NaN
# 6                            NaN                  NaN               NaN
# 7                            NaN                  NaN               NaN
# 8                            NaN                  NaN               NaN
# 9                            NaN                  NaN               NaN
# 10                           NaN                  NaN               NaN
# 11                           NaN                  NaN               NaN
# 12                           NaN                  YES               NaN
# 13                           NaN                  NaN               YES
# 14                           NaN                  NaN               NaN
# 15                           NaN                  NaN               NaN
# 16                           NaN                  NaN               NaN
# 17                           NaN                  NaN               NaN
# 18                           NaN                  NaN               NaN
# 19                           NaN                  NaN               NaN
# 20                           NaN                  NaN               NaN
# 21                           NaN                  NaN               NaN
# 22                           NaN                  NaN               NaN
# 23                           NaN                  NaN               NaN
#
#     Match via FORMULA
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
# 5                 NaN
# 6                 NaN
# 7                 NaN
# 8                 NaN
# 9                 NaN
# 10                NaN
# 11                NaN
# 12                NaN
# 13                NaN
# 14                NaN
# 15                NaN
# 16                NaN
# 17                NaN
# 18                NaN
# 19                NaN
# 20                NaN
# 21                NaN
# 22                NaN
# 23                NaN
#
# [24 rows x 28 columns]

# %%
''' Run Community mode results
   The "community" mode allows you to input a directory containing multiple metabolomics data files, as well as a directory containing multiple metabolic networks.


'''

# !metanetmap community -s ../src/metanetmap/toys_tests_data/toys/sbml/ -a ../src/metanetmap/toys_tests_data/toys/maf/ -d ../src/metanetmap/toys_tests_data/conversion_datatable_toys.tsv -o mapping/community/
# Out:
# 1621.02s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# -----------------------------------------
#             MAPPING METABOLITES
# -----------------------------------------
#
# ------> Main package version <------
# numpy version: 2.3.3
# pandas version: 2.3.2
# cobra version: 0.29.1
#
# Command run:
# Actual command run (from sys.argv): python /home/cmuller/miniconda3/envs/metanetmap/bin/metanetmap community -s ../src/metanetmap/toys_tests_data/toys/sbml/ -a ../src/metanetmap/toys_tests_data/toys/maf/ -d ../src/metanetmap/toys_tests_data/conversion_datatable_toys.tsv -o mapping/community/
#
#
# ---->    MODE COMMUNITY    <----
# Load metabolomics data user path: ../src/metanetmap/toys_tests_data/toys/maf/ and metabolic networks user path: ../src/metanetmap/toys_tests_data/toys/sbml/
#
# ---------------PATHS-------------------
# List metabolomics data paths: ['../src/metanetmap/toys_tests_data/toys/maf/toys1.tsv', '../src/metanetmap/toys_tests_data/toys/maf/toys3.tsv', '../src/metanetmap/toys_tests_data/toys/maf/toys2.tsv']
# List metabolic networks paths: ['../src/metanetmap/toys_tests_data/toys/sbml/toys1.sbml', '../src/metanetmap/toys_tests_data/toys/sbml/toys3.xml', '../src/metanetmap/toys_tests_data/toys/sbml/toys2.sbml']
#
# Output file successfully written to: mapping/community/MNM_mafs/MNM_toys1.tsv
#
# Output file successfully written to: mapping/community/MNM_mafs/MNM_toys3.tsv
#
# Output file successfully written to: mapping/community/MNM_mafs/MNM_toys2.tsv
#
#
# ----------------------------------------------
# ---------------MATCH STEP 1-------------------
# ----------------------------------------------
#
# <1> Direct matching test between metabolites derived from metabolomic data on all metadata in the metabolic network
# <2> Matching test between metabolites derived from metabolomic data on all metadata in the database conversion
#
# ++ Match step for "CPD-17381":
# --"CPD-17381" is present in database with the UNIQUE-ID "CPD-17381" and matches via "UNIQUE-ID"
#
# ++ Match step for "CPD-25370":
# --"CPD-25370" is present directly in "toys1" metabolic network with the ID "CPD-25370" via "UNIQUE-ID"
# --"CPD-25370" is present in database with the UNIQUE-ID "CPD-25370" and matches via "UNIQUE-ID"
#
# ++ Match step for "CHEBI:4167":
# --"CHEBI:4167" is present directly in "toys3" metabolic network with the ID "glc__D" via "CHEBI"
# --"CHEBI:4167" is present in database with the UNIQUE-ID "Glucopyranose" and matches via "CHEBI"
#
# ++ Match step for "CHEBI:84783":
# --"CHEBI:84783" is a metabolite duplicate of "CPD-25370" and matches via "CHEBI"
#
# ++ Match step for "CHEBI:16708":
# --"CHEBI:16708" is present directly in "toys3" metabolic network with the ID "ade" via "CHEBI"
# --"CHEBI:16708" is present in database with the UNIQUE-ID "ADENINE" and matches via "CHEBI"
#
# ++ Match step for "CHEBI:36023":
#
# ++ Match step for "CHEBI:90488":
#
# ++ Match step for "CHEBI:15756":
#
# ++ Match step for "CHEBI:123564":
#
# ++ Match step for "L-methionine":
# --"L-methionine" is present directly in "toys3" metabolic network with the ID "met__L" via "COMMON-NAME"
# --"L-methionine" is present directly in "toys1" metabolic network with the ID "MET" via "COMMON-NAME"
# --"L-methionine" is present in database with the UNIQUE-ID "MET" and matches via "COMMON-NAME"
#
# ++ Match step for "roquefortine C":
# --"roquefortine C" is a metabolite duplicate of "CPD-17381" and matches via "COMMON-NAME"
#
# ++ Match step for "Adenine":
# --"Adenine" is present directly in "toys1" metabolic network with the ID "ADENINE" via "COMMON-NAME"
# --"Adenine" is present directly in "toys3" metabolic network with the ID "ade" via "COMMON-NAME"
# --"Adenine" is a metabolite duplicate of "CHEBI:16708" and matches via "COMMON-NAME"
#
# ++ Match step for "Beta-D-galactosyl-(1->3)-N-acetyl-beta-D-glucosaminyl-R":
# --"Beta-D-galactosyl-(1->3)-N-acetyl-beta-D-glucosaminyl-R" is present in database with the UNIQUE-ID "beta-Gal-13-beta-GlcNac-R" and matches via "COMMON-NAME"
# --"Beta-D-galactosyl-(1->3)-N-acetyl-beta-D-glucosaminyl-R" has a partial match. We have several UNIQUE-ID identifiers for this metabolite: "beta-Gal-13-beta-GlcNac-R" and "Gal-13-GlcN-R"
#
# ++ Match step for "vaccenic":
#
# ++ Match step for "delphinidin 3-O-(4-coumaroyl-rhamnosyl-(1->6)-glucoside":
#
# ++ Match step for "methionine":
# --"methionine" is a metabolite duplicate of "L-methionine" and matches via "COMMON-NAME"
#
# ++ Match step for "8-O-methylfusarubin alcohol":
# --"8-O-methylfusarubin alcohol" is present directly in "toys2" metabolic network with the ID "CPD-18186" via "COMMON-NAME"
# --"8-O-methylfusarubin alcohol" is present in database with the UNIQUE-ID "CPD-18186" and matches via "COMMON-NAME"
#
# ++ Match step for "thionine":
#
# ++ Match step for "beta-D-galactosyl-(1->3)-N-acetyl-beta-D-glucosaminyl-R":
# --"beta-D-galactosyl-(1->3)-N-acetyl-beta-D-glucosaminyl-R" is a metabolite duplicate of "Beta-D-galactosyl-(1->3)-N-acetyl-beta-D-glucosaminyl-R" and matches via "COMMON-NAME"
#
# ++ Match step for "orotic acid":
# --"orotic acid" is present in database with the UNIQUE-ID "OROTATE" and matches via "SYNONYMS"
#
# ++ Match step for "Carbamyl-phosphate":
# --"Carbamyl-phosphate" is present directly in "toys2" metabolic network with the ID "Carbamyl-phosphate" via "SYNONYMS"
# --"Carbamyl-phosphate" is present in database with the UNIQUE-ID "CARBAMOYL-P" and matches via "SYNONYMS"
#
# ++ Match step for "pantothenic acid":
# --"pantothenic acid" is present in database with the UNIQUE-ID "PANTOTHENATE" and matches via "ADD-COMPLEMENT"
#
# ++ Match step for "aprut":
# --"aprut" is present in database with the UNIQUE-ID "CPD-569" and matches via "BIGG"
#
# ++ Match step for "f1p":
# --"f1p" is present directly in "toys3" metabolic network with the ID "f1p" via "BIGG"
# --"f1p" is present in database with the UNIQUE-ID "FRU1P" and matches via "BIGG"
# --"f1p" is present in database with the UNIQUE-ID "CPD-15970" and matches via "BIGG"
# --"f1p" has a partial match. We have several UNIQUE-ID identifiers for this metabolite: "CPD-15970 _AND_ FRU1P
#
# ++ Match step for "crnmock":
# --"crnmock" is present directly in "toys3" metabolic network with the ID "crnmock" via "BIGG"
# --"crnmock" is present directly in "toys3" metabolic network with the ID "crn__D" via "BIGG"
#
# ++ Match step for "INCHIKEY=CGBYBGVMDAPUIH-ARJAWSKDSA-L":
# --"INCHIKEY=CGBYBGVMDAPUIH-ARJAWSKDSA-L" is present in database with the UNIQUE-ID "DIMETHYLMAL-CPD" and matches via "INCHI-KEY"
#
# ++ Match step for "INCHIKEY=AVVWPBAENSWJCB-VSOTGSRCSA-C":
#
# ++ Match step for "INCHIKEY=FSCYHDCTAZZSKN-DJNGBR":
#
# ++ Match step for "CCCC(=O)OCC(/C=C=C1([C@](C)(O)C[C@@H](OC(=O)C)CC(C)(C)1))=C/C=C/C(\C)=C/C=C/C=C(C)/C=C/C=C(C)/C(=O)C[C@]23(C(C)(C)C[C@H](O)C[C@@](C)(O2)3)":
# --"CCCC(=O)OCC(/C=C=C1([C@](C)(O)C[C@@H](OC(=O)C)CC(C)(C)1))=C/C=C/C(\C)=C/C=C/C=C(C)/C=C/C=C(C)/C(=O)C[C@]23(C(C)(C)C[C@H](O)C[C@@](C)(O2)3)" is present in database with the UNIQUE-ID "CPD-26454" and matches via "SMILES"
#
# ++ Match step for "C(S)[C@@H](C(NCCC(=O)[O-])=O)NC(=O)CC[C@@H](C([O-])=O)NC(=O)[C@H](CS)NC(=O)CC[C@H]([NH3+])C([O-])":
#
# ++ Match step for "C9H16NO5":
# --"C9H16NO5" is present directly in "toys3" metabolic network with the ID "pnto__R" via "FORMULA"
# --""C9H16NO5"" has a partial match. We have a formula as identifier for this metabolite: "C9H16NO5"
#
#
# ----------------------------------------------
# ---------------MATCH STEP 2-------------------
# ----------------------------------------------
#
# <3> Matching test on metabolites that matched only on the database conversion data against all metadata from the metabolic network
#
# --"Glucopyranose" is present in ['toys1', 'toys3'] metabolic network with the corresponding ID "Glucopyranose" via the match ID "glucopyranose"
# --"Glucopyranose" is present in ['toys1', 'toys3'] metabolic network with the corresponding ID "glc__D" via the match ID "glucopyranose"
# --"ADENINE" is present in ['toys1', 'toys3'] metabolic network with the corresponding ID "ADENINE" via the match ID "adenine"
# --"ADENINE" is present in ['toys1', 'toys3'] metabolic network with the corresponding ID "ade" via the match ID "adenine"
# --"MET" is present in ['toys1', 'toys3', 'toys2'] metabolic network with the corresponding ID "MET" via the match ID "met"
# --"MET" is present in ['toys1', 'toys3', 'toys2'] metabolic network with the corresponding ID "met__L" via the match ID "met"
# --"MET" is present in ['toys1', 'toys3', 'toys2'] metabolic network with the corresponding ID "MET" via the match ID "met"
# --"Beta-D-galactosyl-(1->3)-N-acetyl-beta-D-glucosaminyl-R" is present in ['toys1', 'toys2'] metabolic network with the corresponding ID "Gal-13-GlcN-R" via the match ID "gal-13-glcn-r"
# --"Beta-D-galactosyl-(1->3)-N-acetyl-beta-D-glucosaminyl-R" is present in ['toys1', 'toys2'] metabolic network with the corresponding ID "Gal-13-GlcN-R" via the match ID "gal-13-glcn-r"
# --"CPD-18186" is present in ['toys2'] metabolic network with the corresponding ID "CPD-18186" via the match ID "cpd-18186"
# --"orotic acid" is present in ['toys3', 'toys2'] metabolic network with the corresponding ID "orot" via the match ID "orotate"
# --"orotic acid" is present in ['toys3', 'toys2'] metabolic network with the corresponding ID "OROTATE" via the match ID "orotate"
# --"CARBAMOYL-P" is present in ['toys3'] metabolic network with the corresponding ID "cbp" via the match ID "carbamoyl-p"
# --"pantothenic acid" is present in ['toys3', 'toys2'] metabolic network with the corresponding ID "pnto__R" via the match ID "pantothenate"
# --"pantothenic acid" is present in ['toys3', 'toys2'] metabolic network with the corresponding ID "PANTOTHENATE" via the match ID "pantothenate"
# --"INCHIKEY=CGBYBGVMDAPUIH-ARJAWSKDSA-L" is present in ['toys1'] metabolic network with the corresponding ID "DIMETHYLMAL-CPD" via the match ID "dimethylmal-cpd"
# --"CCCC(=O)OCC(/C=C=C1([C@](C)(O)C[C@@H](OC(=O)C)CC(C)(C)1))=C/C=C/C(\C)=C/C=C/C=C(C)/C=C/C=C(C)/C(=O)C[C@]23(C(C)(C)C[C@H](O)C[C@@](C)(O2)3)" is present in ['toys2'] metabolic network with the corresponding ID "CPD-26454" via the match ID "cpd-26454"
# --Partial match set to IDs from "Match IDS in metabolic networks": "crn__D _AND_ crnmock"
#
# -------------------- SUMMARY REPORT --------------------
#
#
# Recap of Matches:
#   + Matched metabolites: 13
#   + Unmatched metabolites: 10
#   + Partial matches: 5
#
#  Match Details:
#   --> Full match (database + SBML): 12
#   --> Partial match + metabolic info: 5
#   --> Match only in SBML: 1
#
#  Unmatch Details:
#   --> Full unmatch (no match in DB or SBML): 8
#   --> Match in DB but not in SBML: 2
#   --> Partial match in DB only: 0
#
# --------------------------------------------------------
#
# Output file successfully written to: mapping/community/community_mapping_results_2025-12-15_15_40_45.tsv
#
# --- Total runtime 2.66 seconds ---
#  ---> MAPPING COMPLETED'

# %%
''' Show Community mode results

'''
import os
import pandas as pd

# 1. Set the directory path
directory = 'mapping/community/'

# 2. List all files in the directory
files = [f for f in os.listdir(directory) if os.path.isfile(os.path.join(directory, f))]

# 3. Check if exactly one file exists
if len(files) == 1:
    file_path = os.path.join(directory, files[0])
    print(f"Found file: {file_path}")
    
    # 4. Read the file (auto-detect TSV)
    if file_path.endswith('.tsv'):
        df = pd.read_csv(file_path, sep='\t')
    else:
        print("Unsupported file format.")
        df = None
    
    # 5. Display the table if loaded
    if df is not None:
        display(df)
else:
    print(f"Expected 1 file, found {len(files)}: {files}")
# Out:
# Found file: mapping/community/community_mapping_results_2025-12-15_15_40_45.tsv
#                MNM_ID                                Metabolites in mafs  \
# 0                MNM5                        CHEBI:84783 _AND_ CPD-25370
# 1                MNM1                                         CHEBI:4167
# 2    MNM2 _AND_ MNM19                      L-methionine _AND_ methionine
# 3                MNM6                          Adenine _AND_ CHEBI:16708
# 4    MNM7 _AND_ MNM27  Beta-D-galactosyl-(1->3)-N-acetyl-beta-D-gluco...
# 5               MNM20                        8-O-methylfusarubin alcohol
# 6               MNM17                                        orotic acid
# 7               MNM18                                 Carbamyl-phosphate
# 8   MNM11 _AND_ MNM21                    C9H16NO5 _AND_ pantothenic acid
# 9                MNM9                                                f1p
# 10              MNM10                                            crnmock
# 11               MNM4               INCHIKEY=CGBYBGVMDAPUIH-ARJAWSKDSA-L
# 12              MNM22  CCCC(=O)OCC(/C=C=C1([C@](C)(O)C[C@@H](OC(=O)C)...
# 13               MNM3                     CPD-17381 _AND_ roquefortine C
# 14               MNM8                                              aprut
# 15              MNM12                         CHEBI:36023 _AND_ vaccenic
# 16              MNM13                                        CHEBI:90488
# 17              MNM14               INCHIKEY=AVVWPBAENSWJCB-VSOTGSRCSA-C
# 18              MNM15  delphinidin 3-O-(4-coumaroyl-rhamnosyl-(1->6)-...
# 19              MNM16                                        CHEBI:15756
# 20              MNM23  C(S)[C@@H](C(NCCC(=O)[O-])=O)NC(=O)CC[C@@H](C(...
# 21              MNM24                     INCHIKEY=FSCYHDCTAZZSKN-DJNGBR
# 22              MNM26                                           thionine
#
#                                 Match in database  \
# 0                                       CPD-25370
# 1                                   Glucopyranose
# 2                                             MET
# 3                                         ADENINE
# 4   Gal-13-GlcN-R _AND_ beta-Gal-13-beta-GlcNac-R
# 5                                       CPD-18186
# 6                                         OROTATE
# 7                                     CARBAMOYL-P
# 8                                    PANTOTHENATE
# 9                           CPD-15970 _AND_ FRU1P
# 10                                            NaN
# 11                                DIMETHYLMAL-CPD
# 12                                      CPD-26454
# 13                                      CPD-17381
# 14                                        CPD-569
# 15                                            NaN
# 16                                            NaN
# 17                                            NaN
# 18                                            NaN
# 19                                            NaN
# 20                                            NaN
# 21                                            NaN
# 22                                            NaN
#
#     Match in metabolic networks Match IDS in metabolic networks  \
# 0                     ['toys1']                       CPD-25370
# 1            ['toys1', 'toys3']      Glucopyranose _AND_ glc__D
# 2   ['toys1', 'toys2', 'toys3']                MET _AND_ met__L
# 3            ['toys1', 'toys3']               ADENINE _AND_ ade
# 4            ['toys1', 'toys2']                   Gal-13-GlcN-R
# 5                     ['toys2']                       CPD-18186
# 6            ['toys2', 'toys3']              OROTATE _AND_ orot
# 7            ['toys2', 'toys3']    Carbamyl-phosphate _AND_ cbp
# 8            ['toys2', 'toys3']      PANTOTHENATE _AND_ pnto__R
# 9                     ['toys3']                             f1p
# 10                    ['toys3']            crn__D _AND_ crnmock
# 11                    ['toys1']                 DIMETHYLMAL-CPD
# 12                    ['toys2']                       CPD-26454
# 13                          NaN                             NaN
# 14                          NaN                             NaN
# 15                          NaN                             NaN
# 16                          NaN                             NaN
# 17                          NaN                             NaN
# 18                          NaN                             NaN
# 19                          NaN                             NaN
# 20                          NaN                             NaN
# 21                          NaN                             NaN
# 22                          NaN                             NaN
#
#                                         Partial match Match via UNIQUE-ID  \
# 0                                                 NaN                 YES
# 1                                                 NaN                 NaN
# 2                                    MNM2 _AND_ MNM19                 NaN
# 3                                                 NaN                 NaN
# 4   Gal-13-GlcN-R _AND_ beta-Gal-13-beta-GlcNac-R ...                 NaN
# 5                                                 NaN                 NaN
# 6                                                 NaN                 NaN
# 7                                                 NaN                 NaN
# 8                    C9H16NO5 _AND_ MNM11 _AND_ MNM21                 NaN
# 9                               CPD-15970 _AND_ FRU1P                 NaN
# 10                               crn__D _AND_ crnmock                 NaN
# 11                                                NaN                 NaN
# 12                                                NaN                 NaN
# 13                                                NaN                 YES
# 14                                                NaN                 NaN
# 15                                                NaN                 NaN
# 16                                                NaN                 NaN
# 17                                                NaN                 NaN
# 18                                                NaN                 NaN
# 19                                                NaN                 NaN
# 20                                                NaN                 NaN
# 21                                                NaN                 NaN
# 22                                                NaN                 NaN
#
#    Match via CHEBI Match via COMMON-NAME  Match via ABBREV-NAME  ...  \
# 0              YES                   NaN                    NaN  ...
# 1              YES                   NaN                    NaN  ...
# 2              NaN                   YES                    NaN  ...
# 3              NaN                   YES                    NaN  ...
# 4              NaN                   YES                    NaN  ...
# 5              NaN                   YES                    NaN  ...
# 6              NaN                   NaN                    NaN  ...
# 7              NaN                   NaN                    NaN  ...
# 8              NaN                   NaN                    NaN  ...
# 9              NaN                   NaN                    NaN  ...
# 10             NaN                   NaN                    NaN  ...
# 11             NaN                   NaN                    NaN  ...
# 12             NaN                   NaN                    NaN  ...
# 13             NaN                   YES                    NaN  ...
# 14             NaN                   NaN                    NaN  ...
# 15             NaN                   NaN                    NaN  ...
# 16             NaN                   NaN                    NaN  ...
# 17             NaN                   NaN                    NaN  ...
# 18             NaN                   NaN                    NaN  ...
# 19             NaN                   NaN                    NaN  ...
# 20             NaN                   NaN                    NaN  ...
# 21             NaN                   NaN                    NaN  ...
# 22             NaN                   NaN                    NaN  ...
#
#    Match via LIGAND-CPD Match via REFMET  Match via PUBCHEM  Match via VMH  \
# 0                   NaN              NaN                NaN            NaN
# 1                   NaN              NaN                NaN            NaN
# 2                   NaN              NaN                NaN            NaN
# 3                   NaN              NaN                NaN            NaN
# 4                   NaN              NaN                NaN            NaN
# 5                   NaN              NaN                NaN            NaN
# 6                   NaN              NaN                NaN            NaN
# 7                   NaN              NaN                NaN            NaN
# 8                   NaN              NaN                NaN            NaN
# 9                   NaN              NaN                NaN            NaN
# 10                  NaN              NaN                NaN            NaN
# 11                  NaN              NaN                NaN            NaN
# 12                  NaN              NaN                NaN            NaN
# 13                  NaN              NaN                NaN            NaN
# 14                  NaN              NaN                NaN            NaN
# 15                  NaN              NaN                NaN            NaN
# 16                  NaN              NaN                NaN            NaN
# 17                  NaN              NaN                NaN            NaN
# 18                  NaN              NaN                NaN            NaN
# 19                  NaN              NaN                NaN            NaN
# 20                  NaN              NaN                NaN            NaN
# 21                  NaN              NaN                NaN            NaN
# 22                  NaN              NaN                NaN            NaN
#
#     Match via CAS Match via INCHI  Match via NON-STANDARD-INCHI  \
# 0             NaN             NaN                           NaN
# 1             NaN             NaN                           NaN
# 2             NaN             NaN                           NaN
# 3             NaN             NaN                           NaN
# 4             NaN             NaN                           NaN
# 5             NaN             NaN                           NaN
# 6             NaN             NaN                           NaN
# 7             NaN             NaN                           NaN
# 8             NaN             NaN                           NaN
# 9             NaN             NaN                           NaN
# 10            NaN             NaN                           NaN
# 11            NaN             NaN                           NaN
# 12            NaN             NaN                           NaN
# 13            NaN             NaN                           NaN
# 14            NaN             NaN                           NaN
# 15            NaN             NaN                           NaN
# 16            NaN             NaN                           NaN
# 17            NaN             NaN                           NaN
# 18            NaN             NaN                           NaN
# 19            NaN             NaN                           NaN
# 20            NaN             NaN                           NaN
# 21            NaN             NaN                           NaN
# 22            NaN             NaN                           NaN
#
#     Match via INCHI-KEY  Match via SMILES  Match via FORMULA
# 0                   NaN               NaN                NaN
# 1                   NaN               NaN                NaN
# 2                   NaN               NaN                NaN
# 3                   NaN               NaN                NaN
# 4                   NaN               NaN                NaN
# 5                   NaN               NaN                NaN
# 6                   NaN               NaN                NaN
# 7                   NaN               NaN                NaN
# 8                   NaN               NaN                NaN
# 9                   NaN               NaN                NaN
# 10                  NaN               NaN                NaN
# 11                  YES               NaN                NaN
# 12                  NaN               YES                NaN
# 13                  NaN               NaN                NaN
# 14                  NaN               NaN                NaN
# 15                  NaN               NaN                NaN
# 16                  NaN               NaN                NaN
# 17                  NaN               NaN                NaN
# 18                  NaN               NaN                NaN
# 19                  NaN               NaN                NaN
# 20                  NaN               NaN                NaN
# 21                  NaN               NaN                NaN
# 22                  NaN               NaN                NaN
#
# [23 rows x 29 columns]

# %%
''' Run Community mode with partial match results
    The "community" mode allows you to input a directory containing multiple metabolomics data files, as well as a directory containing multiple metabolic networks.

'''

# !metanetmap community -p -s ../src/metanetmap/toys_tests_data/toys/sbml/ -a ../src/metanetmap/toys_tests_data/toys/maf/ -d ../src/metanetmap/toys_tests_data/conversion_datatable_toys.tsv -o mapping/community_partial/
# Out:
# 1629.82s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# -----------------------------------------
#             MAPPING METABOLITES
# -----------------------------------------
#
# ------> Main package version <------
# numpy version: 2.3.3
# pandas version: 2.3.2
# cobra version: 0.29.1
#
# Command run:
# Actual command run (from sys.argv): python /home/cmuller/miniconda3/envs/metanetmap/bin/metanetmap community -p -s ../src/metanetmap/toys_tests_data/toys/sbml/ -a ../src/metanetmap/toys_tests_data/toys/maf/ -d ../src/metanetmap/toys_tests_data/conversion_datatable_toys.tsv -o mapping/community_partial/
#
#
# ---->    MODE COMMUNITY    <----
# Load metabolomics data user path: ../src/metanetmap/toys_tests_data/toys/maf/ and metabolic networks user path: ../src/metanetmap/toys_tests_data/toys/sbml/
#
# ---------------PATHS-------------------
# List metabolomics data paths: ['../src/metanetmap/toys_tests_data/toys/maf/toys1.tsv', '../src/metanetmap/toys_tests_data/toys/maf/toys3.tsv', '../src/metanetmap/toys_tests_data/toys/maf/toys2.tsv']
# List metabolic networks paths: ['../src/metanetmap/toys_tests_data/toys/sbml/toys1.sbml', '../src/metanetmap/toys_tests_data/toys/sbml/toys3.xml', '../src/metanetmap/toys_tests_data/toys/sbml/toys2.sbml']
#
# Output file successfully written to: mapping/community_partial/MNM_mafs/MNM_toys1.tsv
#
# Output file successfully written to: mapping/community_partial/MNM_mafs/MNM_toys3.tsv
#
# Output file successfully written to: mapping/community_partial/MNM_mafs/MNM_toys2.tsv
#
#
# ----------------------------------------------
# ---------------MATCH STEP 1-------------------
# ----------------------------------------------
#
# <1> Direct matching test between metabolites derived from metabolomic data on all metadata in the metabolic network
# <2> Matching test between metabolites derived from metabolomic data on all metadata in the database conversion
#
# ++ Match step for "CPD-17381":
# --"CPD-17381" is present in database with the UNIQUE-ID "CPD-17381" and matches via "UNIQUE-ID"
#
# ++ Match step for "CPD-25370":
# --"CPD-25370" is present directly in "toys1" metabolic network with the ID "CPD-25370" via "UNIQUE-ID"
# --"CPD-25370" is present in database with the UNIQUE-ID "CPD-25370" and matches via "UNIQUE-ID"
#
# ++ Match step for "CHEBI:4167":
# --"CHEBI:4167" is present directly in "toys3" metabolic network with the ID "glc__D" via "CHEBI"
# --"CHEBI:4167" is present in database with the UNIQUE-ID "Glucopyranose" and matches via "CHEBI"
#
# ++ Match step for "CHEBI:84783":
# --"CHEBI:84783" is a metabolite duplicate of "CPD-25370" and matches via "CHEBI"
#
# ++ Match step for "CHEBI:16708":
# --"CHEBI:16708" is present directly in "toys3" metabolic network with the ID "ade" via "CHEBI"
# --"CHEBI:16708" is present in database with the UNIQUE-ID "ADENINE" and matches via "CHEBI"
#
# ++ Match step for "CHEBI:36023":
#
# ++ Match step for "CHEBI:90488":
#
# ++ Match step for "CHEBI:15756":
#
# ++ Match step for "CHEBI:123564":
#
# ++ Match step for "L-methionine":
# --"L-methionine" is present directly in "toys3" metabolic network with the ID "met__L" via "COMMON-NAME"
# --"L-methionine" is present directly in "toys1" metabolic network with the ID "MET" via "COMMON-NAME"
# --"L-methionine" is present in database with the UNIQUE-ID "MET" and matches via "COMMON-NAME"
#
# ++ Match step for "roquefortine C":
# --"roquefortine C" is a metabolite duplicate of "CPD-17381" and matches via "COMMON-NAME"
#
# ++ Match step for "Adenine":
# --"Adenine" is present directly in "toys1" metabolic network with the ID "ADENINE" via "COMMON-NAME"
# --"Adenine" is present directly in "toys3" metabolic network with the ID "ade" via "COMMON-NAME"
# --"Adenine" is a metabolite duplicate of "CHEBI:16708" and matches via "COMMON-NAME"
#
# ++ Match step for "Beta-D-galactosyl-(1->3)-N-acetyl-beta-D-glucosaminyl-R":
# --"Beta-D-galactosyl-(1->3)-N-acetyl-beta-D-glucosaminyl-R" is present in database with the UNIQUE-ID "beta-Gal-13-beta-GlcNac-R" and matches via "COMMON-NAME"
# --"Beta-D-galactosyl-(1->3)-N-acetyl-beta-D-glucosaminyl-R" has a partial match. We have several UNIQUE-ID identifiers for this metabolite: "beta-Gal-13-beta-GlcNac-R" and "Gal-13-GlcN-R"
#
# ++ Match step for "vaccenic":
#
# ++ Match step for "delphinidin 3-O-(4-coumaroyl-rhamnosyl-(1->6)-glucoside":
#
# ++ Match step for "methionine":
# --"methionine" is a metabolite duplicate of "L-methionine" and matches via "COMMON-NAME"
#
# ++ Match step for "8-O-methylfusarubin alcohol":
# --"8-O-methylfusarubin alcohol" is present directly in "toys2" metabolic network with the ID "CPD-18186" via "COMMON-NAME"
# --"8-O-methylfusarubin alcohol" is present in database with the UNIQUE-ID "CPD-18186" and matches via "COMMON-NAME"
#
# ++ Match step for "thionine":
#
# ++ Match step for "beta-D-galactosyl-(1->3)-N-acetyl-beta-D-glucosaminyl-R":
# --"beta-D-galactosyl-(1->3)-N-acetyl-beta-D-glucosaminyl-R" is a metabolite duplicate of "Beta-D-galactosyl-(1->3)-N-acetyl-beta-D-glucosaminyl-R" and matches via "COMMON-NAME"
#
# ++ Match step for "orotic acid":
# --"orotic acid" is present in database with the UNIQUE-ID "OROTATE" and matches via "SYNONYMS"
#
# ++ Match step for "Carbamyl-phosphate":
# --"Carbamyl-phosphate" is present directly in "toys2" metabolic network with the ID "Carbamyl-phosphate" via "SYNONYMS"
# --"Carbamyl-phosphate" is present in database with the UNIQUE-ID "CARBAMOYL-P" and matches via "SYNONYMS"
#
# ++ Match step for "pantothenic acid":
# --"pantothenic acid" is present in database with the UNIQUE-ID "PANTOTHENATE" and matches via "ADD-COMPLEMENT"
#
# ++ Match step for "aprut":
# --"aprut" is present in database with the UNIQUE-ID "CPD-569" and matches via "BIGG"
#
# ++ Match step for "f1p":
# --"f1p" is present directly in "toys3" metabolic network with the ID "f1p" via "BIGG"
# --"f1p" is present in database with the UNIQUE-ID "FRU1P" and matches via "BIGG"
# --"f1p" is present in database with the UNIQUE-ID "CPD-15970" and matches via "BIGG"
# --"f1p" has a partial match. We have several UNIQUE-ID identifiers for this metabolite: "CPD-15970 _AND_ FRU1P
#
# ++ Match step for "crnmock":
# --"crnmock" is present directly in "toys3" metabolic network with the ID "crnmock" via "BIGG"
# --"crnmock" is present directly in "toys3" metabolic network with the ID "crn__D" via "BIGG"
#
# ++ Match step for "INCHIKEY=CGBYBGVMDAPUIH-ARJAWSKDSA-L":
# --"INCHIKEY=CGBYBGVMDAPUIH-ARJAWSKDSA-L" is present in database with the UNIQUE-ID "DIMETHYLMAL-CPD" and matches via "INCHI-KEY"
#
# ++ Match step for "INCHIKEY=AVVWPBAENSWJCB-VSOTGSRCSA-C":
#
# ++ Match step for "INCHIKEY=FSCYHDCTAZZSKN-DJNGBR":
#
# ++ Match step for "CCCC(=O)OCC(/C=C=C1([C@](C)(O)C[C@@H](OC(=O)C)CC(C)(C)1))=C/C=C/C(\C)=C/C=C/C=C(C)/C=C/C=C(C)/C(=O)C[C@]23(C(C)(C)C[C@H](O)C[C@@](C)(O2)3)":
# --"CCCC(=O)OCC(/C=C=C1([C@](C)(O)C[C@@H](OC(=O)C)CC(C)(C)1))=C/C=C/C(\C)=C/C=C/C=C(C)/C=C/C=C(C)/C(=O)C[C@]23(C(C)(C)C[C@H](O)C[C@@](C)(O2)3)" is present in database with the UNIQUE-ID "CPD-26454" and matches via "SMILES"
#
# ++ Match step for "C(S)[C@@H](C(NCCC(=O)[O-])=O)NC(=O)CC[C@@H](C([O-])=O)NC(=O)[C@H](CS)NC(=O)CC[C@H]([NH3+])C([O-])":
#
# ++ Match step for "C9H16NO5":
# --"C9H16NO5" is present directly in "toys3" metabolic network with the ID "pnto__R" via "FORMULA"
# --""C9H16NO5"" has a partial match. We have a formula as identifier for this metabolite: "C9H16NO5"
#
#
# ----------------------------------------------
# ---------------MATCH STEP 2-------------------
# ----------------------------------------------
#
# <3> Matching test on metabolites that matched only on the database conversion data against all metadata from the metabolic network
#
# --"Glucopyranose" is present in ['toys1', 'toys3'] metabolic network with the corresponding ID "Glucopyranose" via the match ID "glucopyranose"
# --"Glucopyranose" is present in ['toys1', 'toys3'] metabolic network with the corresponding ID "glc__D" via the match ID "glucopyranose"
# --"ADENINE" is present in ['toys1', 'toys3'] metabolic network with the corresponding ID "ADENINE" via the match ID "adenine"
# --"ADENINE" is present in ['toys1', 'toys3'] metabolic network with the corresponding ID "ade" via the match ID "adenine"
# --"MET" is present in ['toys1', 'toys3', 'toys2'] metabolic network with the corresponding ID "MET" via the match ID "met"
# --"MET" is present in ['toys1', 'toys3', 'toys2'] metabolic network with the corresponding ID "met__L" via the match ID "met"
# --"MET" is present in ['toys1', 'toys3', 'toys2'] metabolic network with the corresponding ID "MET" via the match ID "met"
# --"Beta-D-galactosyl-(1->3)-N-acetyl-beta-D-glucosaminyl-R" is present in ['toys1', 'toys2'] metabolic network with the corresponding ID "Gal-13-GlcN-R" via the match ID "gal-13-glcn-r"
# --"Beta-D-galactosyl-(1->3)-N-acetyl-beta-D-glucosaminyl-R" is present in ['toys1', 'toys2'] metabolic network with the corresponding ID "Gal-13-GlcN-R" via the match ID "gal-13-glcn-r"
# --"CPD-18186" is present in ['toys2'] metabolic network with the corresponding ID "CPD-18186" via the match ID "cpd-18186"
# --"orotic acid" is present in ['toys3', 'toys2'] metabolic network with the corresponding ID "orot" via the match ID "orotate"
# --"orotic acid" is present in ['toys3', 'toys2'] metabolic network with the corresponding ID "OROTATE" via the match ID "orotate"
# --"CARBAMOYL-P" is present in ['toys3'] metabolic network with the corresponding ID "cbp" via the match ID "carbamoyl-p"
# --"pantothenic acid" is present in ['toys3', 'toys2'] metabolic network with the corresponding ID "pnto__R" via the match ID "pantothenate"
# --"pantothenic acid" is present in ['toys3', 'toys2'] metabolic network with the corresponding ID "PANTOTHENATE" via the match ID "pantothenate"
# --"INCHIKEY=CGBYBGVMDAPUIH-ARJAWSKDSA-L" is present in ['toys1'] metabolic network with the corresponding ID "DIMETHYLMAL-CPD" via the match ID "dimethylmal-cpd"
# --"CCCC(=O)OCC(/C=C=C1([C@](C)(O)C[C@@H](OC(=O)C)CC(C)(C)1))=C/C=C/C(\C)=C/C=C/C=C(C)/C=C/C=C(C)/C(=O)C[C@]23(C(C)(C)C[C@H](O)C[C@@](C)(O2)3)" is present in ['toys2'] metabolic network with the corresponding ID "CPD-26454" via the match ID "cpd-26454"
# --Partial match set to IDs from "Match IDS in metabolic networks": "crn__D _AND_ crnmock"
#
#
# ------------------------------------------------
# ---------------PARTIAL MATCH -------------------
# ----------------------------------------------
#
# <4> Attempting to find new IDs for unmatched metabolites using multiple strategies: removing enantiomer specificity, using the core part of InChIKeys, or exploring parent/child relationships in CHEBI.
#
#
# -----> CHEBI <-----
# Fetching ChEBI data:   0%|                                | 0/4 [00:00<?, ?it/s]
#  ++CHEBI identification step for CHEBI:90488:
#
#  ++CHEBI identification step for CHEBI:36023:
#
#  ++CHEBI identification step for CHEBI:36023:
#
#  ++CHEBI identification step for CHEBI:15756:
# --CHEBI:90488 is CHEBI:90488
#    --Parents are :
#      -- CHEBI:90488 is related to 1-phosphatidyl-1D-myo-inositol
# Fetching ChEBI data:  25%|██████                  | 1/4 [00:00<00:00,  4.19it/s]--CHEBI:15756 is CHEBI:15756
#    --Parents are :
#      -- CHEBI:15756 is related to straight-chain saturated fatty acid
#      -- CHEBI:15756 is related to long-chain fatty acid
#    --Children are :
#      -- CHEBI:15756 is related to 1-hexadecanoyl-2-methyl-sn-glycero-3-phosphocholine
# --CHEBI:36023 is CHEBI:36023
#    --Parents are :
#      -- vaccenic is related to octadecenoic acid
#      -- vaccenic is related to straight-chain fatty acid
#    --Children are :
#      -- vaccenic is related to trans-vaccenic acid
#      -- vaccenic is related to cis-vaccenic acid
# --CHEBI:36023 is CHEBI:36023
#    --Parents are :
#      -- CHEBI:36023 is related to octadecenoic acid
#      -- CHEBI:36023 is related to straight-chain fatty acid
#    --Children are :
#      -- CHEBI:36023 is related to trans-vaccenic acid
#      -- CHEBI:36023 is related to cis-vaccenic acid
# Fetching ChEBI data: 100%|████████████████████████| 4/4 [00:00<00:00, 12.26it/s]
#
# -----> inchikey <-----
# inchikey: INCHIKEY=AVVWPBAENSWJCB-VSOTGSRCSA-C -> Short inchikey: ['INCHIKEY=AVVWPBAENSWJCB']
# inchikey: INCHIKEY=FSCYHDCTAZZSKN-DJNGBR -> Short inchikey: ['INCHIKEY=FSCYHDCTAZZSKN']
#
# -----> Enantiomers <-----
# -----> Remove enantiomers in database and in metadata of sbml <-----
#
#
# ----------------------------------------------------
# ---------------Retry MATCH STEP 1-------------------
# ----------------------------------------------------
#
# -----> Test: CHEBI <-----
#
# ++ Match step for "CHEBI:90488":
#
# --Try with CHEBI:90488":
#
# --Try with phosphatidylinositol (18:1/20:4)":
#
# --Try with CHEBI:16749":
#
# --Try with 1-phosphatidyl-1D-myo-inositol":
#
# ++ Match step for "CHEBI:15756":
#
# --Try with CHEBI:15756":
#
# --Try with hexadecanoic acid":
# --"CHEBI:15756" is present in database with the UNIQUE-ID "PALMITATE" and matches via "CHEBI"
#
# --Try with PALMITATE":
#       --"CHEBI:15756" has a partial match. A match was found with the ID: "PALMITATE" via: CHEBI
# --"CHEBI:15756" is a metabolite duplicate of "CHEBI:15756" and matches via "CHEBI"
#
# --Try with CHEBI:39418":
#       --"CHEBI:15756" has a partial match. A match was found with the ID: "CHEBI:39418" via: CHEBI
#
# --Try with straight-chain saturated fatty acid":
#
# --Try with CHEBI:15904":
# --"CHEBI:15756" is present in database with the UNIQUE-ID "Long-Chain-Fatty-Acids" and matches via "CHEBI"
#
# --Try with long-chain fatty acid":
#
# --Try with CHEBI:131689":
#       --"CHEBI:15756" has a partial match. A match was found with the ID: "CHEBI:131689" via: CHEBI
#
# --Try with 1-hexadecanoyl-2-methyl-sn-glycero-3-phosphocholine":
#
# ++ Match step for "vaccenic":
#
# --Try with CHEBI:36023":
#
# --Try with vaccenic acid":
# --"vaccenic" is present in database with the UNIQUE-ID "Vaccenate" and matches via "CHEBI"
#
# --Try with CHEBI:25634":
#
# --Try with octadecenoic acid":
#
# --Try with CHEBI:59202":
#
# --Try with straight-chain fatty acid":
#
# --Try with CHEBI:28727":
#
# --Try with trans-vaccenic acid":
# --"vaccenic" has a partial match. We have several UNIQUE-ID identifiers for this metabolite: "Vaccenate" and "CPD-17257"
#
# --Try with CHEBI:50464":
#
# --Try with cis-vaccenic acid":
# --"vaccenic" has a partial match. We have several UNIQUE-ID identifiers for this metabolite: "Vaccenate _AND_ CPD-17257" and "CPD-9247"
#
# ++ Match step for "CHEBI:36023":
#
# --Try with CHEBI:36023":
#
# --Try with vaccenic acid":
# --"CHEBI:36023" is a metabolite duplicate of "vaccenic" and matches via "CHEBI"
#
# --Try with CHEBI:25634":
#
# --Try with octadecenoic acid":
#
# --Try with CHEBI:59202":
#
# --Try with straight-chain fatty acid":
#
# --Try with CHEBI:28727":
#
# --Try with trans-vaccenic acid":
#
# --Try with CHEBI:50464":
#
# --Try with cis-vaccenic acid":
#
# -----> Test: Inchey <-----
#
# ++ Match step for "INCHIKEY=AVVWPBAENSWJCB":
#
# --Try with INCHIKEY=AVVWPBAENSWJCB-VSOTGSRCSA-C":
# --"INCHIKEY=AVVWPBAENSWJCB-VSOTGSRCSA-C" is present in database with the UNIQUE-ID "CPD-24978" and matches via "inchikey"
# --"INCHIKEY=AVVWPBAENSWJCB-VSOTGSRCSA-C" has a partial match. We have several UNIQUE-ID identifiers for this metabolite: "CPD-24978" and "CPD-25014"
# --"INCHIKEY=AVVWPBAENSWJCB-VSOTGSRCSA-C" has a partial match. We have several UNIQUE-ID identifiers for this metabolite: "CPD-24978 _AND_ CPD-25014" and "CPD-25010"
# --"INCHIKEY=AVVWPBAENSWJCB-VSOTGSRCSA-C" has a partial match. We have several UNIQUE-ID identifiers for this metabolite: "CPD-24978 _AND_ CPD-25014 _AND_ CPD-25010" and "CPD-16933"
# --"INCHIKEY=AVVWPBAENSWJCB-VSOTGSRCSA-C" has a partial match. We have several UNIQUE-ID identifiers for this metabolite: "CPD-24978 _AND_ CPD-25014 _AND_ CPD-25010 _AND_ CPD-16933" and "CPD-24986"
# --"INCHIKEY=AVVWPBAENSWJCB-VSOTGSRCSA-C" has a partial match. We have several UNIQUE-ID identifiers for this metabolite: "CPD-24978 _AND_ CPD-25014 _AND_ CPD-25010 _AND_ CPD-16933 _AND_ CPD-24986" and "CPD-24992"
# --"INCHIKEY=AVVWPBAENSWJCB-VSOTGSRCSA-C" has a partial match. We have several UNIQUE-ID identifiers for this metabolite: "CPD-24978 _AND_ CPD-25014 _AND_ CPD-25010 _AND_ CPD-16933 _AND_ CPD-24986 _AND_ CPD-24992" and "CPD-25011"
# --"INCHIKEY=AVVWPBAENSWJCB-VSOTGSRCSA-C" has a partial match. We have several UNIQUE-ID identifiers for this metabolite: "CPD-24978 _AND_ CPD-25014 _AND_ CPD-25010 _AND_ CPD-16933 _AND_ CPD-24986 _AND_ CPD-24992 _AND_ CPD-25011" and "CPD-25008"
# --"INCHIKEY=AVVWPBAENSWJCB-VSOTGSRCSA-C" has a partial match. We have several UNIQUE-ID identifiers for this metabolite: "CPD-24978 _AND_ CPD-25014 _AND_ CPD-25010 _AND_ CPD-16933 _AND_ CPD-24986 _AND_ CPD-24992 _AND_ CPD-25011 _AND_ CPD-25008" and "CPD-25020"
# --"INCHIKEY=AVVWPBAENSWJCB-VSOTGSRCSA-C" has a partial match. We have several UNIQUE-ID identifiers for this metabolite: "CPD-24978 _AND_ CPD-25014 _AND_ CPD-25010 _AND_ CPD-16933 _AND_ CPD-24986 _AND_ CPD-24992 _AND_ CPD-25011 _AND_ CPD-25008 _AND_ CPD-25020" and "CPD-24979"
# --"INCHIKEY=AVVWPBAENSWJCB-VSOTGSRCSA-C" has a partial match. We have several UNIQUE-ID identifiers for this metabolite: "CPD-24978 _AND_ CPD-25014 _AND_ CPD-25010 _AND_ CPD-16933 _AND_ CPD-24986 _AND_ CPD-24992 _AND_ CPD-25011 _AND_ CPD-25008 _AND_ CPD-25020 _AND_ CPD-24979" and "CPD-24991"
# --"INCHIKEY=AVVWPBAENSWJCB-VSOTGSRCSA-C" has a partial match. We have several UNIQUE-ID identifiers for this metabolite: "CPD-24978 _AND_ CPD-25014 _AND_ CPD-25010 _AND_ CPD-16933 _AND_ CPD-24986 _AND_ CPD-24992 _AND_ CPD-25011 _AND_ CPD-25008 _AND_ CPD-25020 _AND_ CPD-24979 _AND_ CPD-24991" and "CPD-24984"
# --"INCHIKEY=AVVWPBAENSWJCB-VSOTGSRCSA-C" has a partial match. We have several UNIQUE-ID identifiers for this metabolite: "CPD-24978 _AND_ CPD-25014 _AND_ CPD-25010 _AND_ CPD-16933 _AND_ CPD-24986 _AND_ CPD-24992 _AND_ CPD-25011 _AND_ CPD-25008 _AND_ CPD-25020 _AND_ CPD-24979 _AND_ CPD-24991 _AND_ CPD-24984" and "CPD-24997"
# --"INCHIKEY=AVVWPBAENSWJCB-VSOTGSRCSA-C" has a partial match. We have several UNIQUE-ID identifiers for this metabolite: "CPD-24978 _AND_ CPD-25014 _AND_ CPD-25010 _AND_ CPD-16933 _AND_ CPD-24986 _AND_ CPD-24992 _AND_ CPD-25011 _AND_ CPD-25008 _AND_ CPD-25020 _AND_ CPD-24979 _AND_ CPD-24991 _AND_ CPD-24984 _AND_ CPD-24997" and "CPD-25015"
# --"INCHIKEY=AVVWPBAENSWJCB-VSOTGSRCSA-C" has a partial match. We have several UNIQUE-ID identifiers for this metabolite: "CPD-24978 _AND_ CPD-25014 _AND_ CPD-25010 _AND_ CPD-16933 _AND_ CPD-24986 _AND_ CPD-24992 _AND_ CPD-25011 _AND_ CPD-25008 _AND_ CPD-25020 _AND_ CPD-24979 _AND_ CPD-24991 _AND_ CPD-24984 _AND_ CPD-24997 _AND_ CPD-25015" and "CPD-25019"
# --"INCHIKEY=AVVWPBAENSWJCB-VSOTGSRCSA-C" has a partial match. We have several UNIQUE-ID identifiers for this metabolite: "CPD-24978 _AND_ CPD-25014 _AND_ CPD-25010 _AND_ CPD-16933 _AND_ CPD-24986 _AND_ CPD-24992 _AND_ CPD-25011 _AND_ CPD-25008 _AND_ CPD-25020 _AND_ CPD-24979 _AND_ CPD-24991 _AND_ CPD-24984 _AND_ CPD-24997 _AND_ CPD-25015 _AND_ CPD-25019" and "CPD0-2486"
# --"INCHIKEY=AVVWPBAENSWJCB-VSOTGSRCSA-C" has a partial match. We have several UNIQUE-ID identifiers for this metabolite: "CPD-24978 _AND_ CPD-25014 _AND_ CPD-25010 _AND_ CPD-16933 _AND_ CPD-24986 _AND_ CPD-24992 _AND_ CPD-25011 _AND_ CPD-25008 _AND_ CPD-25020 _AND_ CPD-24979 _AND_ CPD-24991 _AND_ CPD-24984 _AND_ CPD-24997 _AND_ CPD-25015 _AND_ CPD-25019 _AND_ CPD0-2486" and "CPD-25006"
# --"INCHIKEY=AVVWPBAENSWJCB-VSOTGSRCSA-C" has a partial match. We have several UNIQUE-ID identifiers for this metabolite: "CPD-24978 _AND_ CPD-25014 _AND_ CPD-25010 _AND_ CPD-16933 _AND_ CPD-24986 _AND_ CPD-24992 _AND_ CPD-25011 _AND_ CPD-25008 _AND_ CPD-25020 _AND_ CPD-24979 _AND_ CPD-24991 _AND_ CPD-24984 _AND_ CPD-24997 _AND_ CPD-25015 _AND_ CPD-25019 _AND_ CPD0-2486 _AND_ CPD-25006" and "CPD-16934"
# --"INCHIKEY=AVVWPBAENSWJCB-VSOTGSRCSA-C" has a partial match. We have several UNIQUE-ID identifiers for this metabolite: "CPD-24978 _AND_ CPD-25014 _AND_ CPD-25010 _AND_ CPD-16933 _AND_ CPD-24986 _AND_ CPD-24992 _AND_ CPD-25011 _AND_ CPD-25008 _AND_ CPD-25020 _AND_ CPD-24979 _AND_ CPD-24991 _AND_ CPD-24984 _AND_ CPD-24997 _AND_ CPD-25015 _AND_ CPD-25019 _AND_ CPD0-2486 _AND_ CPD-25006 _AND_ CPD-16934" and "CPD-24952"
# --"INCHIKEY=AVVWPBAENSWJCB-VSOTGSRCSA-C" has a partial match. We have several UNIQUE-ID identifiers for this metabolite: "CPD-24978 _AND_ CPD-25014 _AND_ CPD-25010 _AND_ CPD-16933 _AND_ CPD-24986 _AND_ CPD-24992 _AND_ CPD-25011 _AND_ CPD-25008 _AND_ CPD-25020 _AND_ CPD-24979 _AND_ CPD-24991 _AND_ CPD-24984 _AND_ CPD-24997 _AND_ CPD-25015 _AND_ CPD-25019 _AND_ CPD0-2486 _AND_ CPD-25006 _AND_ CPD-16934 _AND_ CPD-24952" and "CPD-25013"
# --"INCHIKEY=AVVWPBAENSWJCB-VSOTGSRCSA-C" has a partial match. We have several UNIQUE-ID identifiers for this metabolite: "CPD-24978 _AND_ CPD-25014 _AND_ CPD-25010 _AND_ CPD-16933 _AND_ CPD-24986 _AND_ CPD-24992 _AND_ CPD-25011 _AND_ CPD-25008 _AND_ CPD-25020 _AND_ CPD-24979 _AND_ CPD-24991 _AND_ CPD-24984 _AND_ CPD-24997 _AND_ CPD-25015 _AND_ CPD-25019 _AND_ CPD0-2486 _AND_ CPD-25006 _AND_ CPD-16934 _AND_ CPD-24952 _AND_ CPD-25013" and "CPD-24951"
# --"INCHIKEY=AVVWPBAENSWJCB-VSOTGSRCSA-C" has a partial match. We have several UNIQUE-ID identifiers for this metabolite: "CPD-24978 _AND_ CPD-25014 _AND_ CPD-25010 _AND_ CPD-16933 _AND_ CPD-24986 _AND_ CPD-24992 _AND_ CPD-25011 _AND_ CPD-25008 _AND_ CPD-25020 _AND_ CPD-24979 _AND_ CPD-24991 _AND_ CPD-24984 _AND_ CPD-24997 _AND_ CPD-25015 _AND_ CPD-25019 _AND_ CPD0-2486 _AND_ CPD-25006 _AND_ CPD-16934 _AND_ CPD-24952 _AND_ CPD-25013 _AND_ CPD-24951" and "CPD-25012"
# --"INCHIKEY=AVVWPBAENSWJCB-VSOTGSRCSA-C" has a partial match. We have several UNIQUE-ID identifiers for this metabolite: "CPD-24978 _AND_ CPD-25014 _AND_ CPD-25010 _AND_ CPD-16933 _AND_ CPD-24986 _AND_ CPD-24992 _AND_ CPD-25011 _AND_ CPD-25008 _AND_ CPD-25020 _AND_ CPD-24979 _AND_ CPD-24991 _AND_ CPD-24984 _AND_ CPD-24997 _AND_ CPD-25015 _AND_ CPD-25019 _AND_ CPD0-2486 _AND_ CPD-25006 _AND_ CPD-16934 _AND_ CPD-24952 _AND_ CPD-25013 _AND_ CPD-24951 _AND_ CPD-25012" and "CPD0-2485"
# --"INCHIKEY=AVVWPBAENSWJCB-VSOTGSRCSA-C" has a partial match. We have several UNIQUE-ID identifiers for this metabolite: "CPD-24978 _AND_ CPD-25014 _AND_ CPD-25010 _AND_ CPD-16933 _AND_ CPD-24986 _AND_ CPD-24992 _AND_ CPD-25011 _AND_ CPD-25008 _AND_ CPD-25020 _AND_ CPD-24979 _AND_ CPD-24991 _AND_ CPD-24984 _AND_ CPD-24997 _AND_ CPD-25015 _AND_ CPD-25019 _AND_ CPD0-2486 _AND_ CPD-25006 _AND_ CPD-16934 _AND_ CPD-24952 _AND_ CPD-25013 _AND_ CPD-24951 _AND_ CPD-25012 _AND_ CPD0-2485" and "CPD-24996"
# --"INCHIKEY=AVVWPBAENSWJCB-VSOTGSRCSA-C" has a partial match. We have several UNIQUE-ID identifiers for this metabolite: "CPD-24978 _AND_ CPD-25014 _AND_ CPD-25010 _AND_ CPD-16933 _AND_ CPD-24986 _AND_ CPD-24992 _AND_ CPD-25011 _AND_ CPD-25008 _AND_ CPD-25020 _AND_ CPD-24979 _AND_ CPD-24991 _AND_ CPD-24984 _AND_ CPD-24997 _AND_ CPD-25015 _AND_ CPD-25019 _AND_ CPD0-2486 _AND_ CPD-25006 _AND_ CPD-16934 _AND_ CPD-24952 _AND_ CPD-25013 _AND_ CPD-24951 _AND_ CPD-25012 _AND_ CPD0-2485 _AND_ CPD-24996" and "CPD-24985"
# --"INCHIKEY=AVVWPBAENSWJCB-VSOTGSRCSA-C" has a partial match. We have several UNIQUE-ID identifiers for this metabolite: "CPD-24978 _AND_ CPD-25014 _AND_ CPD-25010 _AND_ CPD-16933 _AND_ CPD-24986 _AND_ CPD-24992 _AND_ CPD-25011 _AND_ CPD-25008 _AND_ CPD-25020 _AND_ CPD-24979 _AND_ CPD-24991 _AND_ CPD-24984 _AND_ CPD-24997 _AND_ CPD-25015 _AND_ CPD-25019 _AND_ CPD0-2486 _AND_ CPD-25006 _AND_ CPD-16934 _AND_ CPD-24952 _AND_ CPD-25013 _AND_ CPD-24951 _AND_ CPD-25012 _AND_ CPD0-2485 _AND_ CPD-24996 _AND_ CPD-24985" and "CPD-24990"
# --"INCHIKEY=AVVWPBAENSWJCB-VSOTGSRCSA-C" has a partial match. We have several UNIQUE-ID identifiers for this metabolite: "CPD-24978 _AND_ CPD-25014 _AND_ CPD-25010 _AND_ CPD-16933 _AND_ CPD-24986 _AND_ CPD-24992 _AND_ CPD-25011 _AND_ CPD-25008 _AND_ CPD-25020 _AND_ CPD-24979 _AND_ CPD-24991 _AND_ CPD-24984 _AND_ CPD-24997 _AND_ CPD-25015 _AND_ CPD-25019 _AND_ CPD0-2486 _AND_ CPD-25006 _AND_ CPD-16934 _AND_ CPD-24952 _AND_ CPD-25013 _AND_ CPD-24951 _AND_ CPD-25012 _AND_ CPD0-2485 _AND_ CPD-24996 _AND_ CPD-24985 _AND_ CPD-24990" and "CPD-24983"
# --"INCHIKEY=AVVWPBAENSWJCB-VSOTGSRCSA-C" has a partial match. We have several UNIQUE-ID identifiers for this metabolite: "CPD-24978 _AND_ CPD-25014 _AND_ CPD-25010 _AND_ CPD-16933 _AND_ CPD-24986 _AND_ CPD-24992 _AND_ CPD-25011 _AND_ CPD-25008 _AND_ CPD-25020 _AND_ CPD-24979 _AND_ CPD-24991 _AND_ CPD-24984 _AND_ CPD-24997 _AND_ CPD-25015 _AND_ CPD-25019 _AND_ CPD0-2486 _AND_ CPD-25006 _AND_ CPD-16934 _AND_ CPD-24952 _AND_ CPD-25013 _AND_ CPD-24951 _AND_ CPD-25012 _AND_ CPD0-2485 _AND_ CPD-24996 _AND_ CPD-24985 _AND_ CPD-24990 _AND_ CPD-24983" and "CPD-25009"
# --"INCHIKEY=AVVWPBAENSWJCB-VSOTGSRCSA-C" has a partial match. We have several UNIQUE-ID identifiers for this metabolite: "CPD-24978 _AND_ CPD-25014 _AND_ CPD-25010 _AND_ CPD-16933 _AND_ CPD-24986 _AND_ CPD-24992 _AND_ CPD-25011 _AND_ CPD-25008 _AND_ CPD-25020 _AND_ CPD-24979 _AND_ CPD-24991 _AND_ CPD-24984 _AND_ CPD-24997 _AND_ CPD-25015 _AND_ CPD-25019 _AND_ CPD0-2486 _AND_ CPD-25006 _AND_ CPD-16934 _AND_ CPD-24952 _AND_ CPD-25013 _AND_ CPD-24951 _AND_ CPD-25012 _AND_ CPD0-2485 _AND_ CPD-24996 _AND_ CPD-24985 _AND_ CPD-24990 _AND_ CPD-24983 _AND_ CPD-25009" and "CPD-24993"
# --"INCHIKEY=AVVWPBAENSWJCB-VSOTGSRCSA-C" has a partial match. We have several UNIQUE-ID identifiers for this metabolite: "CPD-24978 _AND_ CPD-25014 _AND_ CPD-25010 _AND_ CPD-16933 _AND_ CPD-24986 _AND_ CPD-24992 _AND_ CPD-25011 _AND_ CPD-25008 _AND_ CPD-25020 _AND_ CPD-24979 _AND_ CPD-24991 _AND_ CPD-24984 _AND_ CPD-24997 _AND_ CPD-25015 _AND_ CPD-25019 _AND_ CPD0-2486 _AND_ CPD-25006 _AND_ CPD-16934 _AND_ CPD-24952 _AND_ CPD-25013 _AND_ CPD-24951 _AND_ CPD-25012 _AND_ CPD0-2485 _AND_ CPD-24996 _AND_ CPD-24985 _AND_ CPD-24990 _AND_ CPD-24983 _AND_ CPD-25009 _AND_ CPD-24993" and "CPD-25005"
# --"INCHIKEY=AVVWPBAENSWJCB-VSOTGSRCSA-C" has a partial match. We have several UNIQUE-ID identifiers for this metabolite: "CPD-24978 _AND_ CPD-25014 _AND_ CPD-25010 _AND_ CPD-16933 _AND_ CPD-24986 _AND_ CPD-24992 _AND_ CPD-25011 _AND_ CPD-25008 _AND_ CPD-25020 _AND_ CPD-24979 _AND_ CPD-24991 _AND_ CPD-24984 _AND_ CPD-24997 _AND_ CPD-25015 _AND_ CPD-25019 _AND_ CPD0-2486 _AND_ CPD-25006 _AND_ CPD-16934 _AND_ CPD-24952 _AND_ CPD-25013 _AND_ CPD-24951 _AND_ CPD-25012 _AND_ CPD0-2485 _AND_ CPD-24996 _AND_ CPD-24985 _AND_ CPD-24990 _AND_ CPD-24983 _AND_ CPD-25009 _AND_ CPD-24993 _AND_ CPD-25005" and "CPD-25004"
# --"INCHIKEY=AVVWPBAENSWJCB-VSOTGSRCSA-C" has a partial match. We have several UNIQUE-ID identifiers for this metabolite: "CPD-24978 _AND_ CPD-25014 _AND_ CPD-25010 _AND_ CPD-16933 _AND_ CPD-24986 _AND_ CPD-24992 _AND_ CPD-25011 _AND_ CPD-25008 _AND_ CPD-25020 _AND_ CPD-24979 _AND_ CPD-24991 _AND_ CPD-24984 _AND_ CPD-24997 _AND_ CPD-25015 _AND_ CPD-25019 _AND_ CPD0-2486 _AND_ CPD-25006 _AND_ CPD-16934 _AND_ CPD-24952 _AND_ CPD-25013 _AND_ CPD-24951 _AND_ CPD-25012 _AND_ CPD0-2485 _AND_ CPD-24996 _AND_ CPD-24985 _AND_ CPD-24990 _AND_ CPD-24983 _AND_ CPD-25009 _AND_ CPD-24993 _AND_ CPD-25005 _AND_ CPD-25004" and "CPD-25007"
#
# ++ Match step for "INCHIKEY=FSCYHDCTAZZSKN":
#
# --Try with INCHIKEY=FSCYHDCTAZZSKN-DJNGBR":
#
# -----> Test: Enantiomers <-----
#
# ++ Match step for "thionine":
#
# ++ Match step for "delphinidin 3-O-(4-coumaroyl-rhamnosyl-(1->6)-glucoside":
# --"delphinidin 3-O-(4-coumaroyl-rhamnosyl-(1->6)-glucoside" is present in database with the UNIQUE-ID "CPD-22089" and matches via "Enantiomers"
#
# ++ Match step for "C(S)[C@@H](C(NCCC(=O)[O-])=O)NC(=O)CC[C@@H](C([O-])=O)NC(=O)[C@H](CS)NC(=O)CC[C@H]([NH3+])C([O-])":
#
#
# ----------------------------------------------------
# ---------------Retry MATCH STEP 2-------------------
# ----------------------------------------------------
# --"PALMITATE" is present in ['toys3'] metabolic network with the corresponding ID "hdca" via the match ID "palmitate"
#
# -------------------- SUMMARY REPORT --------------------
#
#
# Recap of Matches:
#   + Matched metabolites: 14
#   + Unmatched metabolites: 9
#   + Partial matches: 9
#
#  Match Details:
#   --> Full match (database + SBML): 13
#   --> Partial match + metabolic info: 6
#   --> Match only in SBML: 1
#
#  Unmatch Details:
#   --> Full unmatch (no match in DB or SBML): 4
#   --> Match in DB but not in SBML: 5
#   --> Partial match in DB only: 3
#
# --------------------------------------------------------
#
# Output file successfully written to: mapping/community_partial/community_mapping_results_partial_match_2025-12-15_15_40_54.tsv
#
# --- Total runtime 5.49 seconds ---
#  ---> MAPPING COMPLETED'

# %%
''' Show Community mode with partial match 

'''
import os
import pandas as pd

# 1. Set the directory path
directory = 'mapping/community_partial/'

# 2. List all files in the directory
files = [f for f in os.listdir(directory) if os.path.isfile(os.path.join(directory, f))]

# 3. Check if exactly one file exists
if len(files) == 1:
    file_path = os.path.join(directory, files[0])
    print(f"Found file: {file_path}")
    
    # 4. Read the file (auto-detect TSV)
    if file_path.endswith('.tsv'):
        df = pd.read_csv(file_path, sep='\t')
    else:
        print("Unsupported file format.")
        df = None
    
    # 5. Display the table if loaded
    if df is not None:
        display(df)
else:
    print(f"Expected 1 file, found {len(files)}: {files}")
# Out:
# Found file: mapping/community_partial/community_mapping_results_partial_match_2025-12-15_15_40_54.tsv
#                MNM_ID                                Metabolites in mafs  \
# 0                MNM5                        CHEBI:84783 _AND_ CPD-25370
# 1                MNM1                                         CHEBI:4167
# 2    MNM2 _AND_ MNM19                      L-methionine _AND_ methionine
# 3                MNM6                          Adenine _AND_ CHEBI:16708
# 4    MNM7 _AND_ MNM27  Beta-D-galactosyl-(1->3)-N-acetyl-beta-D-gluco...
# 5               MNM20                        8-O-methylfusarubin alcohol
# 6               MNM17                                        orotic acid
# 7               MNM18                                 Carbamyl-phosphate
# 8   MNM11 _AND_ MNM21                    C9H16NO5 _AND_ pantothenic acid
# 9                MNM9                                                f1p
# 10              MNM10                                            crnmock
# 11               MNM4               INCHIKEY=CGBYBGVMDAPUIH-ARJAWSKDSA-L
# 12              MNM22  CCCC(=O)OCC(/C=C=C1([C@](C)(O)C[C@@H](OC(=O)C)...
# 13              MNM16                                        CHEBI:15756
# 14               MNM3                     CPD-17381 _AND_ roquefortine C
# 15               MNM8                                              aprut
# 16              MNM12                         CHEBI:36023 _AND_ vaccenic
# 17              MNM14               INCHIKEY=AVVWPBAENSWJCB-VSOTGSRCSA-C
# 18              MNM15  delphinidin 3-O-(4-coumaroyl-rhamnosyl-(1->6)-...
# 19              MNM13                                        CHEBI:90488
# 20              MNM23  C(S)[C@@H](C(NCCC(=O)[O-])=O)NC(=O)CC[C@@H](C(...
# 21              MNM24                     INCHIKEY=FSCYHDCTAZZSKN-DJNGBR
# 22              MNM26                                           thionine
#
#                                     Match in database  \
# 0                                           CPD-25370
# 1                                       Glucopyranose
# 2                                                 MET
# 3                                             ADENINE
# 4       Gal-13-GlcN-R _AND_ beta-Gal-13-beta-GlcNac-R
# 5                                           CPD-18186
# 6                                             OROTATE
# 7                                         CARBAMOYL-P
# 8                                        PANTOTHENATE
# 9                               CPD-15970 _AND_ FRU1P
# 10                                                NaN
# 11                                    DIMETHYLMAL-CPD
# 12                                          CPD-26454
# 13                             Long-Chain-Fatty-Acids
# 14                                          CPD-17381
# 15                                            CPD-569
# 16           CPD-17257 _AND_ CPD-9247 _AND_ Vaccenate
# 17  CPD-16933 _AND_ CPD-16934 _AND_ CPD-24951 _AND...
# 18                                          CPD-22089
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
#
#     Match in metabolic networks Match IDS in metabolic networks  \
# 0                     ['toys1']                       CPD-25370
# 1            ['toys1', 'toys3']      Glucopyranose _AND_ glc__D
# 2   ['toys1', 'toys2', 'toys3']                MET _AND_ met__L
# 3            ['toys1', 'toys3']               ADENINE _AND_ ade
# 4            ['toys1', 'toys2']                   Gal-13-GlcN-R
# 5                     ['toys2']                       CPD-18186
# 6            ['toys2', 'toys3']              OROTATE _AND_ orot
# 7            ['toys2', 'toys3']    Carbamyl-phosphate _AND_ cbp
# 8            ['toys2', 'toys3']      PANTOTHENATE _AND_ pnto__R
# 9                     ['toys3']                             f1p
# 10                    ['toys3']            crn__D _AND_ crnmock
# 11                    ['toys1']                 DIMETHYLMAL-CPD
# 12                    ['toys2']                       CPD-26454
# 13                    ['toys3']                            hdca
# 14                          NaN                             NaN
# 15                          NaN                             NaN
# 16                          NaN                             NaN
# 17                          NaN                             NaN
# 18                          NaN                             NaN
# 19                          NaN                             NaN
# 20                          NaN                             NaN
# 21                          NaN                             NaN
# 22                          NaN                             NaN
#
#                                         Partial match Match via UNIQUE-ID  \
# 0                                                 NaN                 YES
# 1                                                 NaN                 NaN
# 2                                    MNM2 _AND_ MNM19                 NaN
# 3                                                 NaN                 NaN
# 4   Gal-13-GlcN-R _AND_ beta-Gal-13-beta-GlcNac-R ...                 NaN
# 5                                                 NaN                 NaN
# 6                                                 NaN                 NaN
# 7                                                 NaN                 NaN
# 8                    C9H16NO5 _AND_ MNM11 _AND_ MNM21                 NaN
# 9                               CPD-15970 _AND_ FRU1P                 NaN
# 10                               crn__D _AND_ crnmock                 NaN
# 11                                                NaN                 NaN
# 12                                                NaN                 NaN
# 13  CHEBI:131689 _AND_ CHEBI:39418 _AND_ Long-Chai...                 NaN
# 14                                                NaN                 YES
# 15                                                NaN                 NaN
# 16           CPD-17257 _AND_ CPD-9247 _AND_ Vaccenate                 NaN
# 17  CPD-16933 _AND_ CPD-16934 _AND_ CPD-24951 _AND...                 NaN
# 18                                          CPD-22089                 NaN
# 19                                                NaN                 NaN
# 20                                                NaN                 NaN
# 21                                                NaN                 NaN
# 22                                                NaN                 NaN
#
#    Match via CHEBI Match via COMMON-NAME  Match via ABBREV-NAME  ...  \
# 0              YES                   NaN                    NaN  ...
# 1              YES                   NaN                    NaN  ...
# 2              NaN                   YES                    NaN  ...
# 3              NaN                   YES                    NaN  ...
# 4              NaN                   YES                    NaN  ...
# 5              NaN                   YES                    NaN  ...
# 6              NaN                   NaN                    NaN  ...
# 7              NaN                   NaN                    NaN  ...
# 8              NaN                   NaN                    NaN  ...
# 9              NaN                   NaN                    NaN  ...
# 10             NaN                   NaN                    NaN  ...
# 11             NaN                   NaN                    NaN  ...
# 12             NaN                   NaN                    NaN  ...
# 13             YES                   NaN                    NaN  ...
# 14             NaN                   YES                    NaN  ...
# 15             NaN                   NaN                    NaN  ...
# 16             YES                   NaN                    NaN  ...
# 17             NaN                   NaN                    NaN  ...
# 18             NaN                   NaN                    NaN  ...
# 19             NaN                   NaN                    NaN  ...
# 20             NaN                   NaN                    NaN  ...
# 21             NaN                   NaN                    NaN  ...
# 22             NaN                   NaN                    NaN  ...
#
#    Match via LIGAND-CPD Match via REFMET  Match via PUBCHEM  Match via VMH  \
# 0                   NaN              NaN                NaN            NaN
# 1                   NaN              NaN                NaN            NaN
# 2                   NaN              NaN                NaN            NaN
# 3                   NaN              NaN                NaN            NaN
# 4                   NaN              NaN                NaN            NaN
# 5                   NaN              NaN                NaN            NaN
# 6                   NaN              NaN                NaN            NaN
# 7                   NaN              NaN                NaN            NaN
# 8                   NaN              NaN                NaN            NaN
# 9                   NaN              NaN                NaN            NaN
# 10                  NaN              NaN                NaN            NaN
# 11                  NaN              NaN                NaN            NaN
# 12                  NaN              NaN                NaN            NaN
# 13                  NaN              NaN                NaN            NaN
# 14                  NaN              NaN                NaN            NaN
# 15                  NaN              NaN                NaN            NaN
# 16                  NaN              NaN                NaN            NaN
# 17                  NaN              NaN                NaN            NaN
# 18                  NaN              NaN                NaN            NaN
# 19                  NaN              NaN                NaN            NaN
# 20                  NaN              NaN                NaN            NaN
# 21                  NaN              NaN                NaN            NaN
# 22                  NaN              NaN                NaN            NaN
#
#     Match via CAS Match via INCHI  Match via NON-STANDARD-INCHI  \
# 0             NaN             NaN                           NaN
# 1             NaN             NaN                           NaN
# 2             NaN             NaN                           NaN
# 3             NaN             NaN                           NaN
# 4             NaN             NaN                           NaN
# 5             NaN             NaN                           NaN
# 6             NaN             NaN                           NaN
# 7             NaN             NaN                           NaN
# 8             NaN             NaN                           NaN
# 9             NaN             NaN                           NaN
# 10            NaN             NaN                           NaN
# 11            NaN             NaN                           NaN
# 12            NaN             NaN                           NaN
# 13            NaN             NaN                           NaN
# 14            NaN             NaN                           NaN
# 15            NaN             NaN                           NaN
# 16            NaN             NaN                           NaN
# 17            NaN             NaN                           NaN
# 18            NaN             NaN                           NaN
# 19            NaN             NaN                           NaN
# 20            NaN             NaN                           NaN
# 21            NaN             NaN                           NaN
# 22            NaN             NaN                           NaN
#
#     Match via INCHI-KEY  Match via SMILES  Match via FORMULA
# 0                   NaN               NaN                NaN
# 1                   NaN               NaN                NaN
# 2                   NaN               NaN                NaN
# 3                   NaN               NaN                NaN
# 4                   NaN               NaN                NaN
# 5                   NaN               NaN                NaN
# 6                   NaN               NaN                NaN
# 7                   NaN               NaN                NaN
# 8                   NaN               NaN                NaN
# 9                   NaN               NaN                NaN
# 10                  NaN               NaN                NaN
# 11                  YES               NaN                NaN
# 12                  NaN               YES                NaN
# 13                  NaN               NaN                NaN
# 14                  NaN               NaN                NaN
# 15                  NaN               NaN                NaN
# 16                  NaN               NaN                NaN
# 17                  NaN               NaN                NaN
# 18                  NaN               NaN                NaN
# 19                  NaN               NaN                NaN
# 20                  NaN               NaN                NaN
# 21                  NaN               NaN                NaN
# 22                  NaN               NaN                NaN
#
# [23 rows x 29 columns]

# %% [markdown]
# ## LOG exemple:

# %%
import os

# 1. Set the directory path
directory = 'mapping/classic_partial/logs'

# 2. List all files in the directory
files = [f for f in os.listdir(directory) if os.path.isfile(os.path.join(directory, f))]

# 3. Check if exactly one file exists
if len(files) == 1:
    file_path = os.path.join(directory, files[0])
    print(f"Found log file: {file_path}\n")

    # 4. Read and print the content of the log file
    with open(file_path, 'r', encoding='utf-8') as f:
        content = f.read()
        print(content)
else:
    print(f"Expected 1 file, found {len(files)}: {files}")
# Out:
# Found log file: mapping/classic_partial/logs/mapping_2025-12-15_15_40_38.log
#
# -----------------------------------------
#             MAPPING METABOLITES
# -----------------------------------------
#
# ------> Main package version <------
# numpy version: 2.3.3
# pandas version: 2.3.2
# cobra version: 0.29.1
#
# Command run:
# Actual command run (from sys.argv): python /home/cmuller/miniconda3/envs/metanetmap/bin/metanetmap classic -p -s ../src/metanetmap/toys_tests_data/toys/sbml/toys2.sbml -a ../src/metanetmap/toys_tests_data/toys/maf/ -d ../src/metanetmap/toys_tests_data/conversion_datatable_toys.tsv -o mapping/classic_partial/
#
#
#
# ---->    MODE CLASSIC    <----
#
# Load metabolomics data user path: ../src/metanetmap/toys_tests_data/toys/maf/ and metabolic networks user path: ../src/metanetmap/toys_tests_data/toys/sbml/toys2.sbml
#
#
# ---------------PATHS-------------------
# List metabolomics data paths: ['../src/metanetmap/toys_tests_data/toys/maf/toys1.tsv', '../src/metanetmap/toys_tests_data/toys/maf/toys3.tsv', '../src/metanetmap/toys_tests_data/toys/maf/toys2.tsv']
# List metabolic networks paths: ['../src/metanetmap/toys_tests_data/toys/sbml/toys2.sbml']
#
#
#
# ----------------------------------------------
# ---------------MATCH STEP 1-------------------
# ----------------------------------------------
#
# <1> Direct matching test between metabolites derived from metabolomic data on all metadata in the metabolic network
# <2> Matching test between metabolites derived from metabolomic data on all metadata in the database conversion
#
# ++ Match step for "CPD-17381":
# --"CPD-17381" is present in database with the UNIQUE-ID "CPD-17381" and matches via "UNIQUE-ID"
#
# ++ Match step for "CPD-25370":
# --"CPD-25370" is present in database with the UNIQUE-ID "CPD-25370" and matches via "UNIQUE-ID"
#
# ++ Match step for "CHEBI:4167":
# --"CHEBI:4167" is present in database with the UNIQUE-ID "Glucopyranose" and matches via "CHEBI"
#
# ++ Match step for "CHEBI:84783":
# --"CHEBI:84783" is a metabolite duplicate of "CPD-25370" and matches via "CHEBI"
#
# ++ Match step for "CHEBI:16708":
# --"CHEBI:16708" is present in database with the UNIQUE-ID "ADENINE" and matches via "CHEBI"
#
# ++ Match step for "CHEBI:36023":
#
# ++ Match step for "CHEBI:90488":
#
# ++ Match step for "CHEBI:15756":
#
# ++ Match step for "CHEBI:123564":
#
# ++ Match step for "L-methionine":
# --"L-methionine" is present directly in metabolic network with the ID "['MET']" via "COMMON-NAME"
# --"L-methionine" is present in database with the UNIQUE-ID "MET" and matches via "COMMON-NAME"
#
# ++ Match step for "roquefortine C":
# --"roquefortine C" is a metabolite duplicate of "CPD-17381" and matches via "COMMON-NAME"
#
# ++ Match step for "Adenine":
# --"Adenine" is a metabolite duplicate of "CHEBI:16708" and matches via "COMMON-NAME"
#
# ++ Match step for "Beta-D-galactosyl-(1->3)-N-acetyl-beta-D-glucosaminyl-R":
# --"Beta-D-galactosyl-(1->3)-N-acetyl-beta-D-glucosaminyl-R" is present in database with the UNIQUE-ID "beta-Gal-13-beta-GlcNac-R" and matches via "COMMON-NAME"
# --"Beta-D-galactosyl-(1->3)-N-acetyl-beta-D-glucosaminyl-R" has a partial match. We have several UNIQUE-ID identifiers for this metabolite: "beta-Gal-13-beta-GlcNac-R" and "Gal-13-GlcN-R"
#
# ++ Match step for "vaccenic":
#
# ++ Match step for "delphinidin 3-O-(4-coumaroyl-rhamnosyl-(1->6)-glucoside":
#
# ++ Match step for "methionine":
# --"methionine" is a metabolite duplicate of "L-methionine" and matches via "COMMON-NAME"
# --"methionine" is a metabolite duplicate of "L-methionine" and matches via "COMMON-NAME"
#
# ++ Match step for "8-O-methylfusarubin alcohol":
# --"8-O-methylfusarubin alcohol" is present directly in metabolic network with the ID "['CPD-18186']" via "COMMON-NAME"
# --"8-O-methylfusarubin alcohol" is present in database with the UNIQUE-ID "CPD-18186" and matches via "COMMON-NAME"
#
# ++ Match step for "thionine":
#
# ++ Match step for "beta-D-galactosyl-(1->3)-N-acetyl-beta-D-glucosaminyl-R":
# --"beta-D-galactosyl-(1->3)-N-acetyl-beta-D-glucosaminyl-R" is a metabolite duplicate of "Beta-D-galactosyl-(1->3)-N-acetyl-beta-D-glucosaminyl-R" and matches via "COMMON-NAME"
#
# ++ Match step for "orotic acid":
# --"orotic acid" is present in database with the UNIQUE-ID "OROTATE" and matches via "SYNONYMS"
#
# ++ Match step for "Carbamyl-phosphate":
# --"Carbamyl-phosphate" is present directly in metabolic network with the ID "['Carbamyl-phosphate']" via "SYNONYMS"
# --"Carbamyl-phosphate" is present in database with the UNIQUE-ID "CARBAMOYL-P" and matches via "SYNONYMS"
#
# ++ Match step for "pantothenic acid":
# --"pantothenic acid" is present in database with the UNIQUE-ID "PANTOTHENATE" and matches via "ADD-COMPLEMENT"
#
# ++ Match step for "aprut":
# --"aprut" is present in database with the UNIQUE-ID "CPD-569" and matches via "BIGG"
#
# ++ Match step for "f1p":
# --"f1p" is present in database with the UNIQUE-ID "FRU1P" and matches via "BIGG"
# --"f1p" has a partial match. We have several UNIQUE-ID identifiers for this metabolite: "FRU1P" and "CPD-15970"
#
# ++ Match step for "crnmock":
#
# ++ Match step for "INCHIKEY=CGBYBGVMDAPUIH-ARJAWSKDSA-L":
# --"INCHIKEY=CGBYBGVMDAPUIH-ARJAWSKDSA-L" is present in database with the UNIQUE-ID "DIMETHYLMAL-CPD" and matches via "INCHI-KEY"
#
# ++ Match step for "INCHIKEY=AVVWPBAENSWJCB-VSOTGSRCSA-C":
#
# ++ Match step for "INCHIKEY=FSCYHDCTAZZSKN-DJNGBR":
#
# ++ Match step for "CCCC(=O)OCC(/C=C=C1([C@](C)(O)C[C@@H](OC(=O)C)CC(C)(C)1))=C/C=C/C(\C)=C/C=C/C=C(C)/C=C/C=C(C)/C(=O)C[C@]23(C(C)(C)C[C@H](O)C[C@@](C)(O2)3)":
# --"CCCC(=O)OCC(/C=C=C1([C@](C)(O)C[C@@H](OC(=O)C)CC(C)(C)1))=C/C=C/C(\C)=C/C=C/C=C(C)/C=C/C=C(C)/C(=O)C[C@]23(C(C)(C)C[C@H](O)C[C@@](C)(O2)3)" is present in database with the UNIQUE-ID "CPD-26454" and matches via "SMILES"
#
# ++ Match step for "C(S)[C@@H](C(NCCC(=O)[O-])=O)NC(=O)CC[C@@H](C([O-])=O)NC(=O)[C@H](CS)NC(=O)CC[C@H]([NH3+])C([O-])":
#
# ++ Match step for "C9H16NO5":
#
#
# ----------------------------------------------
# ---------------MATCH STEP 2-------------------
# ----------------------------------------------
#
# <3> Matching test on metabolites that matched only on the database conversion data against all metadata from the metabolic network
#
# --"Beta-D-galactosyl-(1->3)-N-acetyl-beta-D-glucosaminyl-R" is present directly in metabolic network with the corresponding ID "Gal-13-GlcN-R" via the match ID "gal-13-glcn-r"
# --"orotic acid" is present directly in metabolic network with the corresponding ID "OROTATE" via the match ID "orotate"
# --"pantothenic acid" is present directly in metabolic network with the corresponding ID "PANTOTHENATE" via the match ID "pantothenate"
# --"CCCC(=O)OCC(/C=C=C1([C@](C)(O)C[C@@H](OC(=O)C)CC(C)(C)1))=C/C=C/C(\C)=C/C=C/C=C(C)/C=C/C=C(C)/C(=O)C[C@]23(C(C)(C)C[C@H](O)C[C@@](C)(O2)3)" is present directly in metabolic network with the corresponding ID "CPD-26454" via the match ID "cpd-26454"
#
#
# ------------------------------------------------
# ---------------PARTIAL MATCH -------------------
# ----------------------------------------------
#
# <4> Attempting to find new IDs for unmatched metabolites using multiple strategies: removing enantiomer specificity, using the core part of InChIKeys, or exploring parent/child relationships in CHEBI.
#
#
# -----> CHEBI <-----
#
#  ++CHEBI identification step for CHEBI:36023:
#
#  ++CHEBI identification step for CHEBI:15756:
#
#  ++CHEBI identification step for CHEBI:36023:
#
#  ++CHEBI identification step for CHEBI:90488:
# --CHEBI:36023 is CHEBI:36023
#    --Parents are :
#      -- CHEBI:36023 is related to octadecenoic acid
#      -- CHEBI:36023 is related to straight-chain fatty acid
#    --Children are :
#      -- CHEBI:36023 is related to trans-vaccenic acid
#      -- CHEBI:36023 is related to cis-vaccenic acid
# --CHEBI:90488 is CHEBI:90488
#    --Parents are :
#      -- CHEBI:90488 is related to 1-phosphatidyl-1D-myo-inositol
# --CHEBI:36023 is CHEBI:36023
#    --Parents are :
#      -- vaccenic is related to octadecenoic acid
#      -- vaccenic is related to straight-chain fatty acid
#    --Children are :
#      -- vaccenic is related to trans-vaccenic acid
#      -- vaccenic is related to cis-vaccenic acid
# --CHEBI:15756 is CHEBI:15756
#    --Parents are :
#      -- CHEBI:15756 is related to straight-chain saturated fatty acid
#      -- CHEBI:15756 is related to long-chain fatty acid
#    --Children are :
#      -- CHEBI:15756 is related to 1-hexadecanoyl-2-methyl-sn-glycero-3-phosphocholine
#
# -----> inchikey <-----
# inchikey: INCHIKEY=FSCYHDCTAZZSKN-DJNGBR -> Short inchikey: ['INCHIKEY=FSCYHDCTAZZSKN']
# inchikey: INCHIKEY=AVVWPBAENSWJCB-VSOTGSRCSA-C -> Short inchikey: ['INCHIKEY=AVVWPBAENSWJCB']
#
# -----> Enantiomers <-----
# -----> Remove enantiomers in database and in metadata of sbml <-----
#
#
# ----------------------------------------------------
# ---------------Retry MATCH STEP 1-------------------
# ----------------------------------------------------
#
# -----> Test: CHEBI <-----
#
# ++ Match step for "CHEBI:36023":
#
# --Try with CHEBI:36023":
#
# --Try with vaccenic acid":
# --"CHEBI:36023" is present in database with the UNIQUE-ID "Vaccenate" and matches via "CHEBI"
#
# --Try with CHEBI:25634":
#
# --Try with octadecenoic acid":
#
# --Try with CHEBI:59202":
#
# --Try with straight-chain fatty acid":
#
# --Try with CHEBI:28727":
#
# --Try with trans-vaccenic acid":
# --"CHEBI:36023" has a partial match. We have several UNIQUE-ID identifiers for this metabolite: "Vaccenate" and "CPD-17257"
#
# --Try with CHEBI:50464":
#
# --Try with cis-vaccenic acid":
# --"CHEBI:36023" has a partial match. We have several UNIQUE-ID identifiers for this metabolite: "Vaccenate _AND_ CPD-17257" and "CPD-9247"
#
# ++ Match step for "CHEBI:90488":
#
# --Try with CHEBI:90488":
#
# --Try with phosphatidylinositol (18:1/20:4)":
#
# --Try with CHEBI:16749":
#
# --Try with 1-phosphatidyl-1D-myo-inositol":
#
# ++ Match step for "vaccenic":
#
# --Try with CHEBI:36023":
#
# --Try with vaccenic acid":
# --"vaccenic" is present in database with the UNIQUE-ID "Vaccenate" and matches via "CHEBI"
#
# --Try with CHEBI:25634":
#
# --Try with octadecenoic acid":
#
# --Try with CHEBI:59202":
#
# --Try with straight-chain fatty acid":
#
# --Try with CHEBI:28727":
#
# --Try with trans-vaccenic acid":
# --"vaccenic" has a partial match. We have several UNIQUE-ID identifiers for this metabolite: "Vaccenate" and "CPD-17257"
#
# --Try with CHEBI:50464":
#
# --Try with cis-vaccenic acid":
# --"vaccenic" is a metabolite duplicate of "CHEBI:36023" and matches via "CHEBI"
#
# ++ Match step for "CHEBI:15756":
#
# --Try with CHEBI:15756":
#
# --Try with hexadecanoic acid":
# --"CHEBI:15756" is present in database with the UNIQUE-ID "PALMITATE" and matches via "CHEBI"
#
# --Try with PALMITATE":
#
# --Try with CHEBI:39418":
#
# --Try with straight-chain saturated fatty acid":
#
# --Try with CHEBI:15904":
# --"CHEBI:15756" has a partial match. We have several UNIQUE-ID identifiers for this metabolite: "PALMITATE" and "Long-Chain-Fatty-Acids"
#
# --Try with long-chain fatty acid":
#
# --Try with CHEBI:131689":
#
# --Try with 1-hexadecanoyl-2-methyl-sn-glycero-3-phosphocholine":
#
# -----> Test: Inchey <-----
#
# ++ Match step for "INCHIKEY=FSCYHDCTAZZSKN":
#
# --Try with INCHIKEY=FSCYHDCTAZZSKN-DJNGBR":
#
# ++ Match step for "INCHIKEY=AVVWPBAENSWJCB":
#
# --Try with INCHIKEY=AVVWPBAENSWJCB-VSOTGSRCSA-C":
# --"INCHIKEY=AVVWPBAENSWJCB-VSOTGSRCSA-C" is present in database with the UNIQUE-ID "CPD-24978" and matches via "inchikey"
# --"INCHIKEY=AVVWPBAENSWJCB-VSOTGSRCSA-C" has a partial match. We have several UNIQUE-ID identifiers for this metabolite: "CPD-24978" and "CPD-25014"
# --"INCHIKEY=AVVWPBAENSWJCB-VSOTGSRCSA-C" has a partial match. We have several UNIQUE-ID identifiers for this metabolite: "CPD-24978 _AND_ CPD-25014" and "CPD-25010"
# --"INCHIKEY=AVVWPBAENSWJCB-VSOTGSRCSA-C" has a partial match. We have several UNIQUE-ID identifiers for this metabolite: "CPD-24978 _AND_ CPD-25014 _AND_ CPD-25010" and "CPD-16933"
# --"INCHIKEY=AVVWPBAENSWJCB-VSOTGSRCSA-C" has a partial match. We have several UNIQUE-ID identifiers for this metabolite: "CPD-24978 _AND_ CPD-25014 _AND_ CPD-25010 _AND_ CPD-16933" and "CPD-24986"
# --"INCHIKEY=AVVWPBAENSWJCB-VSOTGSRCSA-C" has a partial match. We have several UNIQUE-ID identifiers for this metabolite: "CPD-24978 _AND_ CPD-25014 _AND_ CPD-25010 _AND_ CPD-16933 _AND_ CPD-24986" and "CPD-24992"
# --"INCHIKEY=AVVWPBAENSWJCB-VSOTGSRCSA-C" has a partial match. We have several UNIQUE-ID identifiers for this metabolite: "CPD-24978 _AND_ CPD-25014 _AND_ CPD-25010 _AND_ CPD-16933 _AND_ CPD-24986 _AND_ CPD-24992" and "CPD-25011"
# --"INCHIKEY=AVVWPBAENSWJCB-VSOTGSRCSA-C" has a partial match. We have several UNIQUE-ID identifiers for this metabolite: "CPD-24978 _AND_ CPD-25014 _AND_ CPD-25010 _AND_ CPD-16933 _AND_ CPD-24986 _AND_ CPD-24992 _AND_ CPD-25011" and "CPD-25008"
# --"INCHIKEY=AVVWPBAENSWJCB-VSOTGSRCSA-C" has a partial match. We have several UNIQUE-ID identifiers for this metabolite: "CPD-24978 _AND_ CPD-25014 _AND_ CPD-25010 _AND_ CPD-16933 _AND_ CPD-24986 _AND_ CPD-24992 _AND_ CPD-25011 _AND_ CPD-25008" and "CPD-25020"
# --"INCHIKEY=AVVWPBAENSWJCB-VSOTGSRCSA-C" has a partial match. We have several UNIQUE-ID identifiers for this metabolite: "CPD-24978 _AND_ CPD-25014 _AND_ CPD-25010 _AND_ CPD-16933 _AND_ CPD-24986 _AND_ CPD-24992 _AND_ CPD-25011 _AND_ CPD-25008 _AND_ CPD-25020" and "CPD-24979"
# --"INCHIKEY=AVVWPBAENSWJCB-VSOTGSRCSA-C" has a partial match. We have several UNIQUE-ID identifiers for this metabolite: "CPD-24978 _AND_ CPD-25014 _AND_ CPD-25010 _AND_ CPD-16933 _AND_ CPD-24986 _AND_ CPD-24992 _AND_ CPD-25011 _AND_ CPD-25008 _AND_ CPD-25020 _AND_ CPD-24979" and "CPD-24991"
# --"INCHIKEY=AVVWPBAENSWJCB-VSOTGSRCSA-C" has a partial match. We have several UNIQUE-ID identifiers for this metabolite: "CPD-24978 _AND_ CPD-25014 _AND_ CPD-25010 _AND_ CPD-16933 _AND_ CPD-24986 _AND_ CPD-24992 _AND_ CPD-25011 _AND_ CPD-25008 _AND_ CPD-25020 _AND_ CPD-24979 _AND_ CPD-24991" and "CPD-24984"
# --"INCHIKEY=AVVWPBAENSWJCB-VSOTGSRCSA-C" has a partial match. We have several UNIQUE-ID identifiers for this metabolite: "CPD-24978 _AND_ CPD-25014 _AND_ CPD-25010 _AND_ CPD-16933 _AND_ CPD-24986 _AND_ CPD-24992 _AND_ CPD-25011 _AND_ CPD-25008 _AND_ CPD-25020 _AND_ CPD-24979 _AND_ CPD-24991 _AND_ CPD-24984" and "CPD-24997"
# --"INCHIKEY=AVVWPBAENSWJCB-VSOTGSRCSA-C" has a partial match. We have several UNIQUE-ID identifiers for this metabolite: "CPD-24978 _AND_ CPD-25014 _AND_ CPD-25010 _AND_ CPD-16933 _AND_ CPD-24986 _AND_ CPD-24992 _AND_ CPD-25011 _AND_ CPD-25008 _AND_ CPD-25020 _AND_ CPD-24979 _AND_ CPD-24991 _AND_ CPD-24984 _AND_ CPD-24997" and "CPD-25015"
# --"INCHIKEY=AVVWPBAENSWJCB-VSOTGSRCSA-C" has a partial match. We have several UNIQUE-ID identifiers for this metabolite: "CPD-24978 _AND_ CPD-25014 _AND_ CPD-25010 _AND_ CPD-16933 _AND_ CPD-24986 _AND_ CPD-24992 _AND_ CPD-25011 _AND_ CPD-25008 _AND_ CPD-25020 _AND_ CPD-24979 _AND_ CPD-24991 _AND_ CPD-24984 _AND_ CPD-24997 _AND_ CPD-25015" and "CPD-25019"
# --"INCHIKEY=AVVWPBAENSWJCB-VSOTGSRCSA-C" has a partial match. We have several UNIQUE-ID identifiers for this metabolite: "CPD-24978 _AND_ CPD-25014 _AND_ CPD-25010 _AND_ CPD-16933 _AND_ CPD-24986 _AND_ CPD-24992 _AND_ CPD-25011 _AND_ CPD-25008 _AND_ CPD-25020 _AND_ CPD-24979 _AND_ CPD-24991 _AND_ CPD-24984 _AND_ CPD-24997 _AND_ CPD-25015 _AND_ CPD-25019" and "CPD0-2486"
# --"INCHIKEY=AVVWPBAENSWJCB-VSOTGSRCSA-C" has a partial match. We have several UNIQUE-ID identifiers for this metabolite: "CPD-24978 _AND_ CPD-25014 _AND_ CPD-25010 _AND_ CPD-16933 _AND_ CPD-24986 _AND_ CPD-24992 _AND_ CPD-25011 _AND_ CPD-25008 _AND_ CPD-25020 _AND_ CPD-24979 _AND_ CPD-24991 _AND_ CPD-24984 _AND_ CPD-24997 _AND_ CPD-25015 _AND_ CPD-25019 _AND_ CPD0-2486" and "CPD-25006"
# --"INCHIKEY=AVVWPBAENSWJCB-VSOTGSRCSA-C" has a partial match. We have several UNIQUE-ID identifiers for this metabolite: "CPD-24978 _AND_ CPD-25014 _AND_ CPD-25010 _AND_ CPD-16933 _AND_ CPD-24986 _AND_ CPD-24992 _AND_ CPD-25011 _AND_ CPD-25008 _AND_ CPD-25020 _AND_ CPD-24979 _AND_ CPD-24991 _AND_ CPD-24984 _AND_ CPD-24997 _AND_ CPD-25015 _AND_ CPD-25019 _AND_ CPD0-2486 _AND_ CPD-25006" and "CPD-16934"
# --"INCHIKEY=AVVWPBAENSWJCB-VSOTGSRCSA-C" has a partial match. We have several UNIQUE-ID identifiers for this metabolite: "CPD-24978 _AND_ CPD-25014 _AND_ CPD-25010 _AND_ CPD-16933 _AND_ CPD-24986 _AND_ CPD-24992 _AND_ CPD-25011 _AND_ CPD-25008 _AND_ CPD-25020 _AND_ CPD-24979 _AND_ CPD-24991 _AND_ CPD-24984 _AND_ CPD-24997 _AND_ CPD-25015 _AND_ CPD-25019 _AND_ CPD0-2486 _AND_ CPD-25006 _AND_ CPD-16934" and "CPD-24952"
# --"INCHIKEY=AVVWPBAENSWJCB-VSOTGSRCSA-C" has a partial match. We have several UNIQUE-ID identifiers for this metabolite: "CPD-24978 _AND_ CPD-25014 _AND_ CPD-25010 _AND_ CPD-16933 _AND_ CPD-24986 _AND_ CPD-24992 _AND_ CPD-25011 _AND_ CPD-25008 _AND_ CPD-25020 _AND_ CPD-24979 _AND_ CPD-24991 _AND_ CPD-24984 _AND_ CPD-24997 _AND_ CPD-25015 _AND_ CPD-25019 _AND_ CPD0-2486 _AND_ CPD-25006 _AND_ CPD-16934 _AND_ CPD-24952" and "CPD-25013"
# --"INCHIKEY=AVVWPBAENSWJCB-VSOTGSRCSA-C" has a partial match. We have several UNIQUE-ID identifiers for this metabolite: "CPD-24978 _AND_ CPD-25014 _AND_ CPD-25010 _AND_ CPD-16933 _AND_ CPD-24986 _AND_ CPD-24992 _AND_ CPD-25011 _AND_ CPD-25008 _AND_ CPD-25020 _AND_ CPD-24979 _AND_ CPD-24991 _AND_ CPD-24984 _AND_ CPD-24997 _AND_ CPD-25015 _AND_ CPD-25019 _AND_ CPD0-2486 _AND_ CPD-25006 _AND_ CPD-16934 _AND_ CPD-24952 _AND_ CPD-25013" and "CPD-24951"
# --"INCHIKEY=AVVWPBAENSWJCB-VSOTGSRCSA-C" has a partial match. We have several UNIQUE-ID identifiers for this metabolite: "CPD-24978 _AND_ CPD-25014 _AND_ CPD-25010 _AND_ CPD-16933 _AND_ CPD-24986 _AND_ CPD-24992 _AND_ CPD-25011 _AND_ CPD-25008 _AND_ CPD-25020 _AND_ CPD-24979 _AND_ CPD-24991 _AND_ CPD-24984 _AND_ CPD-24997 _AND_ CPD-25015 _AND_ CPD-25019 _AND_ CPD0-2486 _AND_ CPD-25006 _AND_ CPD-16934 _AND_ CPD-24952 _AND_ CPD-25013 _AND_ CPD-24951" and "CPD-25012"
# --"INCHIKEY=AVVWPBAENSWJCB-VSOTGSRCSA-C" has a partial match. We have several UNIQUE-ID identifiers for this metabolite: "CPD-24978 _AND_ CPD-25014 _AND_ CPD-25010 _AND_ CPD-16933 _AND_ CPD-24986 _AND_ CPD-24992 _AND_ CPD-25011 _AND_ CPD-25008 _AND_ CPD-25020 _AND_ CPD-24979 _AND_ CPD-24991 _AND_ CPD-24984 _AND_ CPD-24997 _AND_ CPD-25015 _AND_ CPD-25019 _AND_ CPD0-2486 _AND_ CPD-25006 _AND_ CPD-16934 _AND_ CPD-24952 _AND_ CPD-25013 _AND_ CPD-24951 _AND_ CPD-25012" and "CPD0-2485"
# --"INCHIKEY=AVVWPBAENSWJCB-VSOTGSRCSA-C" has a partial match. We have several UNIQUE-ID identifiers for this metabolite: "CPD-24978 _AND_ CPD-25014 _AND_ CPD-25010 _AND_ CPD-16933 _AND_ CPD-24986 _AND_ CPD-24992 _AND_ CPD-25011 _AND_ CPD-25008 _AND_ CPD-25020 _AND_ CPD-24979 _AND_ CPD-24991 _AND_ CPD-24984 _AND_ CPD-24997 _AND_ CPD-25015 _AND_ CPD-25019 _AND_ CPD0-2486 _AND_ CPD-25006 _AND_ CPD-16934 _AND_ CPD-24952 _AND_ CPD-25013 _AND_ CPD-24951 _AND_ CPD-25012 _AND_ CPD0-2485" and "CPD-24996"
# --"INCHIKEY=AVVWPBAENSWJCB-VSOTGSRCSA-C" has a partial match. We have several UNIQUE-ID identifiers for this metabolite: "CPD-24978 _AND_ CPD-25014 _AND_ CPD-25010 _AND_ CPD-16933 _AND_ CPD-24986 _AND_ CPD-24992 _AND_ CPD-25011 _AND_ CPD-25008 _AND_ CPD-25020 _AND_ CPD-24979 _AND_ CPD-24991 _AND_ CPD-24984 _AND_ CPD-24997 _AND_ CPD-25015 _AND_ CPD-25019 _AND_ CPD0-2486 _AND_ CPD-25006 _AND_ CPD-16934 _AND_ CPD-24952 _AND_ CPD-25013 _AND_ CPD-24951 _AND_ CPD-25012 _AND_ CPD0-2485 _AND_ CPD-24996" and "CPD-24985"
# --"INCHIKEY=AVVWPBAENSWJCB-VSOTGSRCSA-C" has a partial match. We have several UNIQUE-ID identifiers for this metabolite: "CPD-24978 _AND_ CPD-25014 _AND_ CPD-25010 _AND_ CPD-16933 _AND_ CPD-24986 _AND_ CPD-24992 _AND_ CPD-25011 _AND_ CPD-25008 _AND_ CPD-25020 _AND_ CPD-24979 _AND_ CPD-24991 _AND_ CPD-24984 _AND_ CPD-24997 _AND_ CPD-25015 _AND_ CPD-25019 _AND_ CPD0-2486 _AND_ CPD-25006 _AND_ CPD-16934 _AND_ CPD-24952 _AND_ CPD-25013 _AND_ CPD-24951 _AND_ CPD-25012 _AND_ CPD0-2485 _AND_ CPD-24996 _AND_ CPD-24985" and "CPD-24990"
# --"INCHIKEY=AVVWPBAENSWJCB-VSOTGSRCSA-C" has a partial match. We have several UNIQUE-ID identifiers for this metabolite: "CPD-24978 _AND_ CPD-25014 _AND_ CPD-25010 _AND_ CPD-16933 _AND_ CPD-24986 _AND_ CPD-24992 _AND_ CPD-25011 _AND_ CPD-25008 _AND_ CPD-25020 _AND_ CPD-24979 _AND_ CPD-24991 _AND_ CPD-24984 _AND_ CPD-24997 _AND_ CPD-25015 _AND_ CPD-25019 _AND_ CPD0-2486 _AND_ CPD-25006 _AND_ CPD-16934 _AND_ CPD-24952 _AND_ CPD-25013 _AND_ CPD-24951 _AND_ CPD-25012 _AND_ CPD0-2485 _AND_ CPD-24996 _AND_ CPD-24985 _AND_ CPD-24990" and "CPD-24983"
# --"INCHIKEY=AVVWPBAENSWJCB-VSOTGSRCSA-C" has a partial match. We have several UNIQUE-ID identifiers for this metabolite: "CPD-24978 _AND_ CPD-25014 _AND_ CPD-25010 _AND_ CPD-16933 _AND_ CPD-24986 _AND_ CPD-24992 _AND_ CPD-25011 _AND_ CPD-25008 _AND_ CPD-25020 _AND_ CPD-24979 _AND_ CPD-24991 _AND_ CPD-24984 _AND_ CPD-24997 _AND_ CPD-25015 _AND_ CPD-25019 _AND_ CPD0-2486 _AND_ CPD-25006 _AND_ CPD-16934 _AND_ CPD-24952 _AND_ CPD-25013 _AND_ CPD-24951 _AND_ CPD-25012 _AND_ CPD0-2485 _AND_ CPD-24996 _AND_ CPD-24985 _AND_ CPD-24990 _AND_ CPD-24983" and "CPD-25009"
# --"INCHIKEY=AVVWPBAENSWJCB-VSOTGSRCSA-C" has a partial match. We have several UNIQUE-ID identifiers for this metabolite: "CPD-24978 _AND_ CPD-25014 _AND_ CPD-25010 _AND_ CPD-16933 _AND_ CPD-24986 _AND_ CPD-24992 _AND_ CPD-25011 _AND_ CPD-25008 _AND_ CPD-25020 _AND_ CPD-24979 _AND_ CPD-24991 _AND_ CPD-24984 _AND_ CPD-24997 _AND_ CPD-25015 _AND_ CPD-25019 _AND_ CPD0-2486 _AND_ CPD-25006 _AND_ CPD-16934 _AND_ CPD-24952 _AND_ CPD-25013 _AND_ CPD-24951 _AND_ CPD-25012 _AND_ CPD0-2485 _AND_ CPD-24996 _AND_ CPD-24985 _AND_ CPD-24990 _AND_ CPD-24983 _AND_ CPD-25009" and "CPD-24993"
# --"INCHIKEY=AVVWPBAENSWJCB-VSOTGSRCSA-C" has a partial match. We have several UNIQUE-ID identifiers for this metabolite: "CPD-24978 _AND_ CPD-25014 _AND_ CPD-25010 _AND_ CPD-16933 _AND_ CPD-24986 _AND_ CPD-24992 _AND_ CPD-25011 _AND_ CPD-25008 _AND_ CPD-25020 _AND_ CPD-24979 _AND_ CPD-24991 _AND_ CPD-24984 _AND_ CPD-24997 _AND_ CPD-25015 _AND_ CPD-25019 _AND_ CPD0-2486 _AND_ CPD-25006 _AND_ CPD-16934 _AND_ CPD-24952 _AND_ CPD-25013 _AND_ CPD-24951 _AND_ CPD-25012 _AND_ CPD0-2485 _AND_ CPD-24996 _AND_ CPD-24985 _AND_ CPD-24990 _AND_ CPD-24983 _AND_ CPD-25009 _AND_ CPD-24993" and "CPD-25005"
# --"INCHIKEY=AVVWPBAENSWJCB-VSOTGSRCSA-C" has a partial match. We have several UNIQUE-ID identifiers for this metabolite: "CPD-24978 _AND_ CPD-25014 _AND_ CPD-25010 _AND_ CPD-16933 _AND_ CPD-24986 _AND_ CPD-24992 _AND_ CPD-25011 _AND_ CPD-25008 _AND_ CPD-25020 _AND_ CPD-24979 _AND_ CPD-24991 _AND_ CPD-24984 _AND_ CPD-24997 _AND_ CPD-25015 _AND_ CPD-25019 _AND_ CPD0-2486 _AND_ CPD-25006 _AND_ CPD-16934 _AND_ CPD-24952 _AND_ CPD-25013 _AND_ CPD-24951 _AND_ CPD-25012 _AND_ CPD0-2485 _AND_ CPD-24996 _AND_ CPD-24985 _AND_ CPD-24990 _AND_ CPD-24983 _AND_ CPD-25009 _AND_ CPD-24993 _AND_ CPD-25005" and "CPD-25004"
# --"INCHIKEY=AVVWPBAENSWJCB-VSOTGSRCSA-C" has a partial match. We have several UNIQUE-ID identifiers for this metabolite: "CPD-24978 _AND_ CPD-25014 _AND_ CPD-25010 _AND_ CPD-16933 _AND_ CPD-24986 _AND_ CPD-24992 _AND_ CPD-25011 _AND_ CPD-25008 _AND_ CPD-25020 _AND_ CPD-24979 _AND_ CPD-24991 _AND_ CPD-24984 _AND_ CPD-24997 _AND_ CPD-25015 _AND_ CPD-25019 _AND_ CPD0-2486 _AND_ CPD-25006 _AND_ CPD-16934 _AND_ CPD-24952 _AND_ CPD-25013 _AND_ CPD-24951 _AND_ CPD-25012 _AND_ CPD0-2485 _AND_ CPD-24996 _AND_ CPD-24985 _AND_ CPD-24990 _AND_ CPD-24983 _AND_ CPD-25009 _AND_ CPD-24993 _AND_ CPD-25005 _AND_ CPD-25004" and "CPD-25007"
#
# -----> Test: Enantiomers <-----
#
# ++ Match step for "delphinidin 3-O-(4-coumaroyl-rhamnosyl-(1->6)-glucoside":
# --"delphinidin 3-O-(4-coumaroyl-rhamnosyl-(1->6)-glucoside" is present in database with the UNIQUE-ID "CPD-22089" and matches via "Enantiomers"
#
# ++ Match step for "crnmock":
#
# ++ Match step for "thionine":
#
# ++ Match step for "C(S)[C@@H](C(NCCC(=O)[O-])=O)NC(=O)CC[C@@H](C([O-])=O)NC(=O)[C@H](CS)NC(=O)CC[C@H]([NH3+])C([O-])":
#
# ++ Match step for "C9H16NO5":
#
#
# ----------------------------------------------------
# ---------------Retry MATCH STEP 2-------------------
# ----------------------------------------------------
#
# -------------------- SUMMARY REPORT --------------------
#
#
# Recap of Matches:
#   + Matched metabolites: 7
#   + Unmatched metabolites: 17
#   + Partial matches: 7
#
#  Match Details:
#   --> Full match (database + SBML): 7
#   --> Partial match + metabolic info: 2
#   --> Match only in SBML: 0
#
#  Unmatch Details:
#   --> Full unmatch (no match in DB or SBML): 6
#   --> Match in DB but not in SBML: 11
#   --> Partial match in DB only: 5
#
# --------------------------------------------------------
#
# Output file successfully written to: mapping/classic_partial/mapping_results_partial_match_2025-12-15_15_40_38.tsv
#
# --- Total runtime 0.47 seconds ---
#  ---> MAPPING COMPLETED'

# %% [markdown]
# ## Remove generated data
# To clean directly the repository of the notebook

# %%
''' Run Community mode with partial match
    The "community" mode allows you to input a directory containing multiple metabolomics data files, as well as a directory containing multiple metabolic networks.

'''

# !rm -r mapping/
# Out:
# 1641.46s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
